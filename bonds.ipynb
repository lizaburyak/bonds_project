# %%
import pandas as pd
import os

# %% [markdown]
# я хочу создать отдельные датафреймы для разных типов interest rates

# %%
FederalFundsRate = pd.DataFrame()
PrimeBankRate = pd.DataFrame()
LIBOR_Rate_3_Mo = pd.DataFrame()
Com_Paper_1_Mo = pd.DataFrame()
Treas_Bills_3_Mo = pd.DataFrame()
Treas_Bills_6_Mo = pd.DataFrame()
Treas_Bills_1_Yr = pd.DataFrame()
Treas_Bills_2_Yr = pd.DataFrame()
Treas_Bills_5_Yr = pd.DataFrame()
Treas_Bills_10_Yr = pd.DataFrame()
Treas_Bills_30_Yr = pd.DataFrame()
Aaa_Corp_Bond = pd.DataFrame()
Baa_Corp_Bond = pd.DataFrame()
State_Local_Bonds = pd.DataFrame()
Home_Mtg_Rate = pd.DataFrame()
Feds_Major_Currency_Index = pd.DataFrame()
Real_GDP = pd.DataFrame()
GDP_Price_Index = pd.DataFrame()
Cons_Price_Index = pd.DataFrame()

# %%
path = '/Users/ludmila/Desktop/2000tables'
# Получить список всех файлов Excel в папке
files = [file for file in os.listdir(path) if file.endswith('.xlsx') or file.endswith('.xls')]

# Словарь для хранения датафреймов
d_2000 = {}

for file in files:
    # Создание полного пути к файлу
    full_path = os.path.join(path, file)
    df = pd.read_excel(full_path)
    df = df.T
    
    # Использование первой строки в качестве названий столбцов
    df.columns = df.iloc[0]

    # Удаление первой строки
    df = df[1:]
    
    # Добавление датафрейма в словарь
    d_2000[file[4:8]] = df
    
    # Сортировка ключей в словаре в лексикографическом порядке
    sorted_keys = sorted(d_2000.keys())

    # Извлечение первой строки каждого датафрейма
    rows = []
    for i in range(19):
        row = [d_2000[key].iloc[i].dropna().astype(str).str.lower() for key in sorted_keys]
        rows.append(row)
        
    # Объединение всех строк в один датафрейм
    FederalFundsRate = pd.concat(rows[0], axis=1).T
    PrimeBankRate = pd.concat(rows[1], axis=1).T
    LIBOR_Rate_3_Mo = pd.concat(rows[2], axis=1).T
    Com_Paper_1_Mo = pd.concat(rows[3], axis=1).T
    Treas_Bills_3_Mo = pd.concat(rows[4], axis=1).T
    Treas_Bills_6_Mo = pd.concat(rows[5], axis=1).T
    Treas_Bills_1_Yr = pd.concat(rows[6], axis=1).T
    Treas_Bills_2_Yr = pd.concat(rows[7], axis=1).T
    Treas_Bills_5_Yr = pd.concat(rows[8], axis=1).T
    Treas_Bills_10_Yr = pd.concat(rows[9], axis=1).T
    Treas_Bills_30_Yr = pd.concat(rows[10], axis=1).T
    Aaa_Corp_Bond = pd.concat(rows[11], axis=1).T
    Baa_Corp_Bond = pd.concat(rows[12], axis=1).T
    State_Local_Bonds = pd.concat(rows[13], axis=1).T
    Home_Mtg_Rate = pd.concat(rows[14], axis=1).T
    Feds_Major_Currency_Index = pd.concat(rows[15], axis=1).T
    Real_GDP = pd.concat(rows[16], axis=1).T
    GDP_Price_Index = pd.concat(rows[17], axis=1).T
    Cons_Price_Index = pd.concat(rows[18], axis=1).T

    # Создание списка с новыми индексами
    new_index = pd.date_range(start="01/2000", periods=len(FederalFundsRate), freq='M').strftime('%m/%Y')

    # Замена индексов строк на новые даты
    FederalFundsRate.set_index(new_index, inplace=True)
    PrimeBankRate.set_index(new_index, inplace=True)
    LIBOR_Rate_3_Mo.set_index(new_index, inplace=True)
    Treas_Bills_3_Mo.set_index(new_index, inplace=True)
    Treas_Bills_6_Mo.set_index(new_index, inplace=True)
    Treas_Bills_1_Yr.set_index(new_index, inplace=True)
    Treas_Bills_2_Yr.set_index(new_index, inplace=True)
    Treas_Bills_5_Yr.set_index(new_index, inplace=True)
    Treas_Bills_10_Yr.set_index(new_index, inplace=True)
    Treas_Bills_30_Yr.set_index(new_index, inplace=True)
    Aaa_Corp_Bond.set_index(new_index, inplace=True)
    Baa_Corp_Bond.set_index(new_index, inplace=True)
    State_Local_Bonds.set_index(new_index, inplace=True)
    Home_Mtg_Rate.set_index(new_index, inplace=True)
    Feds_Major_Currency_Index.set_index(new_index, inplace=True)
    Real_GDP.set_index(new_index, inplace=True)
    GDP_Price_Index.set_index(new_index, inplace=True)
    Cons_Price_Index.set_index(new_index, inplace=True)

# %%
FederalFundsRate.head()
# Out:
# Unnamed: 0 Banc One Invest. Advisors Wayne Hummer & Co. Tucker Anthony, Inc.  \
# 01/2000                          5.9                5.8                  5.8
# 02/2000                          NaN                6.0                  5.8
# 03/2000                          5.9                5.8                  6.0
# 04/2000                          6.3                6.3                  6.0
# 05/2000                          6.3                6.4                  6.3
#
# Unnamed: 0 Goldman Sachs & Co. DePrince & Assoc. Scotiabank Bank One  \
# 01/2000                    5.8               5.8        5.8      5.7
# 02/2000                    5.8               5.8        6.0      5.7
# 03/2000                    6.0               5.6        6.0      5.6
# 04/2000                    6.3               6.1        6.5      6.1
# 05/2000                    6.1               6.1        6.5      6.1
#
# Unnamed: 0 Thomson Global Markets Wells Capital Management Tokai Bank, Lid.  \
# ...

# %%
Feds_Major_Currency_Index.head()
# Out:
# Unnamed: 0 Banc One Invest. Advisors Wayne Hummer & Co. Tucker Anthony, Inc.  \
# 01/2000                         94.3               92.9                 95.0
# 02/2000                          NaN               92.9                 95.0
# 03/2000                         95.0               95.0                 95.0
# 04/2000                         95.5               94.2                 95.0
# 05/2000                         95.5               96.1                 95.0
#
# Unnamed: 0 Goldman Sachs & Co. DePrince & Assoc. Scotiabank Bank One  \
# 01/2000                  -99.0              90.6       93.0    -99.0
# 02/2000                  -99.0              92.7       91.6    -99.0
# 03/2000                  -99.0              92.8       95.3    -99.0
# 04/2000                  -99.0              93.1       94.8    -99.0
# 05/2000                  -99.0              95.9       94.2    -99.0
#
# Unnamed: 0 Thomson Global Markets Wells Capital Management Tokai Bank, Lid.  \
# ...

# %%
years = range(2001, 2007)
path = '/Users/ludmila/Desktop/'
paths = []

for year in years:
    full_path = path + str(year) + 'tables'
    paths.append(full_path)

years = range(2007, 2023)
for year in years:
    full_path = path + str(year) + '_output'
    paths.append(full_path)
print(paths)
# Out:
# ['/Users/ludmila/Desktop/2001tables', '/Users/ludmila/Desktop/2002tables', '/Users/ludmila/Desktop/2003tables', '/Users/ludmila/Desktop/2004tables', '/Users/ludmila/Desktop/2005tables', '/Users/ludmila/Desktop/2006tables', '/Users/ludmila/Desktop/2007_output', '/Users/ludmila/Desktop/2008_output', '/Users/ludmila/Desktop/2009_output', '/Users/ludmila/Desktop/2010_output', '/Users/ludmila/Desktop/2011_output', '/Users/ludmila/Desktop/2012_output', '/Users/ludmila/Desktop/2013_output', '/Users/ludmila/Desktop/2014_output', '/Users/ludmila/Desktop/2015_output', '/Users/ludmila/Desktop/2016_output', '/Users/ludmila/Desktop/2017_output', '/Users/ludmila/Desktop/2018_output', '/Users/ludmila/Desktop/2019_output', '/Users/ludmila/Desktop/2020_output', '/Users/ludmila/Desktop/2021_output', '/Users/ludmila/Desktop/2022_output']

# %%
for path in paths:

    # Получить список всех файлов Excel в папке
    files = [file for file in os.listdir(path) if file.endswith('.xlsx') or file.endswith('.xls')]

    # Словарь для хранения датафреймов
    one_year = {}

    for file in files:
        # Создание полного пути к файлу
        if file[0] == '~':
            file = file[2:]
        full_path = os.path.join(path, file)
        df = pd.read_excel(full_path)
        df = df.T
    
        # Использование первой строки в качестве названий столбцов
        df.columns = df.iloc[0]
        
        if file == 'CorrectedBCFF0911email.pdf Third Quarter 2011.xlsx':
            file = 'BCFF0911email.pdf Third Quarter 2011.xlsx'
        if file == 'CorrectedBCFF1214email.pdf Fourth Quarter 2014.xlsx':
            file = 'BCFF1214email.pdf Fourth Quarter 2014.xlsx'
        year = file[6:8]

        # Проверяем, является ли год допустимым числом
        if year.isdigit():
        # Преобразуем год в целое число
            year = int(year)
        else:
            print(file)
            print("Недопустимый формат года")
            
        if year <= 6 or year == 22:
            df = df[1:]
        if 6 < year and year < 22:
            df = df[2:]
            
        if df.shape[0] == 19:
            #print(file)
            df = df.set_index(pd.Index(range(1, 20)))
        else:
            #print(file)
            df = df.set_index(pd.Index(range(1, 21)))
    
        # Добавление датафрейма в словарь
        one_year[file[4:8]] = df
    
    # Сортировка ключей в словаре в лексикографическом порядке
    sorted_keys = sorted(one_year.keys())
    
    rows = []
    for i in range(19):
        row = [one_year[key].iloc[i].dropna().astype(str).str.lower() for key in sorted_keys]
        rows.append(row)
    
    # Объединение всех строк в один датафрейм
    FederalFundsRate_this_year = pd.concat(rows[0], axis=1).T
    PrimeBankRate_this_year = pd.concat(rows[1], axis=1).T
    LIBOR_Rate_3_Mo_this_year = pd.concat(rows[2], axis=1).T
    Com_Paper_1_Mo_this_year = pd.concat(rows[3], axis=1).T
    Treas_Bills_3_Mo_this_year = pd.concat(rows[4], axis=1).T
    Treas_Bills_6_Mo_this_year = pd.concat(rows[5], axis=1).T
    Treas_Bills_1_Yr_this_year = pd.concat(rows[6], axis=1).T
    Treas_Bills_2_Yr_this_year = pd.concat(rows[7], axis=1).T
    Treas_Bills_5_Yr_this_year = pd.concat(rows[8], axis=1).T
    Treas_Bills_10_Yr_this_year = pd.concat(rows[9], axis=1).T
    Treas_Bills_30_Yr_this_year = pd.concat(rows[10], axis=1).T
    Aaa_Corp_Bond_this_year = pd.concat(rows[11], axis=1).T
    Baa_Corp_Bond_this_year = pd.concat(rows[12], axis=1).T
    State_Local_Bonds_this_year = pd.concat(rows[13], axis=1).T
    Home_Mtg_Rate_this_year = pd.concat(rows[14], axis=1).T
    Feds_Major_Currency_Index_this_year = pd.concat(rows[15], axis=1).T
    Real_GDP_this_year = pd.concat(rows[16], axis=1).T
    GDP_Price_Index_this_year = pd.concat(rows[17], axis=1).T
    Cons_Price_Index_this_year = pd.concat(rows[18], axis=1).T
    
    # Создание списка с новыми индексами
    new_index = pd.date_range(start="01/" + path[23:27], periods=len(FederalFundsRate_this_year), freq='M').strftime('%m/%Y')

    # Замена индексов строк на новые даты
    FederalFundsRate_this_year.set_index(new_index, inplace=True)
    PrimeBankRate_this_year.set_index(new_index, inplace=True)
    LIBOR_Rate_3_Mo_this_year.set_index(new_index, inplace=True)
    Com_Paper_1_Mo_this_year.set_index(new_index, inplace=True)
    Treas_Bills_3_Mo_this_year.set_index(new_index, inplace=True)
    Treas_Bills_6_Mo_this_year.set_index(new_index, inplace=True)
    Treas_Bills_1_Yr_this_year.set_index(new_index, inplace=True)
    Treas_Bills_2_Yr_this_year.set_index(new_index, inplace=True)
    Treas_Bills_5_Yr_this_year.set_index(new_index, inplace=True)
    Treas_Bills_10_Yr_this_year.set_index(new_index, inplace=True)
    Treas_Bills_30_Yr_this_year.set_index(new_index, inplace=True)
    Aaa_Corp_Bond_this_year.set_index(new_index, inplace=True)
    Baa_Corp_Bond_this_year.set_index(new_index, inplace=True)
    State_Local_Bonds_this_year.set_index(new_index, inplace=True)
    Home_Mtg_Rate_this_year.set_index(new_index, inplace=True)
    Feds_Major_Currency_Index_this_year.set_index(new_index, inplace=True)
    Real_GDP_this_year.set_index(new_index, inplace=True)
    GDP_Price_Index_this_year.set_index(new_index, inplace=True)
    Cons_Price_Index_this_year.set_index(new_index, inplace=True)
    
    
    FederalFundsRate = pd.concat([FederalFundsRate, FederalFundsRate_this_year], axis=0)
    PrimeBankRate = pd.concat([PrimeBankRate, PrimeBankRate_this_year], axis=0)
    LIBOR_Rate_3_Mo = pd.concat([LIBOR_Rate_3_Mo, LIBOR_Rate_3_Mo_this_year], axis=0)
    Com_Paper_1_Mo = pd.concat([Com_Paper_1_Mo, Com_Paper_1_Mo_this_year], axis=0)
    Treas_Bills_3_Mo = pd.concat([Treas_Bills_3_Mo, Treas_Bills_3_Mo_this_year], axis=0)
    Treas_Bills_6_Mo = pd.concat([Treas_Bills_6_Mo, Treas_Bills_6_Mo_this_year], axis=0)
    Treas_Bills_1_Yr = pd.concat([Treas_Bills_1_Yr, Treas_Bills_1_Yr_this_year], axis=0)
    Treas_Bills_2_Yr = pd.concat([Treas_Bills_2_Yr, Treas_Bills_2_Yr_this_year], axis=0)
    Treas_Bills_5_Yr = pd.concat([Treas_Bills_5_Yr, Treas_Bills_5_Yr_this_year], axis=0)
    Treas_Bills_10_Yr = pd.concat([Treas_Bills_10_Yr, Treas_Bills_10_Yr_this_year], axis=0)
    Treas_Bills_30_Yr = pd.concat([Treas_Bills_30_Yr, Treas_Bills_30_Yr_this_year], axis=0)
    Aaa_Corp_Bond = pd.concat([Aaa_Corp_Bond, Aaa_Corp_Bond_this_year], axis=0)
    Baa_Corp_Bond = pd.concat([Baa_Corp_Bond, Baa_Corp_Bond_this_year], axis=0)
    State_Local_Bonds = pd.concat([State_Local_Bonds, State_Local_Bonds_this_year], axis=0)
    Home_Mtg_Rate = pd.concat([Home_Mtg_Rate, Home_Mtg_Rate_this_year], axis=0)
    Feds_Major_Currency_Index = pd.concat([Feds_Major_Currency_Index, Feds_Major_Currency_Index_this_year], axis=0)
    Real_GDP = pd.concat([Real_GDP, Real_GDP_this_year], axis=0)
    GDP_Price_Index = pd.concat([GDP_Price_Index, GDP_Price_Index_this_year], axis=0)
    Cons_Price_Index = pd.concat([Cons_Price_Index, Cons_Price_Index_this_year], axis=0)

# %%
FederalFundsRate = FederalFundsRate[sorted(FederalFundsRate.columns)]
FederalFundsRate.tail()
# Out:
# Unnamed: 0 ACIMA Private Wealth  AIG ASB Capital Management  \
# 08/2022                     2.5  2.2                    NaN
# 09/2022                     2.5  2.2                    NaN
# 10/2022                     4.0  NaN                    NaN
# 11/2022                     4.0  3.6                    NaN
# 12/2022                     4.3  3.8                    NaN
#
# Unnamed: 0 ASB Captial Management Action Economics Aeitus Investment  \
# 08/2022                       NaN              2.5               NaN
# 09/2022                       NaN              2.3               NaN
# 10/2022                       NaN              3.9               NaN
# 11/2022                       NaN              3.8               NaN
# 12/2022                       NaN              NaN               NaN
#
# Unnamed: 0 Aeltus Investment Aeltus investment Amherst Pierpont Securities  \
# 08/2022                  NaN               NaN                         2.2
# ...

# %%
for val in FederalFundsRate.columns:
    print(val)
# Out:
# ACIMA Private Wealth
# AIG
# ASB Capital Management
# ASB Captial Management
# Action Economics
# Aeitus Investment
# Aeltus Investment
# Aeltus investment
# Amherst Pierpont Securities
# April Consensus
# Argus Research
# August Consensus
# BBVA
# BBVA USA
# BMC Nesbitt Burns
# BMO Capital Markets
# BMO Nesbitt Burns
# BNP Paribas Americas
# Banc One Invest. Advisors
# Banc One invest. Advisors
# Banc of Amercia Securities
# Banc of America Securities
# Banc of America Securities, LLC
# Banc of America-Merrill Lynch
# Bank One
# Bank of America
# Bank of America Merrill Lynch
# Bank of America-Merrill Lynch
# Bank of Toyko-Mitsubishi
# Bank of Toyko-Mitsubishi UFJ
# Bank of the West
# Barclays
# Barclays Capital
# Bardays Capital
# Bear Steams & Co.
# Bear Stearns
# Bear Stearns & Co.
# Bottom 10 Avg.
# Briefing.com
# CAM North America, LLC
# Camilli Economics
# Camilli Economics LLC
# Camilli, Kathleen
# Chan Economics
# Chase Wealth Management
# Chicago Capital
# ...

# %%
# Объединение столбцов
FederalFundsRate['Moody\'s Analytics'] = FederalFundsRate['Moody\'s Analytics'].combine_first(FederalFundsRate['Moody\'s Capital Markets'])
FederalFundsRate['Moody\'s Analytics'] = FederalFundsRate['Moody\'s Analytics'].combine_first(FederalFundsRate['Moody\'s Capital Markets Group'])
FederalFundsRate['Moody\'s Analytics'] = FederalFundsRate['Moody\'s Analytics'].combine_first(FederalFundsRate['Moody\'s Econmy.com'])
FederalFundsRate['Moody\'s Analytics'] = FederalFundsRate['Moody\'s Analytics'].combine_first(FederalFundsRate['Moody\'s Economy.com'])
FederalFundsRate['Moody\'s Analytics'] = FederalFundsRate['Moody\'s Analytics'].combine_first(FederalFundsRate['Moody\'s Investors Service'])
FederalFundsRate['Moody\'s Analytics'] = FederalFundsRate['Moody\'s Analytics'].combine_first(FederalFundsRate['Moodys Investors Service'])
FederalFundsRate = FederalFundsRate.drop('Moody\'s Capital Markets', axis=1)
FederalFundsRate = FederalFundsRate.drop('Moody\'s Capital Markets Group', axis=1)
FederalFundsRate = FederalFundsRate.drop('Moody\'s Econmy.com', axis=1)
FederalFundsRate = FederalFundsRate.drop('Moody\'s Economy.com', axis=1)
FederalFundsRate = FederalFundsRate.drop('Moody\'s Investors Service', axis=1)
FederalFundsRate = FederalFundsRate.drop('Moodys Investors Service', axis=1)

FederalFundsRate['Nat\'l Assn. of Realtors'] = FederalFundsRate['Nat\'l Assn. of Realtors'].combine_first(FederalFundsRate['Nat\'l Assn, of Realtors'])
FederalFundsRate['Nat\'l Assn. of Realtors'] = FederalFundsRate['Nat\'l Assn. of Realtors'].combine_first(FederalFundsRate['Nat\'I Assn, of Realtors'])
FederalFundsRate = FederalFundsRate.drop('Nat\'l Assn, of Realtors', axis=1)
FederalFundsRate = FederalFundsRate.drop('Nat\'I Assn, of Realtors', axis=1)

FederalFundsRate['National City Bank'] = FederalFundsRate['National City Bank'].combine_first(FederalFundsRate['National City Corporation'])
FederalFundsRate = FederalFundsRate.drop('National City Corporation', axis=1)

FederalFundsRate['Nomura Securities Inc.'] = FederalFundsRate['Nomura Securities Inc.'].combine_first(FederalFundsRate['Nomura Securities, Inc.'])
FederalFundsRate = FederalFundsRate.drop('Nomura Securities, Inc.', axis=1)

FederalFundsRate['October Consensus'] = FederalFundsRate['October Consensus'].combine_first(FederalFundsRate['Octoberber Consensus'])
FederalFundsRate = FederalFundsRate.drop('Octoberber Consensus', axis=1)

FederalFundsRate['PNC Bank Corp.'] = FederalFundsRate['PNC Bank Corp.'].combine_first(FederalFundsRate['PNC Financial Services'])
FederalFundsRate['PNC Bank Corp.'] = FederalFundsRate['PNC Bank Corp.'].combine_first(FederalFundsRate['PNC Financial Services Corp.'])
FederalFundsRate['PNC Bank Corp.'] = FederalFundsRate['PNC Bank Corp.'].combine_first(FederalFundsRate['PNC Financial Services Group'])
FederalFundsRate = FederalFundsRate.drop('PNC Financial Services', axis=1)
FederalFundsRate = FederalFundsRate.drop('PNC Financial Services Corp.', axis=1)
FederalFundsRate = FederalFundsRate.drop('PNC Financial Services Group', axis=1)

FederalFundsRate['Prudential Securities'] = FederalFundsRate['Prudential Securities'].combine_first(FederalFundsRate['Prudential Equity Group LLC'])
FederalFundsRate['Prudential Securities'] = FederalFundsRate['Prudential Securities'].combine_first(FederalFundsRate['Prudential Insurance Co.'])
FederalFundsRate['Prudential Securities'] = FederalFundsRate['Prudential Securities'].combine_first(FederalFundsRate['Prudential Financial'])
FederalFundsRate = FederalFundsRate.drop('Prudential Financial', axis=1)
FederalFundsRate = FederalFundsRate.drop('Prudential Insurance Co.', axis=1)
FederalFundsRate = FederalFundsRate.drop('Prudential Equity Group LLC', axis=1)

FederalFundsRate['RBS Greenwich Capital Econ.'] = FederalFundsRate['RBS Greenwich Capital Econ.'].combine_first(FederalFundsRate['RBS Securities'])
FederalFundsRate = FederalFundsRate.drop('RBS Securities', axis=1)

FederalFundsRate['RBC'] = FederalFundsRate['RBC'].combine_first(FederalFundsRate['RBC Capital Markets'])
FederalFundsRate = FederalFundsRate.drop('RBC Capital Markets', axis=1)

FederalFundsRate['RDQ Economics'] = FederalFundsRate['RDQ Economics'].combine_first(FederalFundsRate['RDQ'])
FederalFundsRate = FederalFundsRate.drop('RDQ', axis=1)

FederalFundsRate['RidgeWorth Investments'] = FederalFundsRate['RidgeWorth Investments'].combine_first(FederalFundsRate['RidgeWorth Capital Management'])
FederalFundsRate = FederalFundsRate.drop('RidgeWorth Capital Management', axis=1)

FederalFundsRate['S&P Global'] = FederalFundsRate['S&P Global'].combine_first(FederalFundsRate['S&P Global Market Intelligence'])
FederalFundsRate['S&P Global'] = FederalFundsRate['S&P Global'].combine_first(FederalFundsRate['S&P Global Ratings'])
FederalFundsRate = FederalFundsRate.drop('S&P Global Market Intelligence', axis=1)
FederalFundsRate = FederalFundsRate.drop('S&P Global Ratings', axis=1)

FederalFundsRate['Scotiabank Group'] = FederalFundsRate['Scotiabank Group'].combine_first(FederalFundsRate['Scotiabank'])
FederalFundsRate['Scotiabank Group'] = FederalFundsRate['Scotiabank Group'].combine_first(FederalFundsRate['Scotia Capital'])
FederalFundsRate = FederalFundsRate.drop('Scotia Capital', axis=1)
FederalFundsRate = FederalFundsRate.drop('Scotiabank', axis=1)

FederalFundsRate['September Consensus'] = FederalFundsRate['September Consensus'].combine_first(FederalFundsRate['Sept. Consensus'])
FederalFundsRate = FederalFundsRate.drop('Sept. Consensus', axis=1)

FederalFundsRate['Standard & Poor\'s'] = FederalFundsRate['Standard & Poor\'s'].combine_first(FederalFundsRate['Standard & Poor\'s Corp.'])
FederalFundsRate['Standard & Poor\'s'] = FederalFundsRate['Standard & Poor\'s'].combine_first(FederalFundsRate['Standard & Poors'])
FederalFundsRate['Standard & Poor\'s'] = FederalFundsRate['Standard & Poor\'s'].combine_first(FederalFundsRate['Standard & Poor’s Corp.'])
FederalFundsRate = FederalFundsRate.drop('Standard & Poor’s Corp.', axis=1)
FederalFundsRate = FederalFundsRate.drop('Standard & Poor\'s Corp.', axis=1)
FederalFundsRate = FederalFundsRate.drop('Standard & Poors', axis=1)

FederalFundsRate['Swiss Re'] = FederalFundsRate['Swiss Re'].combine_first(FederalFundsRate['Sw iss Re'])
FederalFundsRate = FederalFundsRate.drop('Sw iss Re', axis=1)

FederalFundsRate['Thredgold Economics'] = FederalFundsRate['Thredgold Economics'].combine_first(FederalFundsRate['Thredgold Economic Assoc.'])
FederalFundsRate['Thredgold Economics'] = FederalFundsRate['Thredgold Economics'].combine_first(FederalFundsRate['Thredgota Economic Assoc.'])
FederalFundsRate = FederalFundsRate.drop('Thredgold Economic Assoc.', axis=1)
FederalFundsRate = FederalFundsRate.drop('Thredgota Economic Assoc.', axis=1)

FederalFundsRate['Tokai Bank, Ltd.'] = FederalFundsRate['Tokai Bank, Ltd.'].combine_first(FederalFundsRate['Tokai Bank, Lid.'])
FederalFundsRate = FederalFundsRate.drop('Tokai Bank, Lid.', axis=1)

FederalFundsRate['Wayne Hummer & Co.'] = FederalFundsRate['Wayne Hummer & Co.'].combine_first(FederalFundsRate['Wayne Hummer Investments'])
FederalFundsRate = FederalFundsRate.drop('Wayne Hummer Investments', axis=1)

FederalFundsRate['Wachovia'] = FederalFundsRate['Wachovia'].combine_first(FederalFundsRate['Wachovia Securities'])
FederalFundsRate = FederalFundsRate.drop('Wachovia Securities', axis=1)

FederalFundsRate['Wells Fargo'] = FederalFundsRate['Wells Fargo'].combine_first(FederalFundsRate['Wells Capital Management'])
FederalFundsRate = FederalFundsRate.drop('Wells Capital Management', axis=1)

FederalFundsRate['Woodworth Holdings'] = FederalFundsRate['Woodworth Holdings'].combine_first(FederalFundsRate['Woodw orth Holdings'])
FederalFundsRate = FederalFundsRate.drop('Woodw orth Holdings', axis=1)

FederalFundsRate['independent Economic Advisory'] = FederalFundsRate['independent Economic Advisory'].combine_first(FederalFundsRate['independent Econ. Advisory'])
FederalFundsRate = FederalFundsRate.drop('independent Econ. Advisory', axis=1)

FederalFundsRate['MacroFin Analytics'] = FederalFundsRate['MacroFin Analytics'].combine_first(FederalFundsRate['MacroFin Analytics & RBS'])
FederalFundsRate['MacroFin Analytics'] = FederalFundsRate['MacroFin Analytics'].combine_first(FederalFundsRate['MacroFin Analytics & Rutgers Bus School'])
FederalFundsRate['MacroFin Analytics'] = FederalFundsRate['MacroFin Analytics'].combine_first(FederalFundsRate['MacroFin Analytics/Rutgers Bus School'])
FederalFundsRate = FederalFundsRate.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
FederalFundsRate = FederalFundsRate.drop('MacroFin Analytics & RBS', axis=1)
FederalFundsRate = FederalFundsRate.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

FederalFundsRate['Mesirow Financial'] = FederalFundsRate['Mesirow  Financial'].combine_first(FederalFundsRate['Mesirow  Financial'])
FederalFundsRate = FederalFundsRate.drop('Mesirow  Financial', axis=1)

FederalFundsRate['Merrill Lynch'] = FederalFundsRate['Merrill Lynch'].combine_first(FederalFundsRate['Merrill Lynch Economics'])
FederalFundsRate = FederalFundsRate.drop('Merrill Lynch Economics', axis=1)

FederalFundsRate['LaSalle Nat\'I Bank'] = FederalFundsRate['LaSalle Nat\'I Bank'].combine_first(FederalFundsRate['LaSalle Nat\'l Bank'])
FederalFundsRate['LaSalle Nat\'I Bank'] = FederalFundsRate['LaSalle Nat\'I Bank'].combine_first(FederalFundsRate['LaSalle Natl Bank'])
FederalFundsRate = FederalFundsRate.drop('LaSalle Nat\'l Bank', axis=1)
FederalFundsRate = FederalFundsRate.drop('LaSalle Natl Bank', axis=1)

FederalFundsRate['Kellner Economic Advisers'] = FederalFundsRate['Kellner Economic Advisers'].combine_first(FederalFundsRate['Keller Economic Advisers'])
FederalFundsRate = FederalFundsRate.drop('Keller Economic Advisers', axis=1)

FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['J.P. Morgan Chase'])
FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['J.P. Morgan Chase'])
FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['JPMorgan Asset Mgt.'])
FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['JPMorgan Fleming Asset Mgt.'])
FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['JPMorgan Privare Client Services'])
FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['JPMorgan Privare Wealth Mgt.'])
FederalFundsRate['J.P. Morgan'] = FederalFundsRate['J.P. Morgan'].combine_first(FederalFundsRate['JPMorgan Private Banking'])
FederalFundsRate = FederalFundsRate.drop('JPMorgan Private Banking', axis=1)
FederalFundsRate = FederalFundsRate.drop('JPMorgan Privare Wealth Mgt.', axis=1)
FederalFundsRate = FederalFundsRate.drop('JPMorgan Privare Client Services', axis=1)
FederalFundsRate = FederalFundsRate.drop('JPMorgan Fleming Asset Mgt.', axis=1)
FederalFundsRate = FederalFundsRate.drop('JPMorgan Asset Mgt.', axis=1)
FederalFundsRate = FederalFundsRate.drop('J.P. Morgan Chase', axis=1)
FederalFundsRate = FederalFundsRate.drop('J.P. MorganChase', axis=1)

FederalFundsRate['Independent Economic Advisory'] = FederalFundsRate['Independent Economic Advisory'].combine_first(FederalFundsRate['Independent Econ. Advisory'])
FederalFundsRate['Independent Economic Advisory'] = FederalFundsRate['Independent Economic Advisory'].combine_first(FederalFundsRate['Investment Economics Advisory'])
FederalFundsRate = FederalFundsRate.drop('Independent Econ. Advisory', axis=1)
FederalFundsRate = FederalFundsRate.drop('Investment Economics Advisory', axis=1)
                                         
FederalFundsRate['ING'] = FederalFundsRate['ING'].combine_first(FederalFundsRate['ING Investment Mgt.'])
FederalFundsRate = FederalFundsRate.drop('ING Investment Mgt.', axis=1)

FederalFundsRate['Huntington Nat\'I Bank'] = FederalFundsRate['Huntington Nat\'I Bank'].combine_first(FederalFundsRate['Huntington Nat\'l Bank'])
FederalFundsRate['Huntington Nat\'I Bank'] = FederalFundsRate['Huntington Nat\'I Bank'].combine_first(FederalFundsRate['Huntington Natl Bank'])
FederalFundsRate = FederalFundsRate.drop('Huntington Nat\'l Bank', axis=1)
FederalFundsRate = FederalFundsRate.drop('Huntington Natl Bank', axis=1)

FederalFundsRate['Goldman Sachs'] = FederalFundsRate['Goldman Sachs'].combine_first(FederalFundsRate['Goldman Sachs & Co,'])
FederalFundsRate['Goldman Sachs'] = FederalFundsRate['Goldman Sachs'].combine_first(FederalFundsRate['Goldman Sachs & Co.'])
FederalFundsRate = FederalFundsRate.drop('Goldman Sachs & Co,', axis=1)
FederalFundsRate = FederalFundsRate.drop('Goldman Sachs & Co.', axis=1)

FederalFundsRate['Genetski Financial Advisors'] = FederalFundsRate['Genetski Financial Advisors'].combine_first(FederalFundsRate['Genetski.com'])
FederalFundsRate = FederalFundsRate.drop('Genetski.com', axis=1)

FederalFundsRate['Fannie Mae'] = FederalFundsRate['Fannie Mae'].combine_first(FederalFundsRate['Fannie Mae '])
FederalFundsRate = FederalFundsRate.drop('Fannie Mae ', axis=1)

FederalFundsRate['Deutsche Bank Securities'] = FederalFundsRate['Deutsche Bank Securities'].combine_first(FederalFundsRate['Deutsche Bank Securities, Inc.'])
FederalFundsRate['Deutsche Bank Securities'] = FederalFundsRate['Deutsche Bank Securities'].combine_first(FederalFundsRate['Deutsche Bank Securities, inc.'])
FederalFundsRate = FederalFundsRate.drop('Deutsche Bank Securities, Inc.', axis=1)
FederalFundsRate = FederalFundsRate.drop('Deutsche Bank Securities, inc.', axis=1)

FederalFundsRate['DePrince & Associates'] = FederalFundsRate['DePrince & Associates'].combine_first(FederalFundsRate['DePrince & Assoc.'])
FederalFundsRate['DePrince & Associates'] = FederalFundsRate['DePrince & Associates'].combine_first(FederalFundsRate['DePrince Associates'])
FederalFundsRate = FederalFundsRate.drop('DePrince & Assoc.', axis=1)
FederalFundsRate = FederalFundsRate.drop('DePrince Associates', axis=1)

FederalFundsRate['Aeltus Investment'] = FederalFundsRate['Aeltus Investment'].combine_first(FederalFundsRate['Aeitus Investment'])
FederalFundsRate['Aeltus Investment'] = FederalFundsRate['Aeltus Investment'].combine_first(FederalFundsRate['Aeltus investment'])
FederalFundsRate = FederalFundsRate.drop('Aeitus Investment', axis=1)
FederalFundsRate = FederalFundsRate.drop('Aeltus investment', axis=1)

FederalFundsRate['ASB Capital Management'] = FederalFundsRate['ASB Capital Management'].combine_first(FederalFundsRate['ASB Captial Management'])
FederalFundsRate = FederalFundsRate.drop('ASB Captial Management', axis=1)

FederalFundsRate['BMO Nesbitt Burns'] = FederalFundsRate['BMO Nesbitt Burns'].combine_first(FederalFundsRate['BMC Nesbitt Burns'])
FederalFundsRate = FederalFundsRate.drop('BMC Nesbitt Burns', axis=1)

FederalFundsRate['Banc One Invest. Advisors'] = FederalFundsRate['Banc One Invest. Advisors'].combine_first(FederalFundsRate['Banc One invest. Advisors'])
FederalFundsRate = FederalFundsRate.drop('Banc One invest. Advisors', axis=1)

FederalFundsRate['Banc of America Securities'] = FederalFundsRate['Banc of America Securities'].combine_first(FederalFundsRate['Banc of Amercia Securities'])
FederalFundsRate = FederalFundsRate.drop('Banc of Amercia Securities', axis=1)

FederalFundsRate['Banc of America Securities'] = FederalFundsRate['Banc of America Securities'].combine_first(FederalFundsRate['Banc of America Securities, LLC'])
FederalFundsRate = FederalFundsRate.drop('Banc of America Securities, LLC', axis=1)

FederalFundsRate['Bank of America Merrill Lynch'] = FederalFundsRate['Bank of America Merrill Lynch'].combine_first(FederalFundsRate['Bank of America-Merrill Lynch'])
FederalFundsRate = FederalFundsRate.drop('Bank of America-Merrill Lynch', axis=1)
FederalFundsRate['Bank of America Merrill Lynch'] = FederalFundsRate['Banc of America-Merrill Lynch'].combine_first(FederalFundsRate['Banc of America-Merrill Lynch'])
FederalFundsRate = FederalFundsRate.drop('Banc of America-Merrill Lynch', axis=1)

FederalFundsRate['Bank of Toyko-Mitsubishi'] = FederalFundsRate['Bank of Toyko-Mitsubishi'].combine_first(FederalFundsRate['Bank of Toyko-Mitsubishi UFJ'])
FederalFundsRate = FederalFundsRate.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

FederalFundsRate['Barclays'] = FederalFundsRate['Barclays'].combine_first(FederalFundsRate['Barclays Capital'])
FederalFundsRate = FederalFundsRate.drop('Barclays Capital', axis=1)

FederalFundsRate['Bear Stearns'] = FederalFundsRate['Bear Stearns'].combine_first(FederalFundsRate['Bear Stearns & Co.'])
FederalFundsRate = FederalFundsRate.drop('Bear Stearns & Co.', axis=1)
FederalFundsRate['Bear Stearns'] = FederalFundsRate['Bear Stearns'].combine_first(FederalFundsRate['Bear Steams & Co.'])
FederalFundsRate = FederalFundsRate.drop('Bear Steams & Co.', axis=1)

FederalFundsRate['Camilli Economics'] = FederalFundsRate['Camilli Economics'].combine_first(FederalFundsRate['Camilli Economics LLC'])
FederalFundsRate = FederalFundsRate.drop('Camilli Economics LLC', axis=1)
FederalFundsRate['Camilli Economics'] = FederalFundsRate['Camilli Economics'].combine_first(FederalFundsRate['Camilli, Kathleen'])
FederalFundsRate = FederalFundsRate.drop('Camilli, Kathleen', axis=1)

FederalFundsRate['Citibank Global Asset Mgmt'] = FederalFundsRate['Citibank Global Asset Mgmt'].combine_first(FederalFundsRate['Citibank Global Asset Mgmt.'])
FederalFundsRate = FederalFundsRate.drop('Citibank Global Asset Mgmt.', axis=1)
FederalFundsRate['Citibank Global Asset Mgmt'] = FederalFundsRate['Citibank Global Asset Mgmt'].combine_first(FederalFundsRate['Citigroup Asset Management'])
FederalFundsRate = FederalFundsRate.drop('Citigroup Asset Management', axis=1)

FederalFundsRate['ClearView Economics'] = FederalFundsRate['ClearView Economics'].combine_first(FederalFundsRate['ClearView Associates'])
FederalFundsRate = FederalFundsRate.drop('ClearView Associates', axis=1)
FederalFundsRate['ClearView Economics'] = FederalFundsRate['ClearView Economics'].combine_first(FederalFundsRate['ClearView  Economics'])
FederalFundsRate = FederalFundsRate.drop('ClearView  Economics', axis=1)

FederalFundsRate['Comerica Bank'] = FederalFundsRate['Comerica Bank'].combine_first(FederalFundsRate['Commerica'])
FederalFundsRate = FederalFundsRate.drop('Commerica', axis=1)

FederalFundsRate['Cycledata Corp.'] = FederalFundsRate['Cycledata Corp.'].combine_first(FederalFundsRate['Cycledata corp.'])
FederalFundsRate = FederalFundsRate.drop('Cycledata corp.', axis=1)

FederalFundsRate['Daiwa Capital Markets America'] = FederalFundsRate['Daiwa Capital Markets America'].combine_first(FederalFundsRate['Daiw a Capital Markets America'])
FederalFundsRate = FederalFundsRate.drop('Daiw a Capital Markets America', axis=1)
FederalFundsRate['Daiwa Capital Markets America'] = FederalFundsRate['Daiwa Capital Markets America'].combine_first(FederalFundsRate['Daiwa Securities America'])
FederalFundsRate = FederalFundsRate.drop('Daiwa Securities America', axis=1)

# %%
FederalFundsRate.tail()
# Out:
# Unnamed: 0 ACIMA Private Wealth  AIG ASB Capital Management Action Economics  \
# 08/2022                     2.5  2.2                    NaN              2.5
# 09/2022                     2.5  2.2                    NaN              2.3
# 10/2022                     4.0  NaN                    NaN              3.9
# 11/2022                     4.0  3.6                    NaN              3.8
# 12/2022                     4.3  3.8                    NaN              NaN
#
# Unnamed: 0 Aeltus Investment Amherst Pierpont Securities April Consensus  \
# 08/2022                  NaN                         2.2             NaN
# 09/2022                  NaN                         2.2             NaN
# 10/2022                  NaN                         3.7             NaN
# 11/2022                  NaN                         3.7             NaN
# 12/2022                  NaN                         3.7             NaN
#
# ...

# %%
for val in FederalFundsRate.columns:
    print(val)
# Out:
# ACIMA Private Wealth
# AIG
# ASB Capital Management
# Action Economics
# Aeltus Investment
# Amherst Pierpont Securities
# April Consensus
# Argus Research
# August Consensus
# BBVA
# BBVA USA
# BMO Capital Markets
# BMO Nesbitt Burns
# BNP Paribas Americas
# Banc One Invest. Advisors
# Banc of America Securities
# Bank One
# Bank of America
# Bank of America Merrill Lynch
# Bank of Toyko-Mitsubishi
# Bank of the West
# Barclays
# Bardays Capital
# Bear Stearns
# Bottom 10 Avg.
# Briefing.com
# CAM North America, LLC
# Camilli Economics
# Chan Economics
# Chase Wealth Management
# Chicago Capital
# Chmura Economics & Analytics
# Citibank Global Asset Mgmt
# Classicalprinciples.com
# ClearView Economics
# Comerica Bank
# Conning & Company
# Credit Swisse Asset Mgt.
# Crestar Asset Management
# Cycledata Corp.
# DS Economics
# Daiwa Capital Markets America
# DePrince & Associates
# December Consensus
# Deutsche Banc Alex. Brown
# Deutsche Bank Global Equities
# ...

# %%
# Объединение столбцов
PrimeBankRate['Moody\'s Analytics'] = PrimeBankRate['Moody\'s Analytics'].combine_first(PrimeBankRate['Moody\'s Capital Markets'])
PrimeBankRate['Moody\'s Analytics'] = PrimeBankRate['Moody\'s Analytics'].combine_first(PrimeBankRate['Moody\'s Capital Markets Group'])
PrimeBankRate['Moody\'s Analytics'] = PrimeBankRate['Moody\'s Analytics'].combine_first(PrimeBankRate['Moody\'s Econmy.com'])
PrimeBankRate['Moody\'s Analytics'] = PrimeBankRate['Moody\'s Analytics'].combine_first(PrimeBankRate['Moody\'s Economy.com'])
PrimeBankRate['Moody\'s Analytics'] = PrimeBankRate['Moody\'s Analytics'].combine_first(PrimeBankRate['Moody\'s Investors Service'])
PrimeBankRate['Moody\'s Analytics'] = PrimeBankRate['Moody\'s Analytics'].combine_first(PrimeBankRate['Moodys Investors Service'])
PrimeBankRate = PrimeBankRate.drop('Moody\'s Capital Markets', axis=1)
PrimeBankRate = PrimeBankRate.drop('Moody\'s Capital Markets Group', axis=1)
PrimeBankRate = PrimeBankRate.drop('Moody\'s Econmy.com', axis=1)
PrimeBankRate = PrimeBankRate.drop('Moody\'s Economy.com', axis=1)
PrimeBankRate = PrimeBankRate.drop('Moody\'s Investors Service', axis=1)
PrimeBankRate = PrimeBankRate.drop('Moodys Investors Service', axis=1)

PrimeBankRate['Nat\'l Assn. of Realtors'] = PrimeBankRate['Nat\'l Assn. of Realtors'].combine_first(PrimeBankRate['Nat\'l Assn, of Realtors'])
PrimeBankRate['Nat\'l Assn. of Realtors'] = PrimeBankRate['Nat\'l Assn. of Realtors'].combine_first(PrimeBankRate['Nat\'I Assn, of Realtors'])
PrimeBankRate = PrimeBankRate.drop('Nat\'l Assn, of Realtors', axis=1)
PrimeBankRate = PrimeBankRate.drop('Nat\'I Assn, of Realtors', axis=1)

PrimeBankRate['National City Bank'] = PrimeBankRate['National City Bank'].combine_first(PrimeBankRate['National City Corporation'])
PrimeBankRate = PrimeBankRate.drop('National City Corporation', axis=1)

PrimeBankRate['Nomura Securities Inc.'] = PrimeBankRate['Nomura Securities Inc.'].combine_first(PrimeBankRate['Nomura Securities, Inc.'])
PrimeBankRate = PrimeBankRate.drop('Nomura Securities, Inc.', axis=1)

PrimeBankRate['October Consensus'] = PrimeBankRate['October Consensus'].combine_first(PrimeBankRate['Octoberber Consensus'])
PrimeBankRate = PrimeBankRate.drop('Octoberber Consensus', axis=1)

PrimeBankRate['PNC Bank Corp.'] = PrimeBankRate['PNC Bank Corp.'].combine_first(PrimeBankRate['PNC Financial Services'])
PrimeBankRate['PNC Bank Corp.'] = PrimeBankRate['PNC Bank Corp.'].combine_first(PrimeBankRate['PNC Financial Services Corp.'])
PrimeBankRate['PNC Bank Corp.'] = PrimeBankRate['PNC Bank Corp.'].combine_first(PrimeBankRate['PNC Financial Services Group'])
PrimeBankRate = PrimeBankRate.drop('PNC Financial Services', axis=1)
PrimeBankRate = PrimeBankRate.drop('PNC Financial Services Corp.', axis=1)
PrimeBankRate = PrimeBankRate.drop('PNC Financial Services Group', axis=1)

PrimeBankRate['Prudential Securities'] = PrimeBankRate['Prudential Securities'].combine_first(PrimeBankRate['Prudential Equity Group LLC'])
PrimeBankRate['Prudential Securities'] = PrimeBankRate['Prudential Securities'].combine_first(PrimeBankRate['Prudential Insurance Co.'])
PrimeBankRate['Prudential Securities'] = PrimeBankRate['Prudential Securities'].combine_first(PrimeBankRate['Prudential Financial'])
PrimeBankRate = PrimeBankRate.drop('Prudential Financial', axis=1)
PrimeBankRate = PrimeBankRate.drop('Prudential Insurance Co.', axis=1)
PrimeBankRate = PrimeBankRate.drop('Prudential Equity Group LLC', axis=1)

PrimeBankRate['RBS Greenwich Capital Econ.'] = PrimeBankRate['RBS Greenwich Capital Econ.'].combine_first(PrimeBankRate['RBS Securities'])
PrimeBankRate = PrimeBankRate.drop('RBS Securities', axis=1)

PrimeBankRate['RBC'] = PrimeBankRate['RBC'].combine_first(PrimeBankRate['RBC Capital Markets'])
PrimeBankRate = PrimeBankRate.drop('RBC Capital Markets', axis=1)

PrimeBankRate['RDQ Economics'] = PrimeBankRate['RDQ Economics'].combine_first(PrimeBankRate['RDQ'])
PrimeBankRate = PrimeBankRate.drop('RDQ', axis=1)

PrimeBankRate['RidgeWorth Investments'] = PrimeBankRate['RidgeWorth Investments'].combine_first(PrimeBankRate['RidgeWorth Capital Management'])
PrimeBankRate = PrimeBankRate.drop('RidgeWorth Capital Management', axis=1)

PrimeBankRate['S&P Global'] = PrimeBankRate['S&P Global'].combine_first(PrimeBankRate['S&P Global Market Intelligence'])
PrimeBankRate['S&P Global'] = PrimeBankRate['S&P Global'].combine_first(PrimeBankRate['S&P Global Ratings'])
PrimeBankRate = PrimeBankRate.drop('S&P Global Market Intelligence', axis=1)
PrimeBankRate = PrimeBankRate.drop('S&P Global Ratings', axis=1)

PrimeBankRate['Scotiabank Group'] = PrimeBankRate['Scotiabank Group'].combine_first(PrimeBankRate['Scotiabank'])
PrimeBankRate['Scotiabank Group'] = PrimeBankRate['Scotiabank Group'].combine_first(PrimeBankRate['Scotia Capital'])
PrimeBankRate = PrimeBankRate.drop('Scotia Capital', axis=1)
PrimeBankRate = PrimeBankRate.drop('Scotiabank', axis=1)

PrimeBankRate['September Consensus'] = PrimeBankRate['September Consensus'].combine_first(PrimeBankRate['Sept. Consensus'])
PrimeBankRate = PrimeBankRate.drop('Sept. Consensus', axis=1)

PrimeBankRate['Standard & Poor\'s'] = PrimeBankRate['Standard & Poor\'s'].combine_first(PrimeBankRate['Standard & Poor\'s Corp.'])
PrimeBankRate['Standard & Poor\'s'] = PrimeBankRate['Standard & Poor\'s'].combine_first(PrimeBankRate['Standard & Poors'])
PrimeBankRate['Standard & Poor\'s'] = PrimeBankRate['Standard & Poor\'s'].combine_first(PrimeBankRate['Standard & Poor’s Corp.'])
PrimeBankRate = PrimeBankRate.drop('Standard & Poor’s Corp.', axis=1)
PrimeBankRate = PrimeBankRate.drop('Standard & Poor\'s Corp.', axis=1)
PrimeBankRate = PrimeBankRate.drop('Standard & Poors', axis=1)

PrimeBankRate['Swiss Re'] = PrimeBankRate['Swiss Re'].combine_first(PrimeBankRate['Sw iss Re'])
PrimeBankRate = PrimeBankRate.drop('Sw iss Re', axis=1)

PrimeBankRate['Thredgold Economics'] = PrimeBankRate['Thredgold Economics'].combine_first(PrimeBankRate['Thredgold Economic Assoc.'])
PrimeBankRate['Thredgold Economics'] = PrimeBankRate['Thredgold Economics'].combine_first(PrimeBankRate['Thredgota Economic Assoc.'])
PrimeBankRate = PrimeBankRate.drop('Thredgold Economic Assoc.', axis=1)
PrimeBankRate = PrimeBankRate.drop('Thredgota Economic Assoc.', axis=1)

PrimeBankRate['Tokai Bank, Ltd.'] = PrimeBankRate['Tokai Bank, Ltd.'].combine_first(PrimeBankRate['Tokai Bank, Lid.'])
PrimeBankRate = PrimeBankRate.drop('Tokai Bank, Lid.', axis=1)

PrimeBankRate['Wayne Hummer & Co.'] = PrimeBankRate['Wayne Hummer & Co.'].combine_first(PrimeBankRate['Wayne Hummer Investments'])
PrimeBankRate = PrimeBankRate.drop('Wayne Hummer Investments', axis=1)

PrimeBankRate['Wachovia'] = PrimeBankRate['Wachovia'].combine_first(PrimeBankRate['Wachovia Securities'])
PrimeBankRate = PrimeBankRate.drop('Wachovia Securities', axis=1)

PrimeBankRate['Wells Fargo'] = PrimeBankRate['Wells Fargo'].combine_first(PrimeBankRate['Wells Capital Management'])
PrimeBankRate = PrimeBankRate.drop('Wells Capital Management', axis=1)

PrimeBankRate['Woodworth Holdings'] = PrimeBankRate['Woodworth Holdings'].combine_first(PrimeBankRate['Woodw orth Holdings'])
PrimeBankRate = PrimeBankRate.drop('Woodw orth Holdings', axis=1)

PrimeBankRate['independent Economic Advisory'] = PrimeBankRate['independent Economic Advisory'].combine_first(PrimeBankRate['independent Econ. Advisory'])
PrimeBankRate = PrimeBankRate.drop('independent Econ. Advisory', axis=1)

PrimeBankRate['MacroFin Analytics'] = PrimeBankRate['MacroFin Analytics'].combine_first(PrimeBankRate['MacroFin Analytics & RBS'])
PrimeBankRate['MacroFin Analytics'] = PrimeBankRate['MacroFin Analytics'].combine_first(PrimeBankRate['MacroFin Analytics & Rutgers Bus School'])
PrimeBankRate['MacroFin Analytics'] = PrimeBankRate['MacroFin Analytics'].combine_first(PrimeBankRate['MacroFin Analytics/Rutgers Bus School'])
PrimeBankRate = PrimeBankRate.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
PrimeBankRate = PrimeBankRate.drop('MacroFin Analytics & RBS', axis=1)
PrimeBankRate = PrimeBankRate.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

PrimeBankRate['Mesirow Financial'] = PrimeBankRate['Mesirow  Financial'].combine_first(PrimeBankRate['Mesirow  Financial'])
PrimeBankRate = PrimeBankRate.drop('Mesirow  Financial', axis=1)

PrimeBankRate['Merrill Lynch'] = PrimeBankRate['Merrill Lynch'].combine_first(PrimeBankRate['Merrill Lynch Economics'])
PrimeBankRate = PrimeBankRate.drop('Merrill Lynch Economics', axis=1)

PrimeBankRate['LaSalle Nat\'I Bank'] = PrimeBankRate['LaSalle Nat\'I Bank'].combine_first(PrimeBankRate['LaSalle Nat\'l Bank'])
PrimeBankRate['LaSalle Nat\'I Bank'] = PrimeBankRate['LaSalle Nat\'I Bank'].combine_first(PrimeBankRate['LaSalle Natl Bank'])
PrimeBankRate = PrimeBankRate.drop('LaSalle Nat\'l Bank', axis=1)
PrimeBankRate = PrimeBankRate.drop('LaSalle Natl Bank', axis=1)

PrimeBankRate['Kellner Economic Advisers'] = PrimeBankRate['Kellner Economic Advisers'].combine_first(PrimeBankRate['Keller Economic Advisers'])
PrimeBankRate = PrimeBankRate.drop('Keller Economic Advisers', axis=1)

PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['J.P. Morgan Chase'])
PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['J.P. Morgan Chase'])
PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['JPMorgan Asset Mgt.'])
PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['JPMorgan Fleming Asset Mgt.'])
PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['JPMorgan Privare Client Services'])
PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['JPMorgan Privare Wealth Mgt.'])
PrimeBankRate['J.P. Morgan'] = PrimeBankRate['J.P. Morgan'].combine_first(PrimeBankRate['JPMorgan Private Banking'])
PrimeBankRate = PrimeBankRate.drop('JPMorgan Private Banking', axis=1)
PrimeBankRate = PrimeBankRate.drop('JPMorgan Privare Wealth Mgt.', axis=1)
PrimeBankRate = PrimeBankRate.drop('JPMorgan Privare Client Services', axis=1)
PrimeBankRate = PrimeBankRate.drop('JPMorgan Fleming Asset Mgt.', axis=1)
PrimeBankRate = PrimeBankRate.drop('JPMorgan Asset Mgt.', axis=1)
PrimeBankRate = PrimeBankRate.drop('J.P. Morgan Chase', axis=1)
PrimeBankRate = PrimeBankRate.drop('J.P. MorganChase', axis=1)

PrimeBankRate['Independent Economic Advisory'] = PrimeBankRate['Independent Economic Advisory'].combine_first(PrimeBankRate['Independent Econ. Advisory'])
PrimeBankRate['Independent Economic Advisory'] = PrimeBankRate['Independent Economic Advisory'].combine_first(PrimeBankRate['Investment Economics Advisory'])
PrimeBankRate = PrimeBankRate.drop('Independent Econ. Advisory', axis=1)
PrimeBankRate = PrimeBankRate.drop('Investment Economics Advisory', axis=1)
                                         
PrimeBankRate['ING'] = PrimeBankRate['ING'].combine_first(PrimeBankRate['ING Investment Mgt.'])
PrimeBankRate = PrimeBankRate.drop('ING Investment Mgt.', axis=1)

PrimeBankRate['Huntington Nat\'I Bank'] = PrimeBankRate['Huntington Nat\'I Bank'].combine_first(PrimeBankRate['Huntington Nat\'l Bank'])
PrimeBankRate['Huntington Nat\'I Bank'] = PrimeBankRate['Huntington Nat\'I Bank'].combine_first(PrimeBankRate['Huntington Natl Bank'])
PrimeBankRate = PrimeBankRate.drop('Huntington Nat\'l Bank', axis=1)
PrimeBankRate = PrimeBankRate.drop('Huntington Natl Bank', axis=1)

PrimeBankRate['Goldman Sachs'] = PrimeBankRate['Goldman Sachs'].combine_first(PrimeBankRate['Goldman Sachs & Co,'])
PrimeBankRate['Goldman Sachs'] = PrimeBankRate['Goldman Sachs'].combine_first(PrimeBankRate['Goldman Sachs & Co.'])
PrimeBankRate = PrimeBankRate.drop('Goldman Sachs & Co,', axis=1)
PrimeBankRate = PrimeBankRate.drop('Goldman Sachs & Co.', axis=1)

PrimeBankRate['Genetski Financial Advisors'] = PrimeBankRate['Genetski Financial Advisors'].combine_first(PrimeBankRate['Genetski.com'])
PrimeBankRate = PrimeBankRate.drop('Genetski.com', axis=1)

PrimeBankRate['Fannie Mae'] = PrimeBankRate['Fannie Mae'].combine_first(PrimeBankRate['Fannie Mae '])
PrimeBankRate = PrimeBankRate.drop('Fannie Mae ', axis=1)

PrimeBankRate['Deutsche Bank Securities'] = PrimeBankRate['Deutsche Bank Securities'].combine_first(PrimeBankRate['Deutsche Bank Securities, Inc.'])
PrimeBankRate['Deutsche Bank Securities'] = PrimeBankRate['Deutsche Bank Securities'].combine_first(PrimeBankRate['Deutsche Bank Securities, inc.'])
PrimeBankRate = PrimeBankRate.drop('Deutsche Bank Securities, Inc.', axis=1)
PrimeBankRate = PrimeBankRate.drop('Deutsche Bank Securities, inc.', axis=1)

PrimeBankRate['DePrince & Associates'] = PrimeBankRate['DePrince & Associates'].combine_first(PrimeBankRate['DePrince & Assoc.'])
PrimeBankRate['DePrince & Associates'] = PrimeBankRate['DePrince & Associates'].combine_first(PrimeBankRate['DePrince Associates'])
PrimeBankRate = PrimeBankRate.drop('DePrince & Assoc.', axis=1)
PrimeBankRate = PrimeBankRate.drop('DePrince Associates', axis=1)

PrimeBankRate['Aeltus Investment'] = PrimeBankRate['Aeltus Investment'].combine_first(PrimeBankRate['Aeitus Investment'])
PrimeBankRate['Aeltus Investment'] = PrimeBankRate['Aeltus Investment'].combine_first(PrimeBankRate['Aeltus investment'])
PrimeBankRate = PrimeBankRate.drop('Aeitus Investment', axis=1)
PrimeBankRate = PrimeBankRate.drop('Aeltus investment', axis=1)

PrimeBankRate['ASB Capital Management'] = PrimeBankRate['ASB Capital Management'].combine_first(PrimeBankRate['ASB Captial Management'])
PrimeBankRate = PrimeBankRate.drop('ASB Captial Management', axis=1)

PrimeBankRate['BMO Nesbitt Burns'] = PrimeBankRate['BMO Nesbitt Burns'].combine_first(PrimeBankRate['BMC Nesbitt Burns'])
PrimeBankRate = PrimeBankRate.drop('BMC Nesbitt Burns', axis=1)

PrimeBankRate['Banc One Invest. Advisors'] = PrimeBankRate['Banc One Invest. Advisors'].combine_first(PrimeBankRate['Banc One invest. Advisors'])
PrimeBankRate = PrimeBankRate.drop('Banc One invest. Advisors', axis=1)

PrimeBankRate['Banc of America Securities'] = PrimeBankRate['Banc of America Securities'].combine_first(PrimeBankRate['Banc of Amercia Securities'])
PrimeBankRate = PrimeBankRate.drop('Banc of Amercia Securities', axis=1)

PrimeBankRate['Banc of America Securities'] = PrimeBankRate['Banc of America Securities'].combine_first(PrimeBankRate['Banc of America Securities, LLC'])
PrimeBankRate = PrimeBankRate.drop('Banc of America Securities, LLC', axis=1)

PrimeBankRate['Bank of America Merrill Lynch'] = PrimeBankRate['Bank of America Merrill Lynch'].combine_first(PrimeBankRate['Bank of America-Merrill Lynch'])
PrimeBankRate = PrimeBankRate.drop('Bank of America-Merrill Lynch', axis=1)
PrimeBankRate['Bank of America Merrill Lynch'] = PrimeBankRate['Banc of America-Merrill Lynch'].combine_first(PrimeBankRate['Banc of America-Merrill Lynch'])
PrimeBankRate = PrimeBankRate.drop('Banc of America-Merrill Lynch', axis=1)

PrimeBankRate['Bank of Toyko-Mitsubishi'] = PrimeBankRate['Bank of Toyko-Mitsubishi'].combine_first(PrimeBankRate['Bank of Toyko-Mitsubishi UFJ'])
PrimeBankRate = PrimeBankRate.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

PrimeBankRate['Barclays'] = PrimeBankRate['Barclays'].combine_first(PrimeBankRate['Barclays Capital'])
PrimeBankRate = PrimeBankRate.drop('Barclays Capital', axis=1)

PrimeBankRate['Bear Stearns'] = PrimeBankRate['Bear Stearns'].combine_first(PrimeBankRate['Bear Stearns & Co.'])
PrimeBankRate = PrimeBankRate.drop('Bear Stearns & Co.', axis=1)
PrimeBankRate['Bear Stearns'] = PrimeBankRate['Bear Stearns'].combine_first(PrimeBankRate['Bear Steams & Co.'])
PrimeBankRate = PrimeBankRate.drop('Bear Steams & Co.', axis=1)

PrimeBankRate['Camilli Economics'] = PrimeBankRate['Camilli Economics'].combine_first(PrimeBankRate['Camilli Economics LLC'])
PrimeBankRate = PrimeBankRate.drop('Camilli Economics LLC', axis=1)
PrimeBankRate['Camilli Economics'] = PrimeBankRate['Camilli Economics'].combine_first(PrimeBankRate['Camilli, Kathleen'])
PrimeBankRate = PrimeBankRate.drop('Camilli, Kathleen', axis=1)

PrimeBankRate['Citibank Global Asset Mgmt'] = PrimeBankRate['Citibank Global Asset Mgmt'].combine_first(PrimeBankRate['Citibank Global Asset Mgmt.'])
PrimeBankRate = PrimeBankRate.drop('Citibank Global Asset Mgmt.', axis=1)
PrimeBankRate['Citibank Global Asset Mgmt'] = PrimeBankRate['Citibank Global Asset Mgmt'].combine_first(PrimeBankRate['Citigroup Asset Management'])
PrimeBankRate = PrimeBankRate.drop('Citigroup Asset Management', axis=1)

PrimeBankRate['ClearView Economics'] = PrimeBankRate['ClearView Economics'].combine_first(PrimeBankRate['ClearView Associates'])
PrimeBankRate = PrimeBankRate.drop('ClearView Associates', axis=1)
PrimeBankRate['ClearView Economics'] = PrimeBankRate['ClearView Economics'].combine_first(PrimeBankRate['ClearView  Economics'])
PrimeBankRate = PrimeBankRate.drop('ClearView  Economics', axis=1)

PrimeBankRate['Comerica Bank'] = PrimeBankRate['Comerica Bank'].combine_first(PrimeBankRate['Commerica'])
PrimeBankRate = PrimeBankRate.drop('Commerica', axis=1)

PrimeBankRate['Cycledata Corp.'] = PrimeBankRate['Cycledata Corp.'].combine_first(PrimeBankRate['Cycledata corp.'])
PrimeBankRate = PrimeBankRate.drop('Cycledata corp.', axis=1)

PrimeBankRate['Daiwa Capital Markets America'] = PrimeBankRate['Daiwa Capital Markets America'].combine_first(PrimeBankRate['Daiw a Capital Markets America'])
PrimeBankRate = PrimeBankRate.drop('Daiw a Capital Markets America', axis=1)
PrimeBankRate['Daiwa Capital Markets America'] = PrimeBankRate['Daiwa Capital Markets America'].combine_first(PrimeBankRate['Daiwa Securities America'])
PrimeBankRate = PrimeBankRate.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
LIBOR_Rate_3_Mo['Moody\'s Analytics'] = LIBOR_Rate_3_Mo['Moody\'s Analytics'].combine_first(LIBOR_Rate_3_Mo['Moody\'s Capital Markets'])
LIBOR_Rate_3_Mo['Moody\'s Analytics'] = LIBOR_Rate_3_Mo['Moody\'s Analytics'].combine_first(LIBOR_Rate_3_Mo['Moody\'s Capital Markets Group'])
LIBOR_Rate_3_Mo['Moody\'s Analytics'] = LIBOR_Rate_3_Mo['Moody\'s Analytics'].combine_first(LIBOR_Rate_3_Mo['Moody\'s Econmy.com'])
LIBOR_Rate_3_Mo['Moody\'s Analytics'] = LIBOR_Rate_3_Mo['Moody\'s Analytics'].combine_first(LIBOR_Rate_3_Mo['Moody\'s Economy.com'])
LIBOR_Rate_3_Mo['Moody\'s Analytics'] = LIBOR_Rate_3_Mo['Moody\'s Analytics'].combine_first(LIBOR_Rate_3_Mo['Moody\'s Investors Service'])
LIBOR_Rate_3_Mo['Moody\'s Analytics'] = LIBOR_Rate_3_Mo['Moody\'s Analytics'].combine_first(LIBOR_Rate_3_Mo['Moodys Investors Service'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Moody\'s Capital Markets', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Moody\'s Capital Markets Group', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Moody\'s Econmy.com', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Moody\'s Economy.com', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Moody\'s Investors Service', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Moodys Investors Service', axis=1)

LIBOR_Rate_3_Mo['Nat\'l Assn. of Realtors'] = LIBOR_Rate_3_Mo['Nat\'l Assn. of Realtors'].combine_first(LIBOR_Rate_3_Mo['Nat\'l Assn, of Realtors'])
LIBOR_Rate_3_Mo['Nat\'l Assn. of Realtors'] = LIBOR_Rate_3_Mo['Nat\'l Assn. of Realtors'].combine_first(LIBOR_Rate_3_Mo['Nat\'I Assn, of Realtors'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Nat\'l Assn, of Realtors', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Nat\'I Assn, of Realtors', axis=1)

LIBOR_Rate_3_Mo['National City Bank'] = LIBOR_Rate_3_Mo['National City Bank'].combine_first(LIBOR_Rate_3_Mo['National City Corporation'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('National City Corporation', axis=1)

LIBOR_Rate_3_Mo['Nomura Securities Inc.'] = LIBOR_Rate_3_Mo['Nomura Securities Inc.'].combine_first(LIBOR_Rate_3_Mo['Nomura Securities, Inc.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Nomura Securities, Inc.', axis=1)

LIBOR_Rate_3_Mo['October Consensus'] = LIBOR_Rate_3_Mo['October Consensus'].combine_first(LIBOR_Rate_3_Mo['Octoberber Consensus'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Octoberber Consensus', axis=1)

LIBOR_Rate_3_Mo['PNC Bank Corp.'] = LIBOR_Rate_3_Mo['PNC Bank Corp.'].combine_first(LIBOR_Rate_3_Mo['PNC Financial Services'])
LIBOR_Rate_3_Mo['PNC Bank Corp.'] = LIBOR_Rate_3_Mo['PNC Bank Corp.'].combine_first(LIBOR_Rate_3_Mo['PNC Financial Services Corp.'])
LIBOR_Rate_3_Mo['PNC Bank Corp.'] = LIBOR_Rate_3_Mo['PNC Bank Corp.'].combine_first(LIBOR_Rate_3_Mo['PNC Financial Services Group'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('PNC Financial Services', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('PNC Financial Services Corp.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('PNC Financial Services Group', axis=1)

LIBOR_Rate_3_Mo['Prudential Securities'] = LIBOR_Rate_3_Mo['Prudential Securities'].combine_first(LIBOR_Rate_3_Mo['Prudential Equity Group LLC'])
LIBOR_Rate_3_Mo['Prudential Securities'] = LIBOR_Rate_3_Mo['Prudential Securities'].combine_first(LIBOR_Rate_3_Mo['Prudential Insurance Co.'])
LIBOR_Rate_3_Mo['Prudential Securities'] = LIBOR_Rate_3_Mo['Prudential Securities'].combine_first(LIBOR_Rate_3_Mo['Prudential Financial'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Prudential Financial', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Prudential Insurance Co.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Prudential Equity Group LLC', axis=1)

LIBOR_Rate_3_Mo['RBS Greenwich Capital Econ.'] = LIBOR_Rate_3_Mo['RBS Greenwich Capital Econ.'].combine_first(LIBOR_Rate_3_Mo['RBS Securities'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('RBS Securities', axis=1)

LIBOR_Rate_3_Mo['RBC'] = LIBOR_Rate_3_Mo['RBC'].combine_first(LIBOR_Rate_3_Mo['RBC Capital Markets'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('RBC Capital Markets', axis=1)

LIBOR_Rate_3_Mo['RDQ Economics'] = LIBOR_Rate_3_Mo['RDQ Economics'].combine_first(LIBOR_Rate_3_Mo['RDQ'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('RDQ', axis=1)

LIBOR_Rate_3_Mo['RidgeWorth Investments'] = LIBOR_Rate_3_Mo['RidgeWorth Investments'].combine_first(LIBOR_Rate_3_Mo['RidgeWorth Capital Management'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('RidgeWorth Capital Management', axis=1)

LIBOR_Rate_3_Mo['S&P Global'] = LIBOR_Rate_3_Mo['S&P Global'].combine_first(LIBOR_Rate_3_Mo['S&P Global Market Intelligence'])
LIBOR_Rate_3_Mo['S&P Global'] = LIBOR_Rate_3_Mo['S&P Global'].combine_first(LIBOR_Rate_3_Mo['S&P Global Ratings'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('S&P Global Market Intelligence', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('S&P Global Ratings', axis=1)

LIBOR_Rate_3_Mo['Scotiabank Group'] = LIBOR_Rate_3_Mo['Scotiabank Group'].combine_first(LIBOR_Rate_3_Mo['Scotiabank'])
LIBOR_Rate_3_Mo['Scotiabank Group'] = LIBOR_Rate_3_Mo['Scotiabank Group'].combine_first(LIBOR_Rate_3_Mo['Scotia Capital'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Scotia Capital', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Scotiabank', axis=1)

LIBOR_Rate_3_Mo['September Consensus'] = LIBOR_Rate_3_Mo['September Consensus'].combine_first(LIBOR_Rate_3_Mo['Sept. Consensus'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Sept. Consensus', axis=1)

LIBOR_Rate_3_Mo['Standard & Poor\'s'] = LIBOR_Rate_3_Mo['Standard & Poor\'s'].combine_first(LIBOR_Rate_3_Mo['Standard & Poor\'s Corp.'])
LIBOR_Rate_3_Mo['Standard & Poor\'s'] = LIBOR_Rate_3_Mo['Standard & Poor\'s'].combine_first(LIBOR_Rate_3_Mo['Standard & Poors'])
LIBOR_Rate_3_Mo['Standard & Poor\'s'] = LIBOR_Rate_3_Mo['Standard & Poor\'s'].combine_first(LIBOR_Rate_3_Mo['Standard & Poor’s Corp.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Standard & Poor’s Corp.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Standard & Poor\'s Corp.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Standard & Poors', axis=1)

LIBOR_Rate_3_Mo['Swiss Re'] = LIBOR_Rate_3_Mo['Swiss Re'].combine_first(LIBOR_Rate_3_Mo['Sw iss Re'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Sw iss Re', axis=1)

LIBOR_Rate_3_Mo['Thredgold Economics'] = LIBOR_Rate_3_Mo['Thredgold Economics'].combine_first(LIBOR_Rate_3_Mo['Thredgold Economic Assoc.'])
LIBOR_Rate_3_Mo['Thredgold Economics'] = LIBOR_Rate_3_Mo['Thredgold Economics'].combine_first(LIBOR_Rate_3_Mo['Thredgota Economic Assoc.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Thredgold Economic Assoc.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Thredgota Economic Assoc.', axis=1)

LIBOR_Rate_3_Mo['Tokai Bank, Ltd.'] = LIBOR_Rate_3_Mo['Tokai Bank, Ltd.'].combine_first(LIBOR_Rate_3_Mo['Tokai Bank, Lid.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Tokai Bank, Lid.', axis=1)

LIBOR_Rate_3_Mo['Wayne Hummer & Co.'] = LIBOR_Rate_3_Mo['Wayne Hummer & Co.'].combine_first(LIBOR_Rate_3_Mo['Wayne Hummer Investments'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Wayne Hummer Investments', axis=1)

LIBOR_Rate_3_Mo['Wachovia'] = LIBOR_Rate_3_Mo['Wachovia'].combine_first(LIBOR_Rate_3_Mo['Wachovia Securities'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Wachovia Securities', axis=1)

LIBOR_Rate_3_Mo['Wells Fargo'] = LIBOR_Rate_3_Mo['Wells Fargo'].combine_first(LIBOR_Rate_3_Mo['Wells Capital Management'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Wells Capital Management', axis=1)

LIBOR_Rate_3_Mo['Woodworth Holdings'] = LIBOR_Rate_3_Mo['Woodworth Holdings'].combine_first(LIBOR_Rate_3_Mo['Woodw orth Holdings'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Woodw orth Holdings', axis=1)

LIBOR_Rate_3_Mo['independent Economic Advisory'] = LIBOR_Rate_3_Mo['independent Economic Advisory'].combine_first(LIBOR_Rate_3_Mo['independent Econ. Advisory'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('independent Econ. Advisory', axis=1)

LIBOR_Rate_3_Mo['MacroFin Analytics'] = LIBOR_Rate_3_Mo['MacroFin Analytics'].combine_first(LIBOR_Rate_3_Mo['MacroFin Analytics & RBS'])
LIBOR_Rate_3_Mo['MacroFin Analytics'] = LIBOR_Rate_3_Mo['MacroFin Analytics'].combine_first(LIBOR_Rate_3_Mo['MacroFin Analytics & Rutgers Bus School'])
LIBOR_Rate_3_Mo['MacroFin Analytics'] = LIBOR_Rate_3_Mo['MacroFin Analytics'].combine_first(LIBOR_Rate_3_Mo['MacroFin Analytics/Rutgers Bus School'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('MacroFin Analytics & RBS', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

LIBOR_Rate_3_Mo['Mesirow Financial'] = LIBOR_Rate_3_Mo['Mesirow  Financial'].combine_first(LIBOR_Rate_3_Mo['Mesirow  Financial'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Mesirow  Financial', axis=1)

LIBOR_Rate_3_Mo['Merrill Lynch'] = LIBOR_Rate_3_Mo['Merrill Lynch'].combine_first(LIBOR_Rate_3_Mo['Merrill Lynch Economics'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Merrill Lynch Economics', axis=1)

LIBOR_Rate_3_Mo['LaSalle Nat\'I Bank'] = LIBOR_Rate_3_Mo['LaSalle Nat\'I Bank'].combine_first(LIBOR_Rate_3_Mo['LaSalle Nat\'l Bank'])
LIBOR_Rate_3_Mo['LaSalle Nat\'I Bank'] = LIBOR_Rate_3_Mo['LaSalle Nat\'I Bank'].combine_first(LIBOR_Rate_3_Mo['LaSalle Natl Bank'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('LaSalle Nat\'l Bank', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('LaSalle Natl Bank', axis=1)

LIBOR_Rate_3_Mo['Kellner Economic Advisers'] = LIBOR_Rate_3_Mo['Kellner Economic Advisers'].combine_first(LIBOR_Rate_3_Mo['Keller Economic Advisers'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Keller Economic Advisers', axis=1)

LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['J.P. Morgan Chase'])
LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['J.P. Morgan Chase'])
LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['JPMorgan Asset Mgt.'])
LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['JPMorgan Fleming Asset Mgt.'])
LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['JPMorgan Privare Client Services'])
LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['JPMorgan Privare Wealth Mgt.'])
LIBOR_Rate_3_Mo['J.P. Morgan'] = LIBOR_Rate_3_Mo['J.P. Morgan'].combine_first(LIBOR_Rate_3_Mo['JPMorgan Private Banking'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('JPMorgan Private Banking', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('JPMorgan Privare Wealth Mgt.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('JPMorgan Privare Client Services', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('JPMorgan Fleming Asset Mgt.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('JPMorgan Asset Mgt.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('J.P. Morgan Chase', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('J.P. MorganChase', axis=1)

LIBOR_Rate_3_Mo['Independent Economic Advisory'] = LIBOR_Rate_3_Mo['Independent Economic Advisory'].combine_first(LIBOR_Rate_3_Mo['Independent Econ. Advisory'])
LIBOR_Rate_3_Mo['Independent Economic Advisory'] = LIBOR_Rate_3_Mo['Independent Economic Advisory'].combine_first(LIBOR_Rate_3_Mo['Investment Economics Advisory'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Independent Econ. Advisory', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Investment Economics Advisory', axis=1)
                                         
LIBOR_Rate_3_Mo['ING'] = LIBOR_Rate_3_Mo['ING'].combine_first(LIBOR_Rate_3_Mo['ING Investment Mgt.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('ING Investment Mgt.', axis=1)

LIBOR_Rate_3_Mo['Huntington Nat\'I Bank'] = LIBOR_Rate_3_Mo['Huntington Nat\'I Bank'].combine_first(LIBOR_Rate_3_Mo['Huntington Nat\'l Bank'])
LIBOR_Rate_3_Mo['Huntington Nat\'I Bank'] = LIBOR_Rate_3_Mo['Huntington Nat\'I Bank'].combine_first(LIBOR_Rate_3_Mo['Huntington Natl Bank'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Huntington Nat\'l Bank', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Huntington Natl Bank', axis=1)

LIBOR_Rate_3_Mo['Goldman Sachs'] = LIBOR_Rate_3_Mo['Goldman Sachs'].combine_first(LIBOR_Rate_3_Mo['Goldman Sachs & Co,'])
LIBOR_Rate_3_Mo['Goldman Sachs'] = LIBOR_Rate_3_Mo['Goldman Sachs'].combine_first(LIBOR_Rate_3_Mo['Goldman Sachs & Co.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Goldman Sachs & Co,', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Goldman Sachs & Co.', axis=1)

LIBOR_Rate_3_Mo['Genetski Financial Advisors'] = LIBOR_Rate_3_Mo['Genetski Financial Advisors'].combine_first(LIBOR_Rate_3_Mo['Genetski.com'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Genetski.com', axis=1)

LIBOR_Rate_3_Mo['Fannie Mae'] = LIBOR_Rate_3_Mo['Fannie Mae'].combine_first(LIBOR_Rate_3_Mo['Fannie Mae '])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Fannie Mae ', axis=1)

LIBOR_Rate_3_Mo['Deutsche Bank Securities'] = LIBOR_Rate_3_Mo['Deutsche Bank Securities'].combine_first(LIBOR_Rate_3_Mo['Deutsche Bank Securities, Inc.'])
LIBOR_Rate_3_Mo['Deutsche Bank Securities'] = LIBOR_Rate_3_Mo['Deutsche Bank Securities'].combine_first(LIBOR_Rate_3_Mo['Deutsche Bank Securities, inc.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Deutsche Bank Securities, Inc.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Deutsche Bank Securities, inc.', axis=1)

LIBOR_Rate_3_Mo['DePrince & Associates'] = LIBOR_Rate_3_Mo['DePrince & Associates'].combine_first(LIBOR_Rate_3_Mo['DePrince & Assoc.'])
LIBOR_Rate_3_Mo['DePrince & Associates'] = LIBOR_Rate_3_Mo['DePrince & Associates'].combine_first(LIBOR_Rate_3_Mo['DePrince Associates'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('DePrince & Assoc.', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('DePrince Associates', axis=1)

LIBOR_Rate_3_Mo['Aeltus Investment'] = LIBOR_Rate_3_Mo['Aeltus Investment'].combine_first(LIBOR_Rate_3_Mo['Aeitus Investment'])
LIBOR_Rate_3_Mo['Aeltus Investment'] = LIBOR_Rate_3_Mo['Aeltus Investment'].combine_first(LIBOR_Rate_3_Mo['Aeltus investment'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Aeitus Investment', axis=1)
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Aeltus investment', axis=1)

LIBOR_Rate_3_Mo['ASB Capital Management'] = LIBOR_Rate_3_Mo['ASB Capital Management'].combine_first(LIBOR_Rate_3_Mo['ASB Captial Management'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('ASB Captial Management', axis=1)

LIBOR_Rate_3_Mo['BMO Nesbitt Burns'] = LIBOR_Rate_3_Mo['BMO Nesbitt Burns'].combine_first(LIBOR_Rate_3_Mo['BMC Nesbitt Burns'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('BMC Nesbitt Burns', axis=1)

LIBOR_Rate_3_Mo['Banc One Invest. Advisors'] = LIBOR_Rate_3_Mo['Banc One Invest. Advisors'].combine_first(LIBOR_Rate_3_Mo['Banc One invest. Advisors'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Banc One invest. Advisors', axis=1)

LIBOR_Rate_3_Mo['Banc of America Securities'] = LIBOR_Rate_3_Mo['Banc of America Securities'].combine_first(LIBOR_Rate_3_Mo['Banc of Amercia Securities'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Banc of Amercia Securities', axis=1)

LIBOR_Rate_3_Mo['Banc of America Securities'] = LIBOR_Rate_3_Mo['Banc of America Securities'].combine_first(LIBOR_Rate_3_Mo['Banc of America Securities, LLC'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Banc of America Securities, LLC', axis=1)

LIBOR_Rate_3_Mo['Bank of America Merrill Lynch'] = LIBOR_Rate_3_Mo['Bank of America Merrill Lynch'].combine_first(LIBOR_Rate_3_Mo['Bank of America-Merrill Lynch'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Bank of America-Merrill Lynch', axis=1)
LIBOR_Rate_3_Mo['Bank of America Merrill Lynch'] = LIBOR_Rate_3_Mo['Banc of America-Merrill Lynch'].combine_first(LIBOR_Rate_3_Mo['Banc of America-Merrill Lynch'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Banc of America-Merrill Lynch', axis=1)

LIBOR_Rate_3_Mo['Bank of Toyko-Mitsubishi'] = LIBOR_Rate_3_Mo['Bank of Toyko-Mitsubishi'].combine_first(LIBOR_Rate_3_Mo['Bank of Toyko-Mitsubishi UFJ'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

LIBOR_Rate_3_Mo['Barclays'] = LIBOR_Rate_3_Mo['Barclays'].combine_first(LIBOR_Rate_3_Mo['Barclays Capital'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Barclays Capital', axis=1)

LIBOR_Rate_3_Mo['Bear Stearns'] = LIBOR_Rate_3_Mo['Bear Stearns'].combine_first(LIBOR_Rate_3_Mo['Bear Stearns & Co.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Bear Stearns & Co.', axis=1)
LIBOR_Rate_3_Mo['Bear Stearns'] = LIBOR_Rate_3_Mo['Bear Stearns'].combine_first(LIBOR_Rate_3_Mo['Bear Steams & Co.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Bear Steams & Co.', axis=1)

LIBOR_Rate_3_Mo['Camilli Economics'] = LIBOR_Rate_3_Mo['Camilli Economics'].combine_first(LIBOR_Rate_3_Mo['Camilli Economics LLC'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Camilli Economics LLC', axis=1)
LIBOR_Rate_3_Mo['Camilli Economics'] = LIBOR_Rate_3_Mo['Camilli Economics'].combine_first(LIBOR_Rate_3_Mo['Camilli, Kathleen'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Camilli, Kathleen', axis=1)

LIBOR_Rate_3_Mo['Citibank Global Asset Mgmt'] = LIBOR_Rate_3_Mo['Citibank Global Asset Mgmt'].combine_first(LIBOR_Rate_3_Mo['Citibank Global Asset Mgmt.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Citibank Global Asset Mgmt.', axis=1)
LIBOR_Rate_3_Mo['Citibank Global Asset Mgmt'] = LIBOR_Rate_3_Mo['Citibank Global Asset Mgmt'].combine_first(LIBOR_Rate_3_Mo['Citigroup Asset Management'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Citigroup Asset Management', axis=1)

LIBOR_Rate_3_Mo['ClearView Economics'] = LIBOR_Rate_3_Mo['ClearView Economics'].combine_first(LIBOR_Rate_3_Mo['ClearView Associates'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('ClearView Associates', axis=1)
LIBOR_Rate_3_Mo['ClearView Economics'] = LIBOR_Rate_3_Mo['ClearView Economics'].combine_first(LIBOR_Rate_3_Mo['ClearView  Economics'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('ClearView  Economics', axis=1)

LIBOR_Rate_3_Mo['Comerica Bank'] = LIBOR_Rate_3_Mo['Comerica Bank'].combine_first(LIBOR_Rate_3_Mo['Commerica'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Commerica', axis=1)

LIBOR_Rate_3_Mo['Cycledata Corp.'] = LIBOR_Rate_3_Mo['Cycledata Corp.'].combine_first(LIBOR_Rate_3_Mo['Cycledata corp.'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Cycledata corp.', axis=1)

LIBOR_Rate_3_Mo['Daiwa Capital Markets America'] = LIBOR_Rate_3_Mo['Daiwa Capital Markets America'].combine_first(LIBOR_Rate_3_Mo['Daiw a Capital Markets America'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Daiw a Capital Markets America', axis=1)
LIBOR_Rate_3_Mo['Daiwa Capital Markets America'] = LIBOR_Rate_3_Mo['Daiwa Capital Markets America'].combine_first(LIBOR_Rate_3_Mo['Daiwa Securities America'])
LIBOR_Rate_3_Mo = LIBOR_Rate_3_Mo.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Com_Paper_1_Mo['Moody\'s Analytics'] = Com_Paper_1_Mo['Moody\'s Analytics'].combine_first(Com_Paper_1_Mo['Moody\'s Capital Markets'])
Com_Paper_1_Mo['Moody\'s Analytics'] = Com_Paper_1_Mo['Moody\'s Analytics'].combine_first(Com_Paper_1_Mo['Moody\'s Capital Markets Group'])
Com_Paper_1_Mo['Moody\'s Analytics'] = Com_Paper_1_Mo['Moody\'s Analytics'].combine_first(Com_Paper_1_Mo['Moody\'s Econmy.com'])
Com_Paper_1_Mo['Moody\'s Analytics'] = Com_Paper_1_Mo['Moody\'s Analytics'].combine_first(Com_Paper_1_Mo['Moody\'s Economy.com'])
Com_Paper_1_Mo['Moody\'s Analytics'] = Com_Paper_1_Mo['Moody\'s Analytics'].combine_first(Com_Paper_1_Mo['Moody\'s Investors Service'])
Com_Paper_1_Mo['Moody\'s Analytics'] = Com_Paper_1_Mo['Moody\'s Analytics'].combine_first(Com_Paper_1_Mo['Moodys Investors Service'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Moody\'s Capital Markets', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Moody\'s Capital Markets Group', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Moody\'s Econmy.com', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Moody\'s Economy.com', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Moody\'s Investors Service', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Moodys Investors Service', axis=1)

Com_Paper_1_Mo['Nat\'l Assn. of Realtors'] = Com_Paper_1_Mo['Nat\'l Assn. of Realtors'].combine_first(Com_Paper_1_Mo['Nat\'l Assn, of Realtors'])
Com_Paper_1_Mo['Nat\'l Assn. of Realtors'] = Com_Paper_1_Mo['Nat\'l Assn. of Realtors'].combine_first(Com_Paper_1_Mo['Nat\'I Assn, of Realtors'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Nat\'l Assn, of Realtors', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Nat\'I Assn, of Realtors', axis=1)

Com_Paper_1_Mo['National City Bank'] = Com_Paper_1_Mo['National City Bank'].combine_first(Com_Paper_1_Mo['National City Corporation'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('National City Corporation', axis=1)

Com_Paper_1_Mo['Nomura Securities Inc.'] = Com_Paper_1_Mo['Nomura Securities Inc.'].combine_first(Com_Paper_1_Mo['Nomura Securities, Inc.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Nomura Securities, Inc.', axis=1)

Com_Paper_1_Mo['October Consensus'] = Com_Paper_1_Mo['October Consensus'].combine_first(Com_Paper_1_Mo['Octoberber Consensus'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Octoberber Consensus', axis=1)

Com_Paper_1_Mo['PNC Bank Corp.'] = Com_Paper_1_Mo['PNC Bank Corp.'].combine_first(Com_Paper_1_Mo['PNC Financial Services'])
Com_Paper_1_Mo['PNC Bank Corp.'] = Com_Paper_1_Mo['PNC Bank Corp.'].combine_first(Com_Paper_1_Mo['PNC Financial Services Corp.'])
Com_Paper_1_Mo['PNC Bank Corp.'] = Com_Paper_1_Mo['PNC Bank Corp.'].combine_first(Com_Paper_1_Mo['PNC Financial Services Group'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('PNC Financial Services', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('PNC Financial Services Corp.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('PNC Financial Services Group', axis=1)

Com_Paper_1_Mo['Prudential Securities'] = Com_Paper_1_Mo['Prudential Securities'].combine_first(Com_Paper_1_Mo['Prudential Equity Group LLC'])
Com_Paper_1_Mo['Prudential Securities'] = Com_Paper_1_Mo['Prudential Securities'].combine_first(Com_Paper_1_Mo['Prudential Insurance Co.'])
Com_Paper_1_Mo['Prudential Securities'] = Com_Paper_1_Mo['Prudential Securities'].combine_first(Com_Paper_1_Mo['Prudential Financial'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Prudential Financial', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Prudential Insurance Co.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Prudential Equity Group LLC', axis=1)

Com_Paper_1_Mo['RBS Greenwich Capital Econ.'] = Com_Paper_1_Mo['RBS Greenwich Capital Econ.'].combine_first(Com_Paper_1_Mo['RBS Securities'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('RBS Securities', axis=1)

Com_Paper_1_Mo['RBC'] = Com_Paper_1_Mo['RBC'].combine_first(Com_Paper_1_Mo['RBC Capital Markets'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('RBC Capital Markets', axis=1)

Com_Paper_1_Mo['RDQ Economics'] = Com_Paper_1_Mo['RDQ Economics'].combine_first(Com_Paper_1_Mo['RDQ'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('RDQ', axis=1)

Com_Paper_1_Mo['RidgeWorth Investments'] = Com_Paper_1_Mo['RidgeWorth Investments'].combine_first(Com_Paper_1_Mo['RidgeWorth Capital Management'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('RidgeWorth Capital Management', axis=1)

Com_Paper_1_Mo['S&P Global'] = Com_Paper_1_Mo['S&P Global'].combine_first(Com_Paper_1_Mo['S&P Global Market Intelligence'])
Com_Paper_1_Mo['S&P Global'] = Com_Paper_1_Mo['S&P Global'].combine_first(Com_Paper_1_Mo['S&P Global Ratings'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('S&P Global Market Intelligence', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('S&P Global Ratings', axis=1)

Com_Paper_1_Mo['Scotiabank Group'] = Com_Paper_1_Mo['Scotiabank Group'].combine_first(Com_Paper_1_Mo['Scotiabank'])
Com_Paper_1_Mo['Scotiabank Group'] = Com_Paper_1_Mo['Scotiabank Group'].combine_first(Com_Paper_1_Mo['Scotia Capital'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Scotia Capital', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Scotiabank', axis=1)

Com_Paper_1_Mo['September Consensus'] = Com_Paper_1_Mo['September Consensus'].combine_first(Com_Paper_1_Mo['Sept. Consensus'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Sept. Consensus', axis=1)

Com_Paper_1_Mo['Standard & Poor\'s'] = Com_Paper_1_Mo['Standard & Poor\'s'].combine_first(Com_Paper_1_Mo['Standard & Poor\'s Corp.'])
Com_Paper_1_Mo['Standard & Poor\'s'] = Com_Paper_1_Mo['Standard & Poor\'s'].combine_first(Com_Paper_1_Mo['Standard & Poors'])
Com_Paper_1_Mo['Standard & Poor\'s'] = Com_Paper_1_Mo['Standard & Poor\'s'].combine_first(Com_Paper_1_Mo['Standard & Poor’s Corp.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Standard & Poor’s Corp.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Standard & Poor\'s Corp.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Standard & Poors', axis=1)

Com_Paper_1_Mo['Swiss Re'] = Com_Paper_1_Mo['Swiss Re'].combine_first(Com_Paper_1_Mo['Sw iss Re'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Sw iss Re', axis=1)

Com_Paper_1_Mo['Thredgold Economics'] = Com_Paper_1_Mo['Thredgold Economics'].combine_first(Com_Paper_1_Mo['Thredgold Economic Assoc.'])
Com_Paper_1_Mo['Thredgold Economics'] = Com_Paper_1_Mo['Thredgold Economics'].combine_first(Com_Paper_1_Mo['Thredgota Economic Assoc.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Thredgold Economic Assoc.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Thredgota Economic Assoc.', axis=1)

Com_Paper_1_Mo['Tokai Bank, Ltd.'] = Com_Paper_1_Mo['Tokai Bank, Ltd.'].combine_first(Com_Paper_1_Mo['Tokai Bank, Lid.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Tokai Bank, Lid.', axis=1)

Com_Paper_1_Mo['Wayne Hummer & Co.'] = Com_Paper_1_Mo['Wayne Hummer & Co.'].combine_first(Com_Paper_1_Mo['Wayne Hummer Investments'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Wayne Hummer Investments', axis=1)

Com_Paper_1_Mo['Wachovia'] = Com_Paper_1_Mo['Wachovia'].combine_first(Com_Paper_1_Mo['Wachovia Securities'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Wachovia Securities', axis=1)

Com_Paper_1_Mo['Wells Fargo'] = Com_Paper_1_Mo['Wells Fargo'].combine_first(Com_Paper_1_Mo['Wells Capital Management'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Wells Capital Management', axis=1)

Com_Paper_1_Mo['Woodworth Holdings'] = Com_Paper_1_Mo['Woodworth Holdings'].combine_first(Com_Paper_1_Mo['Woodw orth Holdings'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Woodw orth Holdings', axis=1)

Com_Paper_1_Mo['independent Economic Advisory'] = Com_Paper_1_Mo['independent Economic Advisory'].combine_first(Com_Paper_1_Mo['independent Econ. Advisory'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('independent Econ. Advisory', axis=1)

Com_Paper_1_Mo['MacroFin Analytics'] = Com_Paper_1_Mo['MacroFin Analytics'].combine_first(Com_Paper_1_Mo['MacroFin Analytics & RBS'])
Com_Paper_1_Mo['MacroFin Analytics'] = Com_Paper_1_Mo['MacroFin Analytics'].combine_first(Com_Paper_1_Mo['MacroFin Analytics & Rutgers Bus School'])
Com_Paper_1_Mo['MacroFin Analytics'] = Com_Paper_1_Mo['MacroFin Analytics'].combine_first(Com_Paper_1_Mo['MacroFin Analytics/Rutgers Bus School'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('MacroFin Analytics & RBS', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Com_Paper_1_Mo['Mesirow Financial'] = Com_Paper_1_Mo['Mesirow  Financial'].combine_first(Com_Paper_1_Mo['Mesirow  Financial'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Mesirow  Financial', axis=1)

Com_Paper_1_Mo['Merrill Lynch'] = Com_Paper_1_Mo['Merrill Lynch'].combine_first(Com_Paper_1_Mo['Merrill Lynch Economics'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Merrill Lynch Economics', axis=1)

Com_Paper_1_Mo['LaSalle Nat\'I Bank'] = Com_Paper_1_Mo['LaSalle Nat\'I Bank'].combine_first(Com_Paper_1_Mo['LaSalle Nat\'l Bank'])
Com_Paper_1_Mo['LaSalle Nat\'I Bank'] = Com_Paper_1_Mo['LaSalle Nat\'I Bank'].combine_first(Com_Paper_1_Mo['LaSalle Natl Bank'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('LaSalle Nat\'l Bank', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('LaSalle Natl Bank', axis=1)

Com_Paper_1_Mo['Kellner Economic Advisers'] = Com_Paper_1_Mo['Kellner Economic Advisers'].combine_first(Com_Paper_1_Mo['Keller Economic Advisers'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Keller Economic Advisers', axis=1)

Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['J.P. Morgan Chase'])
Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['J.P. Morgan Chase'])
Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['JPMorgan Asset Mgt.'])
Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['JPMorgan Fleming Asset Mgt.'])
Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['JPMorgan Privare Client Services'])
Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['JPMorgan Privare Wealth Mgt.'])
Com_Paper_1_Mo['J.P. Morgan'] = Com_Paper_1_Mo['J.P. Morgan'].combine_first(Com_Paper_1_Mo['JPMorgan Private Banking'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('JPMorgan Private Banking', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('JPMorgan Privare Client Services', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('JPMorgan Asset Mgt.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('J.P. Morgan Chase', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('J.P. MorganChase', axis=1)

Com_Paper_1_Mo['Independent Economic Advisory'] = Com_Paper_1_Mo['Independent Economic Advisory'].combine_first(Com_Paper_1_Mo['Independent Econ. Advisory'])
Com_Paper_1_Mo['Independent Economic Advisory'] = Com_Paper_1_Mo['Independent Economic Advisory'].combine_first(Com_Paper_1_Mo['Investment Economics Advisory'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Independent Econ. Advisory', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Investment Economics Advisory', axis=1)
                                         
Com_Paper_1_Mo['ING'] = Com_Paper_1_Mo['ING'].combine_first(Com_Paper_1_Mo['ING Investment Mgt.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('ING Investment Mgt.', axis=1)

Com_Paper_1_Mo['Huntington Nat\'I Bank'] = Com_Paper_1_Mo['Huntington Nat\'I Bank'].combine_first(Com_Paper_1_Mo['Huntington Nat\'l Bank'])
Com_Paper_1_Mo['Huntington Nat\'I Bank'] = Com_Paper_1_Mo['Huntington Nat\'I Bank'].combine_first(Com_Paper_1_Mo['Huntington Natl Bank'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Huntington Nat\'l Bank', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Huntington Natl Bank', axis=1)

Com_Paper_1_Mo['Goldman Sachs'] = Com_Paper_1_Mo['Goldman Sachs'].combine_first(Com_Paper_1_Mo['Goldman Sachs & Co,'])
Com_Paper_1_Mo['Goldman Sachs'] = Com_Paper_1_Mo['Goldman Sachs'].combine_first(Com_Paper_1_Mo['Goldman Sachs & Co.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Goldman Sachs & Co,', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Goldman Sachs & Co.', axis=1)

Com_Paper_1_Mo['Genetski Financial Advisors'] = Com_Paper_1_Mo['Genetski Financial Advisors'].combine_first(Com_Paper_1_Mo['Genetski.com'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Genetski.com', axis=1)

Com_Paper_1_Mo['Fannie Mae'] = Com_Paper_1_Mo['Fannie Mae'].combine_first(Com_Paper_1_Mo['Fannie Mae '])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Fannie Mae ', axis=1)

Com_Paper_1_Mo['Deutsche Bank Securities'] = Com_Paper_1_Mo['Deutsche Bank Securities'].combine_first(Com_Paper_1_Mo['Deutsche Bank Securities, Inc.'])
Com_Paper_1_Mo['Deutsche Bank Securities'] = Com_Paper_1_Mo['Deutsche Bank Securities'].combine_first(Com_Paper_1_Mo['Deutsche Bank Securities, inc.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Deutsche Bank Securities, Inc.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Deutsche Bank Securities, inc.', axis=1)

Com_Paper_1_Mo['DePrince & Associates'] = Com_Paper_1_Mo['DePrince & Associates'].combine_first(Com_Paper_1_Mo['DePrince & Assoc.'])
Com_Paper_1_Mo['DePrince & Associates'] = Com_Paper_1_Mo['DePrince & Associates'].combine_first(Com_Paper_1_Mo['DePrince Associates'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('DePrince & Assoc.', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('DePrince Associates', axis=1)

Com_Paper_1_Mo['Aeltus Investment'] = Com_Paper_1_Mo['Aeltus Investment'].combine_first(Com_Paper_1_Mo['Aeitus Investment'])
Com_Paper_1_Mo['Aeltus Investment'] = Com_Paper_1_Mo['Aeltus Investment'].combine_first(Com_Paper_1_Mo['Aeltus investment'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Aeitus Investment', axis=1)
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Aeltus investment', axis=1)

Com_Paper_1_Mo['ASB Capital Management'] = Com_Paper_1_Mo['ASB Capital Management'].combine_first(Com_Paper_1_Mo['ASB Captial Management'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('ASB Captial Management', axis=1)

Com_Paper_1_Mo['BMO Nesbitt Burns'] = Com_Paper_1_Mo['BMO Nesbitt Burns'].combine_first(Com_Paper_1_Mo['BMC Nesbitt Burns'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('BMC Nesbitt Burns', axis=1)

Com_Paper_1_Mo['Banc One Invest. Advisors'] = Com_Paper_1_Mo['Banc One Invest. Advisors'].combine_first(Com_Paper_1_Mo['Banc One invest. Advisors'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Banc One invest. Advisors', axis=1)

Com_Paper_1_Mo['Banc of America Securities'] = Com_Paper_1_Mo['Banc of America Securities'].combine_first(Com_Paper_1_Mo['Banc of Amercia Securities'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Banc of Amercia Securities', axis=1)

Com_Paper_1_Mo['Banc of America Securities'] = Com_Paper_1_Mo['Banc of America Securities'].combine_first(Com_Paper_1_Mo['Banc of America Securities, LLC'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Banc of America Securities, LLC', axis=1)

Com_Paper_1_Mo['Bank of America Merrill Lynch'] = Com_Paper_1_Mo['Bank of America Merrill Lynch'].combine_first(Com_Paper_1_Mo['Bank of America-Merrill Lynch'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Bank of America-Merrill Lynch', axis=1)
Com_Paper_1_Mo['Bank of America Merrill Lynch'] = Com_Paper_1_Mo['Banc of America-Merrill Lynch'].combine_first(Com_Paper_1_Mo['Banc of America-Merrill Lynch'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Banc of America-Merrill Lynch', axis=1)

Com_Paper_1_Mo['Bank of Toyko-Mitsubishi'] = Com_Paper_1_Mo['Bank of Toyko-Mitsubishi'].combine_first(Com_Paper_1_Mo['Bank of Toyko-Mitsubishi UFJ'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Com_Paper_1_Mo['Barclays'] = Com_Paper_1_Mo['Barclays'].combine_first(Com_Paper_1_Mo['Barclays Capital'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Barclays Capital', axis=1)

Com_Paper_1_Mo['Bear Stearns'] = Com_Paper_1_Mo['Bear Stearns'].combine_first(Com_Paper_1_Mo['Bear Stearns & Co.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Bear Stearns & Co.', axis=1)
Com_Paper_1_Mo['Bear Stearns'] = Com_Paper_1_Mo['Bear Stearns'].combine_first(Com_Paper_1_Mo['Bear Steams & Co.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Bear Steams & Co.', axis=1)

Com_Paper_1_Mo['Camilli Economics'] = Com_Paper_1_Mo['Camilli Economics'].combine_first(Com_Paper_1_Mo['Camilli Economics LLC'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Camilli Economics LLC', axis=1)
Com_Paper_1_Mo['Camilli Economics'] = Com_Paper_1_Mo['Camilli Economics'].combine_first(Com_Paper_1_Mo['Camilli, Kathleen'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Camilli, Kathleen', axis=1)

Com_Paper_1_Mo['Citibank Global Asset Mgmt'] = Com_Paper_1_Mo['Citibank Global Asset Mgmt'].combine_first(Com_Paper_1_Mo['Citibank Global Asset Mgmt.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Citibank Global Asset Mgmt.', axis=1)
Com_Paper_1_Mo['Citibank Global Asset Mgmt'] = Com_Paper_1_Mo['Citibank Global Asset Mgmt'].combine_first(Com_Paper_1_Mo['Citigroup Asset Management'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Citigroup Asset Management', axis=1)

Com_Paper_1_Mo['ClearView Economics'] = Com_Paper_1_Mo['ClearView Economics'].combine_first(Com_Paper_1_Mo['ClearView Associates'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('ClearView Associates', axis=1)
Com_Paper_1_Mo['ClearView Economics'] = Com_Paper_1_Mo['ClearView Economics'].combine_first(Com_Paper_1_Mo['ClearView  Economics'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('ClearView  Economics', axis=1)

Com_Paper_1_Mo['Comerica Bank'] = Com_Paper_1_Mo['Comerica Bank'].combine_first(Com_Paper_1_Mo['Commerica'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Commerica', axis=1)

Com_Paper_1_Mo['Cycledata Corp.'] = Com_Paper_1_Mo['Cycledata Corp.'].combine_first(Com_Paper_1_Mo['Cycledata corp.'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Cycledata corp.', axis=1)

Com_Paper_1_Mo['Daiwa Capital Markets America'] = Com_Paper_1_Mo['Daiwa Capital Markets America'].combine_first(Com_Paper_1_Mo['Daiw a Capital Markets America'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Daiw a Capital Markets America', axis=1)
Com_Paper_1_Mo['Daiwa Capital Markets America'] = Com_Paper_1_Mo['Daiwa Capital Markets America'].combine_first(Com_Paper_1_Mo['Daiwa Securities America'])
Com_Paper_1_Mo = Com_Paper_1_Mo.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_3_Mo['Moody\'s Analytics'] = Treas_Bills_3_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_3_Mo['Moody\'s Capital Markets'])
Treas_Bills_3_Mo['Moody\'s Analytics'] = Treas_Bills_3_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_3_Mo['Moody\'s Capital Markets Group'])
Treas_Bills_3_Mo['Moody\'s Analytics'] = Treas_Bills_3_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_3_Mo['Moody\'s Econmy.com'])
Treas_Bills_3_Mo['Moody\'s Analytics'] = Treas_Bills_3_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_3_Mo['Moody\'s Economy.com'])
Treas_Bills_3_Mo['Moody\'s Analytics'] = Treas_Bills_3_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_3_Mo['Moody\'s Investors Service'])
Treas_Bills_3_Mo['Moody\'s Analytics'] = Treas_Bills_3_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_3_Mo['Moodys Investors Service'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Moodys Investors Service', axis=1)

Treas_Bills_3_Mo['Nat\'l Assn. of Realtors'] = Treas_Bills_3_Mo['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_3_Mo['Nat\'l Assn, of Realtors'])
Treas_Bills_3_Mo['Nat\'l Assn. of Realtors'] = Treas_Bills_3_Mo['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_3_Mo['Nat\'I Assn, of Realtors'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_3_Mo['National City Bank'] = Treas_Bills_3_Mo['National City Bank'].combine_first(Treas_Bills_3_Mo['National City Corporation'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('National City Corporation', axis=1)

Treas_Bills_3_Mo['Nomura Securities Inc.'] = Treas_Bills_3_Mo['Nomura Securities Inc.'].combine_first(Treas_Bills_3_Mo['Nomura Securities, Inc.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_3_Mo['October Consensus'] = Treas_Bills_3_Mo['October Consensus'].combine_first(Treas_Bills_3_Mo['Octoberber Consensus'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Octoberber Consensus', axis=1)

Treas_Bills_3_Mo['PNC Bank Corp.'] = Treas_Bills_3_Mo['PNC Bank Corp.'].combine_first(Treas_Bills_3_Mo['PNC Financial Services'])
Treas_Bills_3_Mo['PNC Bank Corp.'] = Treas_Bills_3_Mo['PNC Bank Corp.'].combine_first(Treas_Bills_3_Mo['PNC Financial Services Corp.'])
Treas_Bills_3_Mo['PNC Bank Corp.'] = Treas_Bills_3_Mo['PNC Bank Corp.'].combine_first(Treas_Bills_3_Mo['PNC Financial Services Group'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('PNC Financial Services', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('PNC Financial Services Group', axis=1)

Treas_Bills_3_Mo['Prudential Securities'] = Treas_Bills_3_Mo['Prudential Securities'].combine_first(Treas_Bills_3_Mo['Prudential Equity Group LLC'])
Treas_Bills_3_Mo['Prudential Securities'] = Treas_Bills_3_Mo['Prudential Securities'].combine_first(Treas_Bills_3_Mo['Prudential Insurance Co.'])
Treas_Bills_3_Mo['Prudential Securities'] = Treas_Bills_3_Mo['Prudential Securities'].combine_first(Treas_Bills_3_Mo['Prudential Financial'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Prudential Financial', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_3_Mo['RBS Greenwich Capital Econ.'] = Treas_Bills_3_Mo['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_3_Mo['RBS Securities'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('RBS Securities', axis=1)

Treas_Bills_3_Mo['RBC'] = Treas_Bills_3_Mo['RBC'].combine_first(Treas_Bills_3_Mo['RBC Capital Markets'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('RBC Capital Markets', axis=1)

Treas_Bills_3_Mo['RDQ Economics'] = Treas_Bills_3_Mo['RDQ Economics'].combine_first(Treas_Bills_3_Mo['RDQ'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('RDQ', axis=1)

Treas_Bills_3_Mo['RidgeWorth Investments'] = Treas_Bills_3_Mo['RidgeWorth Investments'].combine_first(Treas_Bills_3_Mo['RidgeWorth Capital Management'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_3_Mo['S&P Global'] = Treas_Bills_3_Mo['S&P Global'].combine_first(Treas_Bills_3_Mo['S&P Global Market Intelligence'])
Treas_Bills_3_Mo['S&P Global'] = Treas_Bills_3_Mo['S&P Global'].combine_first(Treas_Bills_3_Mo['S&P Global Ratings'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('S&P Global Ratings', axis=1)

Treas_Bills_3_Mo['Scotiabank Group'] = Treas_Bills_3_Mo['Scotiabank Group'].combine_first(Treas_Bills_3_Mo['Scotiabank'])
Treas_Bills_3_Mo['Scotiabank Group'] = Treas_Bills_3_Mo['Scotiabank Group'].combine_first(Treas_Bills_3_Mo['Scotia Capital'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Scotia Capital', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Scotiabank', axis=1)

Treas_Bills_3_Mo['September Consensus'] = Treas_Bills_3_Mo['September Consensus'].combine_first(Treas_Bills_3_Mo['Sept. Consensus'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Sept. Consensus', axis=1)

Treas_Bills_3_Mo['Standard & Poor\'s'] = Treas_Bills_3_Mo['Standard & Poor\'s'].combine_first(Treas_Bills_3_Mo['Standard & Poor\'s Corp.'])
Treas_Bills_3_Mo['Standard & Poor\'s'] = Treas_Bills_3_Mo['Standard & Poor\'s'].combine_first(Treas_Bills_3_Mo['Standard & Poors'])
Treas_Bills_3_Mo['Standard & Poor\'s'] = Treas_Bills_3_Mo['Standard & Poor\'s'].combine_first(Treas_Bills_3_Mo['Standard & Poor’s Corp.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Standard & Poors', axis=1)

Treas_Bills_3_Mo['Swiss Re'] = Treas_Bills_3_Mo['Swiss Re'].combine_first(Treas_Bills_3_Mo['Sw iss Re'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Sw iss Re', axis=1)

Treas_Bills_3_Mo['Thredgold Economics'] = Treas_Bills_3_Mo['Thredgold Economics'].combine_first(Treas_Bills_3_Mo['Thredgold Economic Assoc.'])
Treas_Bills_3_Mo['Thredgold Economics'] = Treas_Bills_3_Mo['Thredgold Economics'].combine_first(Treas_Bills_3_Mo['Thredgota Economic Assoc.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_3_Mo['Tokai Bank, Ltd.'] = Treas_Bills_3_Mo['Tokai Bank, Ltd.'].combine_first(Treas_Bills_3_Mo['Tokai Bank, Lid.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_3_Mo['Wayne Hummer & Co.'] = Treas_Bills_3_Mo['Wayne Hummer & Co.'].combine_first(Treas_Bills_3_Mo['Wayne Hummer Investments'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_3_Mo['Wachovia'] = Treas_Bills_3_Mo['Wachovia'].combine_first(Treas_Bills_3_Mo['Wachovia Securities'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Wachovia Securities', axis=1)

Treas_Bills_3_Mo['Wells Fargo'] = Treas_Bills_3_Mo['Wells Fargo'].combine_first(Treas_Bills_3_Mo['Wells Capital Management'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Wells Capital Management', axis=1)

Treas_Bills_3_Mo['Woodworth Holdings'] = Treas_Bills_3_Mo['Woodworth Holdings'].combine_first(Treas_Bills_3_Mo['Woodw orth Holdings'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Woodw orth Holdings', axis=1)

Treas_Bills_3_Mo['independent Economic Advisory'] = Treas_Bills_3_Mo['independent Economic Advisory'].combine_first(Treas_Bills_3_Mo['independent Econ. Advisory'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('independent Econ. Advisory', axis=1)

Treas_Bills_3_Mo['MacroFin Analytics'] = Treas_Bills_3_Mo['MacroFin Analytics'].combine_first(Treas_Bills_3_Mo['MacroFin Analytics & RBS'])
Treas_Bills_3_Mo['MacroFin Analytics'] = Treas_Bills_3_Mo['MacroFin Analytics'].combine_first(Treas_Bills_3_Mo['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_3_Mo['MacroFin Analytics'] = Treas_Bills_3_Mo['MacroFin Analytics'].combine_first(Treas_Bills_3_Mo['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_3_Mo['Mesirow Financial'] = Treas_Bills_3_Mo['Mesirow  Financial'].combine_first(Treas_Bills_3_Mo['Mesirow  Financial'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Mesirow  Financial', axis=1)

Treas_Bills_3_Mo['Merrill Lynch'] = Treas_Bills_3_Mo['Merrill Lynch'].combine_first(Treas_Bills_3_Mo['Merrill Lynch Economics'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_3_Mo['LaSalle Nat\'I Bank'] = Treas_Bills_3_Mo['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_3_Mo['LaSalle Nat\'l Bank'])
Treas_Bills_3_Mo['LaSalle Nat\'I Bank'] = Treas_Bills_3_Mo['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_3_Mo['LaSalle Natl Bank'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_3_Mo['Kellner Economic Advisers'] = Treas_Bills_3_Mo['Kellner Economic Advisers'].combine_first(Treas_Bills_3_Mo['Keller Economic Advisers'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Keller Economic Advisers', axis=1)

Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['J.P. Morgan Chase'])
Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['J.P. Morgan Chase'])
Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['JPMorgan Asset Mgt.'])
Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['JPMorgan Privare Client Services'])
Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_3_Mo['J.P. Morgan'] = Treas_Bills_3_Mo['J.P. Morgan'].combine_first(Treas_Bills_3_Mo['JPMorgan Private Banking'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('J.P. MorganChase', axis=1)

Treas_Bills_3_Mo['Independent Economic Advisory'] = Treas_Bills_3_Mo['Independent Economic Advisory'].combine_first(Treas_Bills_3_Mo['Independent Econ. Advisory'])
Treas_Bills_3_Mo['Independent Economic Advisory'] = Treas_Bills_3_Mo['Independent Economic Advisory'].combine_first(Treas_Bills_3_Mo['Investment Economics Advisory'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_3_Mo['ING'] = Treas_Bills_3_Mo['ING'].combine_first(Treas_Bills_3_Mo['ING Investment Mgt.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('ING Investment Mgt.', axis=1)

Treas_Bills_3_Mo['Huntington Nat\'I Bank'] = Treas_Bills_3_Mo['Huntington Nat\'I Bank'].combine_first(Treas_Bills_3_Mo['Huntington Nat\'l Bank'])
Treas_Bills_3_Mo['Huntington Nat\'I Bank'] = Treas_Bills_3_Mo['Huntington Nat\'I Bank'].combine_first(Treas_Bills_3_Mo['Huntington Natl Bank'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Huntington Natl Bank', axis=1)

Treas_Bills_3_Mo['Goldman Sachs'] = Treas_Bills_3_Mo['Goldman Sachs'].combine_first(Treas_Bills_3_Mo['Goldman Sachs & Co,'])
Treas_Bills_3_Mo['Goldman Sachs'] = Treas_Bills_3_Mo['Goldman Sachs'].combine_first(Treas_Bills_3_Mo['Goldman Sachs & Co.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_3_Mo['Genetski Financial Advisors'] = Treas_Bills_3_Mo['Genetski Financial Advisors'].combine_first(Treas_Bills_3_Mo['Genetski.com'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Genetski.com', axis=1)

Treas_Bills_3_Mo['Fannie Mae'] = Treas_Bills_3_Mo['Fannie Mae'].combine_first(Treas_Bills_3_Mo['Fannie Mae '])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Fannie Mae ', axis=1)

Treas_Bills_3_Mo['Deutsche Bank Securities'] = Treas_Bills_3_Mo['Deutsche Bank Securities'].combine_first(Treas_Bills_3_Mo['Deutsche Bank Securities, Inc.'])
Treas_Bills_3_Mo['Deutsche Bank Securities'] = Treas_Bills_3_Mo['Deutsche Bank Securities'].combine_first(Treas_Bills_3_Mo['Deutsche Bank Securities, inc.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_3_Mo['DePrince & Associates'] = Treas_Bills_3_Mo['DePrince & Associates'].combine_first(Treas_Bills_3_Mo['DePrince & Assoc.'])
Treas_Bills_3_Mo['DePrince & Associates'] = Treas_Bills_3_Mo['DePrince & Associates'].combine_first(Treas_Bills_3_Mo['DePrince Associates'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('DePrince & Assoc.', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('DePrince Associates', axis=1)

Treas_Bills_3_Mo['Aeltus Investment'] = Treas_Bills_3_Mo['Aeltus Investment'].combine_first(Treas_Bills_3_Mo['Aeitus Investment'])
Treas_Bills_3_Mo['Aeltus Investment'] = Treas_Bills_3_Mo['Aeltus Investment'].combine_first(Treas_Bills_3_Mo['Aeltus investment'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Aeitus Investment', axis=1)
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Aeltus investment', axis=1)

Treas_Bills_3_Mo['ASB Capital Management'] = Treas_Bills_3_Mo['ASB Capital Management'].combine_first(Treas_Bills_3_Mo['ASB Captial Management'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('ASB Captial Management', axis=1)

Treas_Bills_3_Mo['BMO Nesbitt Burns'] = Treas_Bills_3_Mo['BMO Nesbitt Burns'].combine_first(Treas_Bills_3_Mo['BMC Nesbitt Burns'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_3_Mo['Banc One Invest. Advisors'] = Treas_Bills_3_Mo['Banc One Invest. Advisors'].combine_first(Treas_Bills_3_Mo['Banc One invest. Advisors'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_3_Mo['Banc of America Securities'] = Treas_Bills_3_Mo['Banc of America Securities'].combine_first(Treas_Bills_3_Mo['Banc of Amercia Securities'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_3_Mo['Banc of America Securities'] = Treas_Bills_3_Mo['Banc of America Securities'].combine_first(Treas_Bills_3_Mo['Banc of America Securities, LLC'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_3_Mo['Bank of America Merrill Lynch'] = Treas_Bills_3_Mo['Bank of America Merrill Lynch'].combine_first(Treas_Bills_3_Mo['Bank of America-Merrill Lynch'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_3_Mo['Bank of America Merrill Lynch'] = Treas_Bills_3_Mo['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_3_Mo['Banc of America-Merrill Lynch'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_3_Mo['Bank of Toyko-Mitsubishi'] = Treas_Bills_3_Mo['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_3_Mo['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_3_Mo['Barclays'] = Treas_Bills_3_Mo['Barclays'].combine_first(Treas_Bills_3_Mo['Barclays Capital'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Barclays Capital', axis=1)

Treas_Bills_3_Mo['Bear Stearns'] = Treas_Bills_3_Mo['Bear Stearns'].combine_first(Treas_Bills_3_Mo['Bear Stearns & Co.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_3_Mo['Bear Stearns'] = Treas_Bills_3_Mo['Bear Stearns'].combine_first(Treas_Bills_3_Mo['Bear Steams & Co.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Bear Steams & Co.', axis=1)

Treas_Bills_3_Mo['Camilli Economics'] = Treas_Bills_3_Mo['Camilli Economics'].combine_first(Treas_Bills_3_Mo['Camilli Economics LLC'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Camilli Economics LLC', axis=1)
Treas_Bills_3_Mo['Camilli Economics'] = Treas_Bills_3_Mo['Camilli Economics'].combine_first(Treas_Bills_3_Mo['Camilli, Kathleen'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Camilli, Kathleen', axis=1)

Treas_Bills_3_Mo['Citibank Global Asset Mgmt'] = Treas_Bills_3_Mo['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_3_Mo['Citibank Global Asset Mgmt.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_3_Mo['Citibank Global Asset Mgmt'] = Treas_Bills_3_Mo['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_3_Mo['Citigroup Asset Management'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Citigroup Asset Management', axis=1)

Treas_Bills_3_Mo['ClearView Economics'] = Treas_Bills_3_Mo['ClearView Economics'].combine_first(Treas_Bills_3_Mo['ClearView Associates'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('ClearView Associates', axis=1)
Treas_Bills_3_Mo['ClearView Economics'] = Treas_Bills_3_Mo['ClearView Economics'].combine_first(Treas_Bills_3_Mo['ClearView  Economics'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('ClearView  Economics', axis=1)

Treas_Bills_3_Mo['Comerica Bank'] = Treas_Bills_3_Mo['Comerica Bank'].combine_first(Treas_Bills_3_Mo['Commerica'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Commerica', axis=1)

Treas_Bills_3_Mo['Cycledata Corp.'] = Treas_Bills_3_Mo['Cycledata Corp.'].combine_first(Treas_Bills_3_Mo['Cycledata corp.'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Cycledata corp.', axis=1)

Treas_Bills_3_Mo['Daiwa Capital Markets America'] = Treas_Bills_3_Mo['Daiwa Capital Markets America'].combine_first(Treas_Bills_3_Mo['Daiw a Capital Markets America'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_3_Mo['Daiwa Capital Markets America'] = Treas_Bills_3_Mo['Daiwa Capital Markets America'].combine_first(Treas_Bills_3_Mo['Daiwa Securities America'])
Treas_Bills_3_Mo = Treas_Bills_3_Mo.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_6_Mo['Moody\'s Analytics'] = Treas_Bills_6_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_6_Mo['Moody\'s Capital Markets'])
Treas_Bills_6_Mo['Moody\'s Analytics'] = Treas_Bills_6_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_6_Mo['Moody\'s Capital Markets Group'])
Treas_Bills_6_Mo['Moody\'s Analytics'] = Treas_Bills_6_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_6_Mo['Moody\'s Econmy.com'])
Treas_Bills_6_Mo['Moody\'s Analytics'] = Treas_Bills_6_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_6_Mo['Moody\'s Economy.com'])
Treas_Bills_6_Mo['Moody\'s Analytics'] = Treas_Bills_6_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_6_Mo['Moody\'s Investors Service'])
Treas_Bills_6_Mo['Moody\'s Analytics'] = Treas_Bills_6_Mo['Moody\'s Analytics'].combine_first(Treas_Bills_6_Mo['Moodys Investors Service'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Moodys Investors Service', axis=1)

Treas_Bills_6_Mo['Nat\'l Assn. of Realtors'] = Treas_Bills_6_Mo['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_6_Mo['Nat\'l Assn, of Realtors'])
Treas_Bills_6_Mo['Nat\'l Assn. of Realtors'] = Treas_Bills_6_Mo['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_6_Mo['Nat\'I Assn, of Realtors'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_6_Mo['National City Bank'] = Treas_Bills_6_Mo['National City Bank'].combine_first(Treas_Bills_6_Mo['National City Corporation'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('National City Corporation', axis=1)

Treas_Bills_6_Mo['Nomura Securities Inc.'] = Treas_Bills_6_Mo['Nomura Securities Inc.'].combine_first(Treas_Bills_6_Mo['Nomura Securities, Inc.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_6_Mo['October Consensus'] = Treas_Bills_6_Mo['October Consensus'].combine_first(Treas_Bills_6_Mo['Octoberber Consensus'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Octoberber Consensus', axis=1)

Treas_Bills_6_Mo['PNC Bank Corp.'] = Treas_Bills_6_Mo['PNC Bank Corp.'].combine_first(Treas_Bills_6_Mo['PNC Financial Services'])
Treas_Bills_6_Mo['PNC Bank Corp.'] = Treas_Bills_6_Mo['PNC Bank Corp.'].combine_first(Treas_Bills_6_Mo['PNC Financial Services Corp.'])
Treas_Bills_6_Mo['PNC Bank Corp.'] = Treas_Bills_6_Mo['PNC Bank Corp.'].combine_first(Treas_Bills_6_Mo['PNC Financial Services Group'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('PNC Financial Services', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('PNC Financial Services Group', axis=1)

Treas_Bills_6_Mo['Prudential Securities'] = Treas_Bills_6_Mo['Prudential Securities'].combine_first(Treas_Bills_6_Mo['Prudential Equity Group LLC'])
Treas_Bills_6_Mo['Prudential Securities'] = Treas_Bills_6_Mo['Prudential Securities'].combine_first(Treas_Bills_6_Mo['Prudential Insurance Co.'])
Treas_Bills_6_Mo['Prudential Securities'] = Treas_Bills_6_Mo['Prudential Securities'].combine_first(Treas_Bills_6_Mo['Prudential Financial'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Prudential Financial', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_6_Mo['RBS Greenwich Capital Econ.'] = Treas_Bills_6_Mo['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_6_Mo['RBS Securities'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('RBS Securities', axis=1)

Treas_Bills_6_Mo['RBC'] = Treas_Bills_6_Mo['RBC'].combine_first(Treas_Bills_6_Mo['RBC Capital Markets'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('RBC Capital Markets', axis=1)

Treas_Bills_6_Mo['RDQ Economics'] = Treas_Bills_6_Mo['RDQ Economics'].combine_first(Treas_Bills_6_Mo['RDQ'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('RDQ', axis=1)

Treas_Bills_6_Mo['RidgeWorth Investments'] = Treas_Bills_6_Mo['RidgeWorth Investments'].combine_first(Treas_Bills_6_Mo['RidgeWorth Capital Management'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_6_Mo['S&P Global'] = Treas_Bills_6_Mo['S&P Global'].combine_first(Treas_Bills_6_Mo['S&P Global Market Intelligence'])
Treas_Bills_6_Mo['S&P Global'] = Treas_Bills_6_Mo['S&P Global'].combine_first(Treas_Bills_6_Mo['S&P Global Ratings'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('S&P Global Ratings', axis=1)

Treas_Bills_6_Mo['Scotiabank Group'] = Treas_Bills_6_Mo['Scotiabank Group'].combine_first(Treas_Bills_6_Mo['Scotiabank'])
Treas_Bills_6_Mo['Scotiabank Group'] = Treas_Bills_6_Mo['Scotiabank Group'].combine_first(Treas_Bills_6_Mo['Scotia Capital'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Scotia Capital', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Scotiabank', axis=1)

Treas_Bills_6_Mo['September Consensus'] = Treas_Bills_6_Mo['September Consensus'].combine_first(Treas_Bills_6_Mo['Sept. Consensus'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Sept. Consensus', axis=1)

Treas_Bills_6_Mo['Standard & Poor\'s'] = Treas_Bills_6_Mo['Standard & Poor\'s'].combine_first(Treas_Bills_6_Mo['Standard & Poor\'s Corp.'])
Treas_Bills_6_Mo['Standard & Poor\'s'] = Treas_Bills_6_Mo['Standard & Poor\'s'].combine_first(Treas_Bills_6_Mo['Standard & Poors'])
Treas_Bills_6_Mo['Standard & Poor\'s'] = Treas_Bills_6_Mo['Standard & Poor\'s'].combine_first(Treas_Bills_6_Mo['Standard & Poor’s Corp.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Standard & Poors', axis=1)

Treas_Bills_6_Mo['Swiss Re'] = Treas_Bills_6_Mo['Swiss Re'].combine_first(Treas_Bills_6_Mo['Sw iss Re'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Sw iss Re', axis=1)

Treas_Bills_6_Mo['Thredgold Economics'] = Treas_Bills_6_Mo['Thredgold Economics'].combine_first(Treas_Bills_6_Mo['Thredgold Economic Assoc.'])
Treas_Bills_6_Mo['Thredgold Economics'] = Treas_Bills_6_Mo['Thredgold Economics'].combine_first(Treas_Bills_6_Mo['Thredgota Economic Assoc.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_6_Mo['Tokai Bank, Ltd.'] = Treas_Bills_6_Mo['Tokai Bank, Ltd.'].combine_first(Treas_Bills_6_Mo['Tokai Bank, Lid.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_6_Mo['Wayne Hummer & Co.'] = Treas_Bills_6_Mo['Wayne Hummer & Co.'].combine_first(Treas_Bills_6_Mo['Wayne Hummer Investments'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_6_Mo['Wachovia'] = Treas_Bills_6_Mo['Wachovia'].combine_first(Treas_Bills_6_Mo['Wachovia Securities'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Wachovia Securities', axis=1)

Treas_Bills_6_Mo['Wells Fargo'] = Treas_Bills_6_Mo['Wells Fargo'].combine_first(Treas_Bills_6_Mo['Wells Capital Management'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Wells Capital Management', axis=1)

Treas_Bills_6_Mo['Woodworth Holdings'] = Treas_Bills_6_Mo['Woodworth Holdings'].combine_first(Treas_Bills_6_Mo['Woodw orth Holdings'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Woodw orth Holdings', axis=1)

Treas_Bills_6_Mo['independent Economic Advisory'] = Treas_Bills_6_Mo['independent Economic Advisory'].combine_first(Treas_Bills_6_Mo['independent Econ. Advisory'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('independent Econ. Advisory', axis=1)

Treas_Bills_6_Mo['MacroFin Analytics'] = Treas_Bills_6_Mo['MacroFin Analytics'].combine_first(Treas_Bills_6_Mo['MacroFin Analytics & RBS'])
Treas_Bills_6_Mo['MacroFin Analytics'] = Treas_Bills_6_Mo['MacroFin Analytics'].combine_first(Treas_Bills_6_Mo['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_6_Mo['MacroFin Analytics'] = Treas_Bills_6_Mo['MacroFin Analytics'].combine_first(Treas_Bills_6_Mo['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_6_Mo['Mesirow Financial'] = Treas_Bills_6_Mo['Mesirow  Financial'].combine_first(Treas_Bills_6_Mo['Mesirow  Financial'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Mesirow  Financial', axis=1)

Treas_Bills_6_Mo['Merrill Lynch'] = Treas_Bills_6_Mo['Merrill Lynch'].combine_first(Treas_Bills_6_Mo['Merrill Lynch Economics'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_6_Mo['LaSalle Nat\'I Bank'] = Treas_Bills_6_Mo['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_6_Mo['LaSalle Nat\'l Bank'])
Treas_Bills_6_Mo['LaSalle Nat\'I Bank'] = Treas_Bills_6_Mo['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_6_Mo['LaSalle Natl Bank'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_6_Mo['Kellner Economic Advisers'] = Treas_Bills_6_Mo['Kellner Economic Advisers'].combine_first(Treas_Bills_6_Mo['Keller Economic Advisers'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Keller Economic Advisers', axis=1)

Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['J.P. Morgan Chase'])
Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['J.P. Morgan Chase'])
Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['JPMorgan Asset Mgt.'])
Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['JPMorgan Privare Client Services'])
Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_6_Mo['J.P. Morgan'] = Treas_Bills_6_Mo['J.P. Morgan'].combine_first(Treas_Bills_6_Mo['JPMorgan Private Banking'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('J.P. MorganChase', axis=1)

Treas_Bills_6_Mo['Independent Economic Advisory'] = Treas_Bills_6_Mo['Independent Economic Advisory'].combine_first(Treas_Bills_6_Mo['Independent Econ. Advisory'])
Treas_Bills_6_Mo['Independent Economic Advisory'] = Treas_Bills_6_Mo['Independent Economic Advisory'].combine_first(Treas_Bills_6_Mo['Investment Economics Advisory'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_6_Mo['ING'] = Treas_Bills_6_Mo['ING'].combine_first(Treas_Bills_6_Mo['ING Investment Mgt.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('ING Investment Mgt.', axis=1)

Treas_Bills_6_Mo['Huntington Nat\'I Bank'] = Treas_Bills_6_Mo['Huntington Nat\'I Bank'].combine_first(Treas_Bills_6_Mo['Huntington Nat\'l Bank'])
Treas_Bills_6_Mo['Huntington Nat\'I Bank'] = Treas_Bills_6_Mo['Huntington Nat\'I Bank'].combine_first(Treas_Bills_6_Mo['Huntington Natl Bank'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Huntington Natl Bank', axis=1)

Treas_Bills_6_Mo['Goldman Sachs'] = Treas_Bills_6_Mo['Goldman Sachs'].combine_first(Treas_Bills_6_Mo['Goldman Sachs & Co,'])
Treas_Bills_6_Mo['Goldman Sachs'] = Treas_Bills_6_Mo['Goldman Sachs'].combine_first(Treas_Bills_6_Mo['Goldman Sachs & Co.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_6_Mo['Genetski Financial Advisors'] = Treas_Bills_6_Mo['Genetski Financial Advisors'].combine_first(Treas_Bills_6_Mo['Genetski.com'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Genetski.com', axis=1)

Treas_Bills_6_Mo['Fannie Mae'] = Treas_Bills_6_Mo['Fannie Mae'].combine_first(Treas_Bills_6_Mo['Fannie Mae '])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Fannie Mae ', axis=1)

Treas_Bills_6_Mo['Deutsche Bank Securities'] = Treas_Bills_6_Mo['Deutsche Bank Securities'].combine_first(Treas_Bills_6_Mo['Deutsche Bank Securities, Inc.'])
Treas_Bills_6_Mo['Deutsche Bank Securities'] = Treas_Bills_6_Mo['Deutsche Bank Securities'].combine_first(Treas_Bills_6_Mo['Deutsche Bank Securities, inc.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_6_Mo['DePrince & Associates'] = Treas_Bills_6_Mo['DePrince & Associates'].combine_first(Treas_Bills_6_Mo['DePrince & Assoc.'])
Treas_Bills_6_Mo['DePrince & Associates'] = Treas_Bills_6_Mo['DePrince & Associates'].combine_first(Treas_Bills_6_Mo['DePrince Associates'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('DePrince & Assoc.', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('DePrince Associates', axis=1)

Treas_Bills_6_Mo['Aeltus Investment'] = Treas_Bills_6_Mo['Aeltus Investment'].combine_first(Treas_Bills_6_Mo['Aeitus Investment'])
Treas_Bills_6_Mo['Aeltus Investment'] = Treas_Bills_6_Mo['Aeltus Investment'].combine_first(Treas_Bills_6_Mo['Aeltus investment'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Aeitus Investment', axis=1)
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Aeltus investment', axis=1)

Treas_Bills_6_Mo['ASB Capital Management'] = Treas_Bills_6_Mo['ASB Capital Management'].combine_first(Treas_Bills_6_Mo['ASB Captial Management'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('ASB Captial Management', axis=1)

Treas_Bills_6_Mo['BMO Nesbitt Burns'] = Treas_Bills_6_Mo['BMO Nesbitt Burns'].combine_first(Treas_Bills_6_Mo['BMC Nesbitt Burns'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_6_Mo['Banc One Invest. Advisors'] = Treas_Bills_6_Mo['Banc One Invest. Advisors'].combine_first(Treas_Bills_6_Mo['Banc One invest. Advisors'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_6_Mo['Banc of America Securities'] = Treas_Bills_6_Mo['Banc of America Securities'].combine_first(Treas_Bills_6_Mo['Banc of Amercia Securities'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_6_Mo['Banc of America Securities'] = Treas_Bills_6_Mo['Banc of America Securities'].combine_first(Treas_Bills_6_Mo['Banc of America Securities, LLC'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_6_Mo['Bank of America Merrill Lynch'] = Treas_Bills_6_Mo['Bank of America Merrill Lynch'].combine_first(Treas_Bills_6_Mo['Bank of America-Merrill Lynch'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_6_Mo['Bank of America Merrill Lynch'] = Treas_Bills_6_Mo['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_6_Mo['Banc of America-Merrill Lynch'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_6_Mo['Bank of Toyko-Mitsubishi'] = Treas_Bills_6_Mo['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_6_Mo['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_6_Mo['Barclays'] = Treas_Bills_6_Mo['Barclays'].combine_first(Treas_Bills_6_Mo['Barclays Capital'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Barclays Capital', axis=1)

Treas_Bills_6_Mo['Bear Stearns'] = Treas_Bills_6_Mo['Bear Stearns'].combine_first(Treas_Bills_6_Mo['Bear Stearns & Co.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_6_Mo['Bear Stearns'] = Treas_Bills_6_Mo['Bear Stearns'].combine_first(Treas_Bills_6_Mo['Bear Steams & Co.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Bear Steams & Co.', axis=1)

Treas_Bills_6_Mo['Camilli Economics'] = Treas_Bills_6_Mo['Camilli Economics'].combine_first(Treas_Bills_6_Mo['Camilli Economics LLC'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Camilli Economics LLC', axis=1)
Treas_Bills_6_Mo['Camilli Economics'] = Treas_Bills_6_Mo['Camilli Economics'].combine_first(Treas_Bills_6_Mo['Camilli, Kathleen'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Camilli, Kathleen', axis=1)

Treas_Bills_6_Mo['Citibank Global Asset Mgmt'] = Treas_Bills_6_Mo['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_6_Mo['Citibank Global Asset Mgmt.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_6_Mo['Citibank Global Asset Mgmt'] = Treas_Bills_6_Mo['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_6_Mo['Citigroup Asset Management'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Citigroup Asset Management', axis=1)

Treas_Bills_6_Mo['ClearView Economics'] = Treas_Bills_6_Mo['ClearView Economics'].combine_first(Treas_Bills_6_Mo['ClearView Associates'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('ClearView Associates', axis=1)
Treas_Bills_6_Mo['ClearView Economics'] = Treas_Bills_6_Mo['ClearView Economics'].combine_first(Treas_Bills_6_Mo['ClearView  Economics'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('ClearView  Economics', axis=1)

Treas_Bills_6_Mo['Comerica Bank'] = Treas_Bills_6_Mo['Comerica Bank'].combine_first(Treas_Bills_6_Mo['Commerica'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Commerica', axis=1)

Treas_Bills_6_Mo['Cycledata Corp.'] = Treas_Bills_6_Mo['Cycledata Corp.'].combine_first(Treas_Bills_6_Mo['Cycledata corp.'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Cycledata corp.', axis=1)

Treas_Bills_6_Mo['Daiwa Capital Markets America'] = Treas_Bills_6_Mo['Daiwa Capital Markets America'].combine_first(Treas_Bills_6_Mo['Daiw a Capital Markets America'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_6_Mo['Daiwa Capital Markets America'] = Treas_Bills_6_Mo['Daiwa Capital Markets America'].combine_first(Treas_Bills_6_Mo['Daiwa Securities America'])
Treas_Bills_6_Mo = Treas_Bills_6_Mo.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_1_Yr['Moody\'s Analytics'] = Treas_Bills_1_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_1_Yr['Moody\'s Capital Markets'])
Treas_Bills_1_Yr['Moody\'s Analytics'] = Treas_Bills_1_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_1_Yr['Moody\'s Capital Markets Group'])
Treas_Bills_1_Yr['Moody\'s Analytics'] = Treas_Bills_1_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_1_Yr['Moody\'s Econmy.com'])
Treas_Bills_1_Yr['Moody\'s Analytics'] = Treas_Bills_1_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_1_Yr['Moody\'s Economy.com'])
Treas_Bills_1_Yr['Moody\'s Analytics'] = Treas_Bills_1_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_1_Yr['Moody\'s Investors Service'])
Treas_Bills_1_Yr['Moody\'s Analytics'] = Treas_Bills_1_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_1_Yr['Moodys Investors Service'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Moodys Investors Service', axis=1)

Treas_Bills_1_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_1_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_1_Yr['Nat\'l Assn, of Realtors'])
Treas_Bills_1_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_1_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_1_Yr['Nat\'I Assn, of Realtors'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_1_Yr['National City Bank'] = Treas_Bills_1_Yr['National City Bank'].combine_first(Treas_Bills_1_Yr['National City Corporation'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('National City Corporation', axis=1)

Treas_Bills_1_Yr['Nomura Securities Inc.'] = Treas_Bills_1_Yr['Nomura Securities Inc.'].combine_first(Treas_Bills_1_Yr['Nomura Securities, Inc.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_1_Yr['October Consensus'] = Treas_Bills_1_Yr['October Consensus'].combine_first(Treas_Bills_1_Yr['Octoberber Consensus'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Octoberber Consensus', axis=1)

Treas_Bills_1_Yr['PNC Bank Corp.'] = Treas_Bills_1_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_1_Yr['PNC Financial Services'])
Treas_Bills_1_Yr['PNC Bank Corp.'] = Treas_Bills_1_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_1_Yr['PNC Financial Services Corp.'])
Treas_Bills_1_Yr['PNC Bank Corp.'] = Treas_Bills_1_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_1_Yr['PNC Financial Services Group'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('PNC Financial Services', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('PNC Financial Services Group', axis=1)

Treas_Bills_1_Yr['Prudential Securities'] = Treas_Bills_1_Yr['Prudential Securities'].combine_first(Treas_Bills_1_Yr['Prudential Equity Group LLC'])
Treas_Bills_1_Yr['Prudential Securities'] = Treas_Bills_1_Yr['Prudential Securities'].combine_first(Treas_Bills_1_Yr['Prudential Insurance Co.'])
Treas_Bills_1_Yr['Prudential Securities'] = Treas_Bills_1_Yr['Prudential Securities'].combine_first(Treas_Bills_1_Yr['Prudential Financial'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Prudential Financial', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_1_Yr['RBS Greenwich Capital Econ.'] = Treas_Bills_1_Yr['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_1_Yr['RBS Securities'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('RBS Securities', axis=1)

Treas_Bills_1_Yr['RBC'] = Treas_Bills_1_Yr['RBC'].combine_first(Treas_Bills_1_Yr['RBC Capital Markets'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('RBC Capital Markets', axis=1)

Treas_Bills_1_Yr['RDQ Economics'] = Treas_Bills_1_Yr['RDQ Economics'].combine_first(Treas_Bills_1_Yr['RDQ'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('RDQ', axis=1)

Treas_Bills_1_Yr['RidgeWorth Investments'] = Treas_Bills_1_Yr['RidgeWorth Investments'].combine_first(Treas_Bills_1_Yr['RidgeWorth Capital Management'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_1_Yr['S&P Global'] = Treas_Bills_1_Yr['S&P Global'].combine_first(Treas_Bills_1_Yr['S&P Global Market Intelligence'])
Treas_Bills_1_Yr['S&P Global'] = Treas_Bills_1_Yr['S&P Global'].combine_first(Treas_Bills_1_Yr['S&P Global Ratings'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('S&P Global Ratings', axis=1)

Treas_Bills_1_Yr['Scotiabank Group'] = Treas_Bills_1_Yr['Scotiabank Group'].combine_first(Treas_Bills_1_Yr['Scotiabank'])
Treas_Bills_1_Yr['Scotiabank Group'] = Treas_Bills_1_Yr['Scotiabank Group'].combine_first(Treas_Bills_1_Yr['Scotia Capital'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Scotia Capital', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Scotiabank', axis=1)

Treas_Bills_1_Yr['September Consensus'] = Treas_Bills_1_Yr['September Consensus'].combine_first(Treas_Bills_1_Yr['Sept. Consensus'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Sept. Consensus', axis=1)

Treas_Bills_1_Yr['Standard & Poor\'s'] = Treas_Bills_1_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_1_Yr['Standard & Poor\'s Corp.'])
Treas_Bills_1_Yr['Standard & Poor\'s'] = Treas_Bills_1_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_1_Yr['Standard & Poors'])
Treas_Bills_1_Yr['Standard & Poor\'s'] = Treas_Bills_1_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_1_Yr['Standard & Poor’s Corp.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Standard & Poors', axis=1)

Treas_Bills_1_Yr['Swiss Re'] = Treas_Bills_1_Yr['Swiss Re'].combine_first(Treas_Bills_1_Yr['Sw iss Re'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Sw iss Re', axis=1)

Treas_Bills_1_Yr['Thredgold Economics'] = Treas_Bills_1_Yr['Thredgold Economics'].combine_first(Treas_Bills_1_Yr['Thredgold Economic Assoc.'])
Treas_Bills_1_Yr['Thredgold Economics'] = Treas_Bills_1_Yr['Thredgold Economics'].combine_first(Treas_Bills_1_Yr['Thredgota Economic Assoc.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_1_Yr['Tokai Bank, Ltd.'] = Treas_Bills_1_Yr['Tokai Bank, Ltd.'].combine_first(Treas_Bills_1_Yr['Tokai Bank, Lid.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_1_Yr['Wayne Hummer & Co.'] = Treas_Bills_1_Yr['Wayne Hummer & Co.'].combine_first(Treas_Bills_1_Yr['Wayne Hummer Investments'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_1_Yr['Wachovia'] = Treas_Bills_1_Yr['Wachovia'].combine_first(Treas_Bills_1_Yr['Wachovia Securities'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Wachovia Securities', axis=1)

Treas_Bills_1_Yr['Wells Fargo'] = Treas_Bills_1_Yr['Wells Fargo'].combine_first(Treas_Bills_1_Yr['Wells Capital Management'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Wells Capital Management', axis=1)

Treas_Bills_1_Yr['Woodworth Holdings'] = Treas_Bills_1_Yr['Woodworth Holdings'].combine_first(Treas_Bills_1_Yr['Woodw orth Holdings'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Woodw orth Holdings', axis=1)

Treas_Bills_1_Yr['independent Economic Advisory'] = Treas_Bills_1_Yr['independent Economic Advisory'].combine_first(Treas_Bills_1_Yr['independent Econ. Advisory'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('independent Econ. Advisory', axis=1)

Treas_Bills_1_Yr['MacroFin Analytics'] = Treas_Bills_1_Yr['MacroFin Analytics'].combine_first(Treas_Bills_1_Yr['MacroFin Analytics & RBS'])
Treas_Bills_1_Yr['MacroFin Analytics'] = Treas_Bills_1_Yr['MacroFin Analytics'].combine_first(Treas_Bills_1_Yr['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_1_Yr['MacroFin Analytics'] = Treas_Bills_1_Yr['MacroFin Analytics'].combine_first(Treas_Bills_1_Yr['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_1_Yr['Mesirow Financial'] = Treas_Bills_1_Yr['Mesirow  Financial'].combine_first(Treas_Bills_1_Yr['Mesirow  Financial'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Mesirow  Financial', axis=1)

Treas_Bills_1_Yr['Merrill Lynch'] = Treas_Bills_1_Yr['Merrill Lynch'].combine_first(Treas_Bills_1_Yr['Merrill Lynch Economics'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_1_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_1_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_1_Yr['LaSalle Nat\'l Bank'])
Treas_Bills_1_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_1_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_1_Yr['LaSalle Natl Bank'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_1_Yr['Kellner Economic Advisers'] = Treas_Bills_1_Yr['Kellner Economic Advisers'].combine_first(Treas_Bills_1_Yr['Keller Economic Advisers'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Keller Economic Advisers', axis=1)

Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['J.P. Morgan Chase'])
Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['J.P. Morgan Chase'])
Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['JPMorgan Asset Mgt.'])
Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['JPMorgan Privare Client Services'])
Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_1_Yr['J.P. Morgan'] = Treas_Bills_1_Yr['J.P. Morgan'].combine_first(Treas_Bills_1_Yr['JPMorgan Private Banking'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('J.P. MorganChase', axis=1)

Treas_Bills_1_Yr['Independent Economic Advisory'] = Treas_Bills_1_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_1_Yr['Independent Econ. Advisory'])
Treas_Bills_1_Yr['Independent Economic Advisory'] = Treas_Bills_1_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_1_Yr['Investment Economics Advisory'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_1_Yr['ING'] = Treas_Bills_1_Yr['ING'].combine_first(Treas_Bills_1_Yr['ING Investment Mgt.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('ING Investment Mgt.', axis=1)

Treas_Bills_1_Yr['Huntington Nat\'I Bank'] = Treas_Bills_1_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_1_Yr['Huntington Nat\'l Bank'])
Treas_Bills_1_Yr['Huntington Nat\'I Bank'] = Treas_Bills_1_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_1_Yr['Huntington Natl Bank'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Huntington Natl Bank', axis=1)

Treas_Bills_1_Yr['Goldman Sachs'] = Treas_Bills_1_Yr['Goldman Sachs'].combine_first(Treas_Bills_1_Yr['Goldman Sachs & Co,'])
Treas_Bills_1_Yr['Goldman Sachs'] = Treas_Bills_1_Yr['Goldman Sachs'].combine_first(Treas_Bills_1_Yr['Goldman Sachs & Co.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_1_Yr['Genetski Financial Advisors'] = Treas_Bills_1_Yr['Genetski Financial Advisors'].combine_first(Treas_Bills_1_Yr['Genetski.com'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Genetski.com', axis=1)

Treas_Bills_1_Yr['Fannie Mae'] = Treas_Bills_1_Yr['Fannie Mae'].combine_first(Treas_Bills_1_Yr['Fannie Mae '])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Fannie Mae ', axis=1)

Treas_Bills_1_Yr['Deutsche Bank Securities'] = Treas_Bills_1_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_1_Yr['Deutsche Bank Securities, Inc.'])
Treas_Bills_1_Yr['Deutsche Bank Securities'] = Treas_Bills_1_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_1_Yr['Deutsche Bank Securities, inc.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_1_Yr['DePrince & Associates'] = Treas_Bills_1_Yr['DePrince & Associates'].combine_first(Treas_Bills_1_Yr['DePrince & Assoc.'])
Treas_Bills_1_Yr['DePrince & Associates'] = Treas_Bills_1_Yr['DePrince & Associates'].combine_first(Treas_Bills_1_Yr['DePrince Associates'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('DePrince & Assoc.', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('DePrince Associates', axis=1)

Treas_Bills_1_Yr['Aeltus Investment'] = Treas_Bills_1_Yr['Aeltus Investment'].combine_first(Treas_Bills_1_Yr['Aeitus Investment'])
Treas_Bills_1_Yr['Aeltus Investment'] = Treas_Bills_1_Yr['Aeltus Investment'].combine_first(Treas_Bills_1_Yr['Aeltus investment'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Aeitus Investment', axis=1)
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Aeltus investment', axis=1)

Treas_Bills_1_Yr['ASB Capital Management'] = Treas_Bills_1_Yr['ASB Capital Management'].combine_first(Treas_Bills_1_Yr['ASB Captial Management'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('ASB Captial Management', axis=1)

Treas_Bills_1_Yr['BMO Nesbitt Burns'] = Treas_Bills_1_Yr['BMO Nesbitt Burns'].combine_first(Treas_Bills_1_Yr['BMC Nesbitt Burns'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_1_Yr['Banc One Invest. Advisors'] = Treas_Bills_1_Yr['Banc One Invest. Advisors'].combine_first(Treas_Bills_1_Yr['Banc One invest. Advisors'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_1_Yr['Banc of America Securities'] = Treas_Bills_1_Yr['Banc of America Securities'].combine_first(Treas_Bills_1_Yr['Banc of Amercia Securities'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_1_Yr['Banc of America Securities'] = Treas_Bills_1_Yr['Banc of America Securities'].combine_first(Treas_Bills_1_Yr['Banc of America Securities, LLC'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_1_Yr['Bank of America Merrill Lynch'] = Treas_Bills_1_Yr['Bank of America Merrill Lynch'].combine_first(Treas_Bills_1_Yr['Bank of America-Merrill Lynch'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_1_Yr['Bank of America Merrill Lynch'] = Treas_Bills_1_Yr['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_1_Yr['Banc of America-Merrill Lynch'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_1_Yr['Bank of Toyko-Mitsubishi'] = Treas_Bills_1_Yr['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_1_Yr['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_1_Yr['Barclays'] = Treas_Bills_1_Yr['Barclays'].combine_first(Treas_Bills_1_Yr['Barclays Capital'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Barclays Capital', axis=1)

Treas_Bills_1_Yr['Bear Stearns'] = Treas_Bills_1_Yr['Bear Stearns'].combine_first(Treas_Bills_1_Yr['Bear Stearns & Co.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_1_Yr['Bear Stearns'] = Treas_Bills_1_Yr['Bear Stearns'].combine_first(Treas_Bills_1_Yr['Bear Steams & Co.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Bear Steams & Co.', axis=1)

Treas_Bills_1_Yr['Camilli Economics'] = Treas_Bills_1_Yr['Camilli Economics'].combine_first(Treas_Bills_1_Yr['Camilli Economics LLC'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Camilli Economics LLC', axis=1)
Treas_Bills_1_Yr['Camilli Economics'] = Treas_Bills_1_Yr['Camilli Economics'].combine_first(Treas_Bills_1_Yr['Camilli, Kathleen'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Camilli, Kathleen', axis=1)

Treas_Bills_1_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_1_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_1_Yr['Citibank Global Asset Mgmt.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_1_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_1_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_1_Yr['Citigroup Asset Management'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Citigroup Asset Management', axis=1)

Treas_Bills_1_Yr['ClearView Economics'] = Treas_Bills_1_Yr['ClearView Economics'].combine_first(Treas_Bills_1_Yr['ClearView Associates'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('ClearView Associates', axis=1)
Treas_Bills_1_Yr['ClearView Economics'] = Treas_Bills_1_Yr['ClearView Economics'].combine_first(Treas_Bills_1_Yr['ClearView  Economics'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('ClearView  Economics', axis=1)

Treas_Bills_1_Yr['Comerica Bank'] = Treas_Bills_1_Yr['Comerica Bank'].combine_first(Treas_Bills_1_Yr['Commerica'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Commerica', axis=1)

Treas_Bills_1_Yr['Cycledata Corp.'] = Treas_Bills_1_Yr['Cycledata Corp.'].combine_first(Treas_Bills_1_Yr['Cycledata corp.'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Cycledata corp.', axis=1)

Treas_Bills_1_Yr['Daiwa Capital Markets America'] = Treas_Bills_1_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_1_Yr['Daiw a Capital Markets America'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_1_Yr['Daiwa Capital Markets America'] = Treas_Bills_1_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_1_Yr['Daiwa Securities America'])
Treas_Bills_1_Yr = Treas_Bills_1_Yr.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_2_Yr['Moody\'s Analytics'] = Treas_Bills_2_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_2_Yr['Moody\'s Capital Markets'])
Treas_Bills_2_Yr['Moody\'s Analytics'] = Treas_Bills_2_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_2_Yr['Moody\'s Capital Markets Group'])
Treas_Bills_2_Yr['Moody\'s Analytics'] = Treas_Bills_2_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_2_Yr['Moody\'s Econmy.com'])
Treas_Bills_2_Yr['Moody\'s Analytics'] = Treas_Bills_2_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_2_Yr['Moody\'s Economy.com'])
Treas_Bills_2_Yr['Moody\'s Analytics'] = Treas_Bills_2_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_2_Yr['Moody\'s Investors Service'])
Treas_Bills_2_Yr['Moody\'s Analytics'] = Treas_Bills_2_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_2_Yr['Moodys Investors Service'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Moodys Investors Service', axis=1)

Treas_Bills_2_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_2_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_2_Yr['Nat\'l Assn, of Realtors'])
Treas_Bills_2_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_2_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_2_Yr['Nat\'I Assn, of Realtors'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_2_Yr['National City Bank'] = Treas_Bills_2_Yr['National City Bank'].combine_first(Treas_Bills_2_Yr['National City Corporation'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('National City Corporation', axis=1)

Treas_Bills_2_Yr['Nomura Securities Inc.'] = Treas_Bills_2_Yr['Nomura Securities Inc.'].combine_first(Treas_Bills_2_Yr['Nomura Securities, Inc.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_2_Yr['October Consensus'] = Treas_Bills_2_Yr['October Consensus'].combine_first(Treas_Bills_2_Yr['Octoberber Consensus'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Octoberber Consensus', axis=1)

Treas_Bills_2_Yr['PNC Bank Corp.'] = Treas_Bills_2_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_2_Yr['PNC Financial Services'])
Treas_Bills_2_Yr['PNC Bank Corp.'] = Treas_Bills_2_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_2_Yr['PNC Financial Services Corp.'])
Treas_Bills_2_Yr['PNC Bank Corp.'] = Treas_Bills_2_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_2_Yr['PNC Financial Services Group'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('PNC Financial Services', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('PNC Financial Services Group', axis=1)

Treas_Bills_2_Yr['Prudential Securities'] = Treas_Bills_2_Yr['Prudential Securities'].combine_first(Treas_Bills_2_Yr['Prudential Equity Group LLC'])
Treas_Bills_2_Yr['Prudential Securities'] = Treas_Bills_2_Yr['Prudential Securities'].combine_first(Treas_Bills_2_Yr['Prudential Insurance Co.'])
Treas_Bills_2_Yr['Prudential Securities'] = Treas_Bills_2_Yr['Prudential Securities'].combine_first(Treas_Bills_2_Yr['Prudential Financial'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Prudential Financial', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_2_Yr['RBS Greenwich Capital Econ.'] = Treas_Bills_2_Yr['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_2_Yr['RBS Securities'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('RBS Securities', axis=1)

Treas_Bills_2_Yr['RBC'] = Treas_Bills_2_Yr['RBC'].combine_first(Treas_Bills_2_Yr['RBC Capital Markets'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('RBC Capital Markets', axis=1)

Treas_Bills_2_Yr['RDQ Economics'] = Treas_Bills_2_Yr['RDQ Economics'].combine_first(Treas_Bills_2_Yr['RDQ'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('RDQ', axis=1)

Treas_Bills_2_Yr['RidgeWorth Investments'] = Treas_Bills_2_Yr['RidgeWorth Investments'].combine_first(Treas_Bills_2_Yr['RidgeWorth Capital Management'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_2_Yr['S&P Global'] = Treas_Bills_2_Yr['S&P Global'].combine_first(Treas_Bills_2_Yr['S&P Global Market Intelligence'])
Treas_Bills_2_Yr['S&P Global'] = Treas_Bills_2_Yr['S&P Global'].combine_first(Treas_Bills_2_Yr['S&P Global Ratings'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('S&P Global Ratings', axis=1)

Treas_Bills_2_Yr['Scotiabank Group'] = Treas_Bills_2_Yr['Scotiabank Group'].combine_first(Treas_Bills_2_Yr['Scotiabank'])
Treas_Bills_2_Yr['Scotiabank Group'] = Treas_Bills_2_Yr['Scotiabank Group'].combine_first(Treas_Bills_2_Yr['Scotia Capital'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Scotia Capital', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Scotiabank', axis=1)

Treas_Bills_2_Yr['September Consensus'] = Treas_Bills_2_Yr['September Consensus'].combine_first(Treas_Bills_2_Yr['Sept. Consensus'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Sept. Consensus', axis=1)

Treas_Bills_2_Yr['Standard & Poor\'s'] = Treas_Bills_2_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_2_Yr['Standard & Poor\'s Corp.'])
Treas_Bills_2_Yr['Standard & Poor\'s'] = Treas_Bills_2_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_2_Yr['Standard & Poors'])
Treas_Bills_2_Yr['Standard & Poor\'s'] = Treas_Bills_2_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_2_Yr['Standard & Poor’s Corp.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Standard & Poors', axis=1)

Treas_Bills_2_Yr['Swiss Re'] = Treas_Bills_2_Yr['Swiss Re'].combine_first(Treas_Bills_2_Yr['Sw iss Re'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Sw iss Re', axis=1)

Treas_Bills_2_Yr['Thredgold Economics'] = Treas_Bills_2_Yr['Thredgold Economics'].combine_first(Treas_Bills_2_Yr['Thredgold Economic Assoc.'])
Treas_Bills_2_Yr['Thredgold Economics'] = Treas_Bills_2_Yr['Thredgold Economics'].combine_first(Treas_Bills_2_Yr['Thredgota Economic Assoc.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_2_Yr['Tokai Bank, Ltd.'] = Treas_Bills_2_Yr['Tokai Bank, Ltd.'].combine_first(Treas_Bills_2_Yr['Tokai Bank, Lid.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_2_Yr['Wayne Hummer & Co.'] = Treas_Bills_2_Yr['Wayne Hummer & Co.'].combine_first(Treas_Bills_2_Yr['Wayne Hummer Investments'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_2_Yr['Wachovia'] = Treas_Bills_2_Yr['Wachovia'].combine_first(Treas_Bills_2_Yr['Wachovia Securities'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Wachovia Securities', axis=1)

Treas_Bills_2_Yr['Wells Fargo'] = Treas_Bills_2_Yr['Wells Fargo'].combine_first(Treas_Bills_2_Yr['Wells Capital Management'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Wells Capital Management', axis=1)

Treas_Bills_2_Yr['Woodworth Holdings'] = Treas_Bills_2_Yr['Woodworth Holdings'].combine_first(Treas_Bills_2_Yr['Woodw orth Holdings'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Woodw orth Holdings', axis=1)

Treas_Bills_2_Yr['independent Economic Advisory'] = Treas_Bills_2_Yr['independent Economic Advisory'].combine_first(Treas_Bills_2_Yr['independent Econ. Advisory'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('independent Econ. Advisory', axis=1)

Treas_Bills_2_Yr['MacroFin Analytics'] = Treas_Bills_2_Yr['MacroFin Analytics'].combine_first(Treas_Bills_2_Yr['MacroFin Analytics & RBS'])
Treas_Bills_2_Yr['MacroFin Analytics'] = Treas_Bills_2_Yr['MacroFin Analytics'].combine_first(Treas_Bills_2_Yr['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_2_Yr['MacroFin Analytics'] = Treas_Bills_2_Yr['MacroFin Analytics'].combine_first(Treas_Bills_2_Yr['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_2_Yr['Mesirow Financial'] = Treas_Bills_2_Yr['Mesirow  Financial'].combine_first(Treas_Bills_2_Yr['Mesirow  Financial'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Mesirow  Financial', axis=1)

Treas_Bills_2_Yr['Merrill Lynch'] = Treas_Bills_2_Yr['Merrill Lynch'].combine_first(Treas_Bills_2_Yr['Merrill Lynch Economics'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_2_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_2_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_2_Yr['LaSalle Nat\'l Bank'])
Treas_Bills_2_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_2_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_2_Yr['LaSalle Natl Bank'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_2_Yr['Kellner Economic Advisers'] = Treas_Bills_2_Yr['Kellner Economic Advisers'].combine_first(Treas_Bills_2_Yr['Keller Economic Advisers'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Keller Economic Advisers', axis=1)

Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['J.P. Morgan Chase'])
Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['J.P. Morgan Chase'])
Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['JPMorgan Asset Mgt.'])
Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['JPMorgan Privare Client Services'])
Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_2_Yr['J.P. Morgan'] = Treas_Bills_2_Yr['J.P. Morgan'].combine_first(Treas_Bills_2_Yr['JPMorgan Private Banking'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('J.P. MorganChase', axis=1)

Treas_Bills_2_Yr['Independent Economic Advisory'] = Treas_Bills_2_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_2_Yr['Independent Econ. Advisory'])
Treas_Bills_2_Yr['Independent Economic Advisory'] = Treas_Bills_2_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_2_Yr['Investment Economics Advisory'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_2_Yr['ING'] = Treas_Bills_2_Yr['ING'].combine_first(Treas_Bills_2_Yr['ING Investment Mgt.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('ING Investment Mgt.', axis=1)

Treas_Bills_2_Yr['Huntington Nat\'I Bank'] = Treas_Bills_2_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_2_Yr['Huntington Nat\'l Bank'])
Treas_Bills_2_Yr['Huntington Nat\'I Bank'] = Treas_Bills_2_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_2_Yr['Huntington Natl Bank'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Huntington Natl Bank', axis=1)

Treas_Bills_2_Yr['Goldman Sachs'] = Treas_Bills_2_Yr['Goldman Sachs'].combine_first(Treas_Bills_2_Yr['Goldman Sachs & Co,'])
Treas_Bills_2_Yr['Goldman Sachs'] = Treas_Bills_2_Yr['Goldman Sachs'].combine_first(Treas_Bills_2_Yr['Goldman Sachs & Co.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_2_Yr['Genetski Financial Advisors'] = Treas_Bills_2_Yr['Genetski Financial Advisors'].combine_first(Treas_Bills_2_Yr['Genetski.com'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Genetski.com', axis=1)

Treas_Bills_2_Yr['Fannie Mae'] = Treas_Bills_2_Yr['Fannie Mae'].combine_first(Treas_Bills_2_Yr['Fannie Mae '])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Fannie Mae ', axis=1)

Treas_Bills_2_Yr['Deutsche Bank Securities'] = Treas_Bills_2_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_2_Yr['Deutsche Bank Securities, Inc.'])
Treas_Bills_2_Yr['Deutsche Bank Securities'] = Treas_Bills_2_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_2_Yr['Deutsche Bank Securities, inc.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_2_Yr['DePrince & Associates'] = Treas_Bills_2_Yr['DePrince & Associates'].combine_first(Treas_Bills_2_Yr['DePrince & Assoc.'])
Treas_Bills_2_Yr['DePrince & Associates'] = Treas_Bills_2_Yr['DePrince & Associates'].combine_first(Treas_Bills_2_Yr['DePrince Associates'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('DePrince & Assoc.', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('DePrince Associates', axis=1)

Treas_Bills_2_Yr['Aeltus Investment'] = Treas_Bills_2_Yr['Aeltus Investment'].combine_first(Treas_Bills_2_Yr['Aeitus Investment'])
Treas_Bills_2_Yr['Aeltus Investment'] = Treas_Bills_2_Yr['Aeltus Investment'].combine_first(Treas_Bills_2_Yr['Aeltus investment'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Aeitus Investment', axis=1)
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Aeltus investment', axis=1)

Treas_Bills_2_Yr['ASB Capital Management'] = Treas_Bills_2_Yr['ASB Capital Management'].combine_first(Treas_Bills_2_Yr['ASB Captial Management'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('ASB Captial Management', axis=1)

Treas_Bills_2_Yr['BMO Nesbitt Burns'] = Treas_Bills_2_Yr['BMO Nesbitt Burns'].combine_first(Treas_Bills_2_Yr['BMC Nesbitt Burns'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_2_Yr['Banc One Invest. Advisors'] = Treas_Bills_2_Yr['Banc One Invest. Advisors'].combine_first(Treas_Bills_2_Yr['Banc One invest. Advisors'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_2_Yr['Banc of America Securities'] = Treas_Bills_2_Yr['Banc of America Securities'].combine_first(Treas_Bills_2_Yr['Banc of Amercia Securities'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_2_Yr['Banc of America Securities'] = Treas_Bills_2_Yr['Banc of America Securities'].combine_first(Treas_Bills_2_Yr['Banc of America Securities, LLC'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_2_Yr['Bank of America Merrill Lynch'] = Treas_Bills_2_Yr['Bank of America Merrill Lynch'].combine_first(Treas_Bills_2_Yr['Bank of America-Merrill Lynch'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_2_Yr['Bank of America Merrill Lynch'] = Treas_Bills_2_Yr['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_2_Yr['Banc of America-Merrill Lynch'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_2_Yr['Bank of Toyko-Mitsubishi'] = Treas_Bills_2_Yr['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_2_Yr['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_2_Yr['Barclays'] = Treas_Bills_2_Yr['Barclays'].combine_first(Treas_Bills_2_Yr['Barclays Capital'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Barclays Capital', axis=1)

Treas_Bills_2_Yr['Bear Stearns'] = Treas_Bills_2_Yr['Bear Stearns'].combine_first(Treas_Bills_2_Yr['Bear Stearns & Co.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_2_Yr['Bear Stearns'] = Treas_Bills_2_Yr['Bear Stearns'].combine_first(Treas_Bills_2_Yr['Bear Steams & Co.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Bear Steams & Co.', axis=1)

Treas_Bills_2_Yr['Camilli Economics'] = Treas_Bills_2_Yr['Camilli Economics'].combine_first(Treas_Bills_2_Yr['Camilli Economics LLC'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Camilli Economics LLC', axis=1)
Treas_Bills_2_Yr['Camilli Economics'] = Treas_Bills_2_Yr['Camilli Economics'].combine_first(Treas_Bills_2_Yr['Camilli, Kathleen'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Camilli, Kathleen', axis=1)

Treas_Bills_2_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_2_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_2_Yr['Citibank Global Asset Mgmt.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_2_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_2_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_2_Yr['Citigroup Asset Management'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Citigroup Asset Management', axis=1)

Treas_Bills_2_Yr['ClearView Economics'] = Treas_Bills_2_Yr['ClearView Economics'].combine_first(Treas_Bills_2_Yr['ClearView Associates'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('ClearView Associates', axis=1)
Treas_Bills_2_Yr['ClearView Economics'] = Treas_Bills_2_Yr['ClearView Economics'].combine_first(Treas_Bills_2_Yr['ClearView  Economics'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('ClearView  Economics', axis=1)

Treas_Bills_2_Yr['Comerica Bank'] = Treas_Bills_2_Yr['Comerica Bank'].combine_first(Treas_Bills_2_Yr['Commerica'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Commerica', axis=1)

Treas_Bills_2_Yr['Cycledata Corp.'] = Treas_Bills_2_Yr['Cycledata Corp.'].combine_first(Treas_Bills_2_Yr['Cycledata corp.'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Cycledata corp.', axis=1)

Treas_Bills_2_Yr['Daiwa Capital Markets America'] = Treas_Bills_2_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_2_Yr['Daiw a Capital Markets America'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_2_Yr['Daiwa Capital Markets America'] = Treas_Bills_2_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_2_Yr['Daiwa Securities America'])
Treas_Bills_2_Yr = Treas_Bills_2_Yr.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_5_Yr['Moody\'s Analytics'] = Treas_Bills_5_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_5_Yr['Moody\'s Capital Markets'])
Treas_Bills_5_Yr['Moody\'s Analytics'] = Treas_Bills_5_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_5_Yr['Moody\'s Capital Markets Group'])
Treas_Bills_5_Yr['Moody\'s Analytics'] = Treas_Bills_5_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_5_Yr['Moody\'s Econmy.com'])
Treas_Bills_5_Yr['Moody\'s Analytics'] = Treas_Bills_5_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_5_Yr['Moody\'s Economy.com'])
Treas_Bills_5_Yr['Moody\'s Analytics'] = Treas_Bills_5_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_5_Yr['Moody\'s Investors Service'])
Treas_Bills_5_Yr['Moody\'s Analytics'] = Treas_Bills_5_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_5_Yr['Moodys Investors Service'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Moodys Investors Service', axis=1)

Treas_Bills_5_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_5_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_5_Yr['Nat\'l Assn, of Realtors'])
Treas_Bills_5_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_5_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_5_Yr['Nat\'I Assn, of Realtors'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_5_Yr['National City Bank'] = Treas_Bills_5_Yr['National City Bank'].combine_first(Treas_Bills_5_Yr['National City Corporation'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('National City Corporation', axis=1)

Treas_Bills_5_Yr['Nomura Securities Inc.'] = Treas_Bills_5_Yr['Nomura Securities Inc.'].combine_first(Treas_Bills_5_Yr['Nomura Securities, Inc.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_5_Yr['October Consensus'] = Treas_Bills_5_Yr['October Consensus'].combine_first(Treas_Bills_5_Yr['Octoberber Consensus'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Octoberber Consensus', axis=1)

Treas_Bills_5_Yr['PNC Bank Corp.'] = Treas_Bills_5_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_5_Yr['PNC Financial Services'])
Treas_Bills_5_Yr['PNC Bank Corp.'] = Treas_Bills_5_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_5_Yr['PNC Financial Services Corp.'])
Treas_Bills_5_Yr['PNC Bank Corp.'] = Treas_Bills_5_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_5_Yr['PNC Financial Services Group'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('PNC Financial Services', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('PNC Financial Services Group', axis=1)

Treas_Bills_5_Yr['Prudential Securities'] = Treas_Bills_5_Yr['Prudential Securities'].combine_first(Treas_Bills_5_Yr['Prudential Equity Group LLC'])
Treas_Bills_5_Yr['Prudential Securities'] = Treas_Bills_5_Yr['Prudential Securities'].combine_first(Treas_Bills_5_Yr['Prudential Insurance Co.'])
Treas_Bills_5_Yr['Prudential Securities'] = Treas_Bills_5_Yr['Prudential Securities'].combine_first(Treas_Bills_5_Yr['Prudential Financial'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Prudential Financial', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_5_Yr['RBS Greenwich Capital Econ.'] = Treas_Bills_5_Yr['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_5_Yr['RBS Securities'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('RBS Securities', axis=1)

Treas_Bills_5_Yr['RBC'] = Treas_Bills_5_Yr['RBC'].combine_first(Treas_Bills_5_Yr['RBC Capital Markets'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('RBC Capital Markets', axis=1)

Treas_Bills_5_Yr['RDQ Economics'] = Treas_Bills_5_Yr['RDQ Economics'].combine_first(Treas_Bills_5_Yr['RDQ'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('RDQ', axis=1)

Treas_Bills_5_Yr['RidgeWorth Investments'] = Treas_Bills_5_Yr['RidgeWorth Investments'].combine_first(Treas_Bills_5_Yr['RidgeWorth Capital Management'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_5_Yr['S&P Global'] = Treas_Bills_5_Yr['S&P Global'].combine_first(Treas_Bills_5_Yr['S&P Global Market Intelligence'])
Treas_Bills_5_Yr['S&P Global'] = Treas_Bills_5_Yr['S&P Global'].combine_first(Treas_Bills_5_Yr['S&P Global Ratings'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('S&P Global Ratings', axis=1)

Treas_Bills_5_Yr['Scotiabank Group'] = Treas_Bills_5_Yr['Scotiabank Group'].combine_first(Treas_Bills_5_Yr['Scotiabank'])
Treas_Bills_5_Yr['Scotiabank Group'] = Treas_Bills_5_Yr['Scotiabank Group'].combine_first(Treas_Bills_5_Yr['Scotia Capital'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Scotia Capital', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Scotiabank', axis=1)

Treas_Bills_5_Yr['September Consensus'] = Treas_Bills_5_Yr['September Consensus'].combine_first(Treas_Bills_5_Yr['Sept. Consensus'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Sept. Consensus', axis=1)

Treas_Bills_5_Yr['Standard & Poor\'s'] = Treas_Bills_5_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_5_Yr['Standard & Poor\'s Corp.'])
Treas_Bills_5_Yr['Standard & Poor\'s'] = Treas_Bills_5_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_5_Yr['Standard & Poors'])
Treas_Bills_5_Yr['Standard & Poor\'s'] = Treas_Bills_5_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_5_Yr['Standard & Poor’s Corp.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Standard & Poors', axis=1)

Treas_Bills_5_Yr['Swiss Re'] = Treas_Bills_5_Yr['Swiss Re'].combine_first(Treas_Bills_5_Yr['Sw iss Re'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Sw iss Re', axis=1)

Treas_Bills_5_Yr['Thredgold Economics'] = Treas_Bills_5_Yr['Thredgold Economics'].combine_first(Treas_Bills_5_Yr['Thredgold Economic Assoc.'])
Treas_Bills_5_Yr['Thredgold Economics'] = Treas_Bills_5_Yr['Thredgold Economics'].combine_first(Treas_Bills_5_Yr['Thredgota Economic Assoc.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_5_Yr['Tokai Bank, Ltd.'] = Treas_Bills_5_Yr['Tokai Bank, Ltd.'].combine_first(Treas_Bills_5_Yr['Tokai Bank, Lid.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_5_Yr['Wayne Hummer & Co.'] = Treas_Bills_5_Yr['Wayne Hummer & Co.'].combine_first(Treas_Bills_5_Yr['Wayne Hummer Investments'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_5_Yr['Wachovia'] = Treas_Bills_5_Yr['Wachovia'].combine_first(Treas_Bills_5_Yr['Wachovia Securities'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Wachovia Securities', axis=1)

Treas_Bills_5_Yr['Wells Fargo'] = Treas_Bills_5_Yr['Wells Fargo'].combine_first(Treas_Bills_5_Yr['Wells Capital Management'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Wells Capital Management', axis=1)

Treas_Bills_5_Yr['Woodworth Holdings'] = Treas_Bills_5_Yr['Woodworth Holdings'].combine_first(Treas_Bills_5_Yr['Woodw orth Holdings'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Woodw orth Holdings', axis=1)

Treas_Bills_5_Yr['independent Economic Advisory'] = Treas_Bills_5_Yr['independent Economic Advisory'].combine_first(Treas_Bills_5_Yr['independent Econ. Advisory'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('independent Econ. Advisory', axis=1)

Treas_Bills_5_Yr['MacroFin Analytics'] = Treas_Bills_5_Yr['MacroFin Analytics'].combine_first(Treas_Bills_5_Yr['MacroFin Analytics & RBS'])
Treas_Bills_5_Yr['MacroFin Analytics'] = Treas_Bills_5_Yr['MacroFin Analytics'].combine_first(Treas_Bills_5_Yr['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_5_Yr['MacroFin Analytics'] = Treas_Bills_5_Yr['MacroFin Analytics'].combine_first(Treas_Bills_5_Yr['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_5_Yr['Mesirow Financial'] = Treas_Bills_5_Yr['Mesirow  Financial'].combine_first(Treas_Bills_5_Yr['Mesirow  Financial'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Mesirow  Financial', axis=1)

Treas_Bills_5_Yr['Merrill Lynch'] = Treas_Bills_5_Yr['Merrill Lynch'].combine_first(Treas_Bills_5_Yr['Merrill Lynch Economics'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_5_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_5_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_5_Yr['LaSalle Nat\'l Bank'])
Treas_Bills_5_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_5_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_5_Yr['LaSalle Natl Bank'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_5_Yr['Kellner Economic Advisers'] = Treas_Bills_5_Yr['Kellner Economic Advisers'].combine_first(Treas_Bills_5_Yr['Keller Economic Advisers'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Keller Economic Advisers', axis=1)

Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['J.P. Morgan Chase'])
Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['J.P. Morgan Chase'])
Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['JPMorgan Asset Mgt.'])
Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['JPMorgan Privare Client Services'])
Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_5_Yr['J.P. Morgan'] = Treas_Bills_5_Yr['J.P. Morgan'].combine_first(Treas_Bills_5_Yr['JPMorgan Private Banking'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('J.P. MorganChase', axis=1)

Treas_Bills_5_Yr['Independent Economic Advisory'] = Treas_Bills_5_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_5_Yr['Independent Econ. Advisory'])
Treas_Bills_5_Yr['Independent Economic Advisory'] = Treas_Bills_5_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_5_Yr['Investment Economics Advisory'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_5_Yr['ING'] = Treas_Bills_5_Yr['ING'].combine_first(Treas_Bills_5_Yr['ING Investment Mgt.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('ING Investment Mgt.', axis=1)

Treas_Bills_5_Yr['Huntington Nat\'I Bank'] = Treas_Bills_5_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_5_Yr['Huntington Nat\'l Bank'])
Treas_Bills_5_Yr['Huntington Nat\'I Bank'] = Treas_Bills_5_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_5_Yr['Huntington Natl Bank'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Huntington Natl Bank', axis=1)

Treas_Bills_5_Yr['Goldman Sachs'] = Treas_Bills_5_Yr['Goldman Sachs'].combine_first(Treas_Bills_5_Yr['Goldman Sachs & Co,'])
Treas_Bills_5_Yr['Goldman Sachs'] = Treas_Bills_5_Yr['Goldman Sachs'].combine_first(Treas_Bills_5_Yr['Goldman Sachs & Co.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_5_Yr['Genetski Financial Advisors'] = Treas_Bills_5_Yr['Genetski Financial Advisors'].combine_first(Treas_Bills_5_Yr['Genetski.com'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Genetski.com', axis=1)

Treas_Bills_5_Yr['Fannie Mae'] = Treas_Bills_5_Yr['Fannie Mae'].combine_first(Treas_Bills_5_Yr['Fannie Mae '])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Fannie Mae ', axis=1)

Treas_Bills_5_Yr['Deutsche Bank Securities'] = Treas_Bills_5_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_5_Yr['Deutsche Bank Securities, Inc.'])
Treas_Bills_5_Yr['Deutsche Bank Securities'] = Treas_Bills_5_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_5_Yr['Deutsche Bank Securities, inc.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_5_Yr['DePrince & Associates'] = Treas_Bills_5_Yr['DePrince & Associates'].combine_first(Treas_Bills_5_Yr['DePrince & Assoc.'])
Treas_Bills_5_Yr['DePrince & Associates'] = Treas_Bills_5_Yr['DePrince & Associates'].combine_first(Treas_Bills_5_Yr['DePrince Associates'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('DePrince & Assoc.', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('DePrince Associates', axis=1)

Treas_Bills_5_Yr['Aeltus Investment'] = Treas_Bills_5_Yr['Aeltus Investment'].combine_first(Treas_Bills_5_Yr['Aeitus Investment'])
Treas_Bills_5_Yr['Aeltus Investment'] = Treas_Bills_5_Yr['Aeltus Investment'].combine_first(Treas_Bills_5_Yr['Aeltus investment'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Aeitus Investment', axis=1)
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Aeltus investment', axis=1)

Treas_Bills_5_Yr['ASB Capital Management'] = Treas_Bills_5_Yr['ASB Capital Management'].combine_first(Treas_Bills_5_Yr['ASB Captial Management'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('ASB Captial Management', axis=1)

Treas_Bills_5_Yr['BMO Nesbitt Burns'] = Treas_Bills_5_Yr['BMO Nesbitt Burns'].combine_first(Treas_Bills_5_Yr['BMC Nesbitt Burns'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_5_Yr['Banc One Invest. Advisors'] = Treas_Bills_5_Yr['Banc One Invest. Advisors'].combine_first(Treas_Bills_5_Yr['Banc One invest. Advisors'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_5_Yr['Banc of America Securities'] = Treas_Bills_5_Yr['Banc of America Securities'].combine_first(Treas_Bills_5_Yr['Banc of Amercia Securities'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_5_Yr['Banc of America Securities'] = Treas_Bills_5_Yr['Banc of America Securities'].combine_first(Treas_Bills_5_Yr['Banc of America Securities, LLC'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_5_Yr['Bank of America Merrill Lynch'] = Treas_Bills_5_Yr['Bank of America Merrill Lynch'].combine_first(Treas_Bills_5_Yr['Bank of America-Merrill Lynch'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_5_Yr['Bank of America Merrill Lynch'] = Treas_Bills_5_Yr['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_5_Yr['Banc of America-Merrill Lynch'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_5_Yr['Bank of Toyko-Mitsubishi'] = Treas_Bills_5_Yr['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_5_Yr['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_5_Yr['Barclays'] = Treas_Bills_5_Yr['Barclays'].combine_first(Treas_Bills_5_Yr['Barclays Capital'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Barclays Capital', axis=1)

Treas_Bills_5_Yr['Bear Stearns'] = Treas_Bills_5_Yr['Bear Stearns'].combine_first(Treas_Bills_5_Yr['Bear Stearns & Co.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_5_Yr['Bear Stearns'] = Treas_Bills_5_Yr['Bear Stearns'].combine_first(Treas_Bills_5_Yr['Bear Steams & Co.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Bear Steams & Co.', axis=1)

Treas_Bills_5_Yr['Camilli Economics'] = Treas_Bills_5_Yr['Camilli Economics'].combine_first(Treas_Bills_5_Yr['Camilli Economics LLC'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Camilli Economics LLC', axis=1)
Treas_Bills_5_Yr['Camilli Economics'] = Treas_Bills_5_Yr['Camilli Economics'].combine_first(Treas_Bills_5_Yr['Camilli, Kathleen'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Camilli, Kathleen', axis=1)

Treas_Bills_5_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_5_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_5_Yr['Citibank Global Asset Mgmt.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_5_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_5_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_5_Yr['Citigroup Asset Management'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Citigroup Asset Management', axis=1)

Treas_Bills_5_Yr['ClearView Economics'] = Treas_Bills_5_Yr['ClearView Economics'].combine_first(Treas_Bills_5_Yr['ClearView Associates'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('ClearView Associates', axis=1)
Treas_Bills_5_Yr['ClearView Economics'] = Treas_Bills_5_Yr['ClearView Economics'].combine_first(Treas_Bills_5_Yr['ClearView  Economics'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('ClearView  Economics', axis=1)

Treas_Bills_5_Yr['Comerica Bank'] = Treas_Bills_5_Yr['Comerica Bank'].combine_first(Treas_Bills_5_Yr['Commerica'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Commerica', axis=1)

Treas_Bills_5_Yr['Cycledata Corp.'] = Treas_Bills_5_Yr['Cycledata Corp.'].combine_first(Treas_Bills_5_Yr['Cycledata corp.'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Cycledata corp.', axis=1)

Treas_Bills_5_Yr['Daiwa Capital Markets America'] = Treas_Bills_5_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_5_Yr['Daiw a Capital Markets America'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_5_Yr['Daiwa Capital Markets America'] = Treas_Bills_5_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_5_Yr['Daiwa Securities America'])
Treas_Bills_5_Yr = Treas_Bills_5_Yr.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_10_Yr['Moody\'s Analytics'] = Treas_Bills_10_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_10_Yr['Moody\'s Capital Markets'])
Treas_Bills_10_Yr['Moody\'s Analytics'] = Treas_Bills_10_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_10_Yr['Moody\'s Capital Markets Group'])
Treas_Bills_10_Yr['Moody\'s Analytics'] = Treas_Bills_10_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_10_Yr['Moody\'s Econmy.com'])
Treas_Bills_10_Yr['Moody\'s Analytics'] = Treas_Bills_10_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_10_Yr['Moody\'s Economy.com'])
Treas_Bills_10_Yr['Moody\'s Analytics'] = Treas_Bills_10_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_10_Yr['Moody\'s Investors Service'])
Treas_Bills_10_Yr['Moody\'s Analytics'] = Treas_Bills_10_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_10_Yr['Moodys Investors Service'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Moodys Investors Service', axis=1)

Treas_Bills_10_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_10_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_10_Yr['Nat\'l Assn, of Realtors'])
Treas_Bills_10_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_10_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_10_Yr['Nat\'I Assn, of Realtors'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_10_Yr['National City Bank'] = Treas_Bills_10_Yr['National City Bank'].combine_first(Treas_Bills_10_Yr['National City Corporation'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('National City Corporation', axis=1)

Treas_Bills_10_Yr['Nomura Securities Inc.'] = Treas_Bills_10_Yr['Nomura Securities Inc.'].combine_first(Treas_Bills_10_Yr['Nomura Securities, Inc.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_10_Yr['October Consensus'] = Treas_Bills_10_Yr['October Consensus'].combine_first(Treas_Bills_10_Yr['Octoberber Consensus'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Octoberber Consensus', axis=1)

Treas_Bills_10_Yr['PNC Bank Corp.'] = Treas_Bills_10_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_10_Yr['PNC Financial Services'])
Treas_Bills_10_Yr['PNC Bank Corp.'] = Treas_Bills_10_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_10_Yr['PNC Financial Services Corp.'])
Treas_Bills_10_Yr['PNC Bank Corp.'] = Treas_Bills_10_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_10_Yr['PNC Financial Services Group'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('PNC Financial Services', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('PNC Financial Services Group', axis=1)

Treas_Bills_10_Yr['Prudential Securities'] = Treas_Bills_10_Yr['Prudential Securities'].combine_first(Treas_Bills_10_Yr['Prudential Equity Group LLC'])
Treas_Bills_10_Yr['Prudential Securities'] = Treas_Bills_10_Yr['Prudential Securities'].combine_first(Treas_Bills_10_Yr['Prudential Insurance Co.'])
Treas_Bills_10_Yr['Prudential Securities'] = Treas_Bills_10_Yr['Prudential Securities'].combine_first(Treas_Bills_10_Yr['Prudential Financial'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Prudential Financial', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_10_Yr['RBS Greenwich Capital Econ.'] = Treas_Bills_10_Yr['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_10_Yr['RBS Securities'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('RBS Securities', axis=1)

Treas_Bills_10_Yr['RBC'] = Treas_Bills_10_Yr['RBC'].combine_first(Treas_Bills_10_Yr['RBC Capital Markets'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('RBC Capital Markets', axis=1)

Treas_Bills_10_Yr['RDQ Economics'] = Treas_Bills_10_Yr['RDQ Economics'].combine_first(Treas_Bills_10_Yr['RDQ'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('RDQ', axis=1)

Treas_Bills_10_Yr['RidgeWorth Investments'] = Treas_Bills_10_Yr['RidgeWorth Investments'].combine_first(Treas_Bills_10_Yr['RidgeWorth Capital Management'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_10_Yr['S&P Global'] = Treas_Bills_10_Yr['S&P Global'].combine_first(Treas_Bills_10_Yr['S&P Global Market Intelligence'])
Treas_Bills_10_Yr['S&P Global'] = Treas_Bills_10_Yr['S&P Global'].combine_first(Treas_Bills_10_Yr['S&P Global Ratings'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('S&P Global Ratings', axis=1)

Treas_Bills_10_Yr['Scotiabank Group'] = Treas_Bills_10_Yr['Scotiabank Group'].combine_first(Treas_Bills_10_Yr['Scotiabank'])
Treas_Bills_10_Yr['Scotiabank Group'] = Treas_Bills_10_Yr['Scotiabank Group'].combine_first(Treas_Bills_10_Yr['Scotia Capital'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Scotia Capital', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Scotiabank', axis=1)

Treas_Bills_10_Yr['September Consensus'] = Treas_Bills_10_Yr['September Consensus'].combine_first(Treas_Bills_10_Yr['Sept. Consensus'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Sept. Consensus', axis=1)

Treas_Bills_10_Yr['Standard & Poor\'s'] = Treas_Bills_10_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_10_Yr['Standard & Poor\'s Corp.'])
Treas_Bills_10_Yr['Standard & Poor\'s'] = Treas_Bills_10_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_10_Yr['Standard & Poors'])
Treas_Bills_10_Yr['Standard & Poor\'s'] = Treas_Bills_10_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_10_Yr['Standard & Poor’s Corp.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Standard & Poors', axis=1)

Treas_Bills_10_Yr['Swiss Re'] = Treas_Bills_10_Yr['Swiss Re'].combine_first(Treas_Bills_10_Yr['Sw iss Re'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Sw iss Re', axis=1)

Treas_Bills_10_Yr['Thredgold Economics'] = Treas_Bills_10_Yr['Thredgold Economics'].combine_first(Treas_Bills_10_Yr['Thredgold Economic Assoc.'])
Treas_Bills_10_Yr['Thredgold Economics'] = Treas_Bills_10_Yr['Thredgold Economics'].combine_first(Treas_Bills_10_Yr['Thredgota Economic Assoc.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_10_Yr['Tokai Bank, Ltd.'] = Treas_Bills_10_Yr['Tokai Bank, Ltd.'].combine_first(Treas_Bills_10_Yr['Tokai Bank, Lid.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_10_Yr['Wayne Hummer & Co.'] = Treas_Bills_10_Yr['Wayne Hummer & Co.'].combine_first(Treas_Bills_10_Yr['Wayne Hummer Investments'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_10_Yr['Wachovia'] = Treas_Bills_10_Yr['Wachovia'].combine_first(Treas_Bills_10_Yr['Wachovia Securities'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Wachovia Securities', axis=1)

Treas_Bills_10_Yr['Wells Fargo'] = Treas_Bills_10_Yr['Wells Fargo'].combine_first(Treas_Bills_10_Yr['Wells Capital Management'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Wells Capital Management', axis=1)

Treas_Bills_10_Yr['Woodworth Holdings'] = Treas_Bills_10_Yr['Woodworth Holdings'].combine_first(Treas_Bills_10_Yr['Woodw orth Holdings'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Woodw orth Holdings', axis=1)

Treas_Bills_10_Yr['independent Economic Advisory'] = Treas_Bills_10_Yr['independent Economic Advisory'].combine_first(Treas_Bills_10_Yr['independent Econ. Advisory'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('independent Econ. Advisory', axis=1)

Treas_Bills_10_Yr['MacroFin Analytics'] = Treas_Bills_10_Yr['MacroFin Analytics'].combine_first(Treas_Bills_10_Yr['MacroFin Analytics & RBS'])
Treas_Bills_10_Yr['MacroFin Analytics'] = Treas_Bills_10_Yr['MacroFin Analytics'].combine_first(Treas_Bills_10_Yr['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_10_Yr['MacroFin Analytics'] = Treas_Bills_10_Yr['MacroFin Analytics'].combine_first(Treas_Bills_10_Yr['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_10_Yr['Mesirow Financial'] = Treas_Bills_10_Yr['Mesirow  Financial'].combine_first(Treas_Bills_10_Yr['Mesirow  Financial'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Mesirow  Financial', axis=1)

Treas_Bills_10_Yr['Merrill Lynch'] = Treas_Bills_10_Yr['Merrill Lynch'].combine_first(Treas_Bills_10_Yr['Merrill Lynch Economics'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_10_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_10_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_10_Yr['LaSalle Nat\'l Bank'])
Treas_Bills_10_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_10_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_10_Yr['LaSalle Natl Bank'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_10_Yr['Kellner Economic Advisers'] = Treas_Bills_10_Yr['Kellner Economic Advisers'].combine_first(Treas_Bills_10_Yr['Keller Economic Advisers'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Keller Economic Advisers', axis=1)

Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['J.P. Morgan Chase'])
Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['J.P. Morgan Chase'])
Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['JPMorgan Asset Mgt.'])
Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['JPMorgan Privare Client Services'])
Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_10_Yr['J.P. Morgan'] = Treas_Bills_10_Yr['J.P. Morgan'].combine_first(Treas_Bills_10_Yr['JPMorgan Private Banking'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('J.P. MorganChase', axis=1)

Treas_Bills_10_Yr['Independent Economic Advisory'] = Treas_Bills_10_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_10_Yr['Independent Econ. Advisory'])
Treas_Bills_10_Yr['Independent Economic Advisory'] = Treas_Bills_10_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_10_Yr['Investment Economics Advisory'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_10_Yr['ING'] = Treas_Bills_10_Yr['ING'].combine_first(Treas_Bills_10_Yr['ING Investment Mgt.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('ING Investment Mgt.', axis=1)

Treas_Bills_10_Yr['Huntington Nat\'I Bank'] = Treas_Bills_10_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_10_Yr['Huntington Nat\'l Bank'])
Treas_Bills_10_Yr['Huntington Nat\'I Bank'] = Treas_Bills_10_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_10_Yr['Huntington Natl Bank'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Huntington Natl Bank', axis=1)

Treas_Bills_10_Yr['Goldman Sachs'] = Treas_Bills_10_Yr['Goldman Sachs'].combine_first(Treas_Bills_10_Yr['Goldman Sachs & Co,'])
Treas_Bills_10_Yr['Goldman Sachs'] = Treas_Bills_10_Yr['Goldman Sachs'].combine_first(Treas_Bills_10_Yr['Goldman Sachs & Co.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_10_Yr['Genetski Financial Advisors'] = Treas_Bills_10_Yr['Genetski Financial Advisors'].combine_first(Treas_Bills_10_Yr['Genetski.com'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Genetski.com', axis=1)

Treas_Bills_10_Yr['Fannie Mae'] = Treas_Bills_10_Yr['Fannie Mae'].combine_first(Treas_Bills_10_Yr['Fannie Mae '])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Fannie Mae ', axis=1)

Treas_Bills_10_Yr['Deutsche Bank Securities'] = Treas_Bills_10_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_10_Yr['Deutsche Bank Securities, Inc.'])
Treas_Bills_10_Yr['Deutsche Bank Securities'] = Treas_Bills_10_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_10_Yr['Deutsche Bank Securities, inc.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_10_Yr['DePrince & Associates'] = Treas_Bills_10_Yr['DePrince & Associates'].combine_first(Treas_Bills_10_Yr['DePrince & Assoc.'])
Treas_Bills_10_Yr['DePrince & Associates'] = Treas_Bills_10_Yr['DePrince & Associates'].combine_first(Treas_Bills_10_Yr['DePrince Associates'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('DePrince & Assoc.', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('DePrince Associates', axis=1)

Treas_Bills_10_Yr['Aeltus Investment'] = Treas_Bills_10_Yr['Aeltus Investment'].combine_first(Treas_Bills_10_Yr['Aeitus Investment'])
Treas_Bills_10_Yr['Aeltus Investment'] = Treas_Bills_10_Yr['Aeltus Investment'].combine_first(Treas_Bills_10_Yr['Aeltus investment'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Aeitus Investment', axis=1)
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Aeltus investment', axis=1)

Treas_Bills_10_Yr['ASB Capital Management'] = Treas_Bills_10_Yr['ASB Capital Management'].combine_first(Treas_Bills_10_Yr['ASB Captial Management'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('ASB Captial Management', axis=1)

Treas_Bills_10_Yr['BMO Nesbitt Burns'] = Treas_Bills_10_Yr['BMO Nesbitt Burns'].combine_first(Treas_Bills_10_Yr['BMC Nesbitt Burns'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_10_Yr['Banc One Invest. Advisors'] = Treas_Bills_10_Yr['Banc One Invest. Advisors'].combine_first(Treas_Bills_10_Yr['Banc One invest. Advisors'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_10_Yr['Banc of America Securities'] = Treas_Bills_10_Yr['Banc of America Securities'].combine_first(Treas_Bills_10_Yr['Banc of Amercia Securities'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_10_Yr['Banc of America Securities'] = Treas_Bills_10_Yr['Banc of America Securities'].combine_first(Treas_Bills_10_Yr['Banc of America Securities, LLC'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_10_Yr['Bank of America Merrill Lynch'] = Treas_Bills_10_Yr['Bank of America Merrill Lynch'].combine_first(Treas_Bills_10_Yr['Bank of America-Merrill Lynch'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_10_Yr['Bank of America Merrill Lynch'] = Treas_Bills_10_Yr['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_10_Yr['Banc of America-Merrill Lynch'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_10_Yr['Bank of Toyko-Mitsubishi'] = Treas_Bills_10_Yr['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_10_Yr['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_10_Yr['Barclays'] = Treas_Bills_10_Yr['Barclays'].combine_first(Treas_Bills_10_Yr['Barclays Capital'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Barclays Capital', axis=1)

Treas_Bills_10_Yr['Bear Stearns'] = Treas_Bills_10_Yr['Bear Stearns'].combine_first(Treas_Bills_10_Yr['Bear Stearns & Co.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_10_Yr['Bear Stearns'] = Treas_Bills_10_Yr['Bear Stearns'].combine_first(Treas_Bills_10_Yr['Bear Steams & Co.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Bear Steams & Co.', axis=1)

Treas_Bills_10_Yr['Camilli Economics'] = Treas_Bills_10_Yr['Camilli Economics'].combine_first(Treas_Bills_10_Yr['Camilli Economics LLC'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Camilli Economics LLC', axis=1)
Treas_Bills_10_Yr['Camilli Economics'] = Treas_Bills_10_Yr['Camilli Economics'].combine_first(Treas_Bills_10_Yr['Camilli, Kathleen'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Camilli, Kathleen', axis=1)

Treas_Bills_10_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_10_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_10_Yr['Citibank Global Asset Mgmt.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_10_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_10_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_10_Yr['Citigroup Asset Management'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Citigroup Asset Management', axis=1)

Treas_Bills_10_Yr['ClearView Economics'] = Treas_Bills_10_Yr['ClearView Economics'].combine_first(Treas_Bills_10_Yr['ClearView Associates'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('ClearView Associates', axis=1)
Treas_Bills_10_Yr['ClearView Economics'] = Treas_Bills_10_Yr['ClearView Economics'].combine_first(Treas_Bills_10_Yr['ClearView  Economics'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('ClearView  Economics', axis=1)

Treas_Bills_10_Yr['Comerica Bank'] = Treas_Bills_10_Yr['Comerica Bank'].combine_first(Treas_Bills_10_Yr['Commerica'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Commerica', axis=1)

Treas_Bills_10_Yr['Cycledata Corp.'] = Treas_Bills_10_Yr['Cycledata Corp.'].combine_first(Treas_Bills_10_Yr['Cycledata corp.'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Cycledata corp.', axis=1)

Treas_Bills_10_Yr['Daiwa Capital Markets America'] = Treas_Bills_10_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_10_Yr['Daiw a Capital Markets America'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_10_Yr['Daiwa Capital Markets America'] = Treas_Bills_10_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_10_Yr['Daiwa Securities America'])
Treas_Bills_10_Yr = Treas_Bills_10_Yr.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Treas_Bills_30_Yr['Moody\'s Analytics'] = Treas_Bills_30_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_30_Yr['Moody\'s Capital Markets'])
Treas_Bills_30_Yr['Moody\'s Analytics'] = Treas_Bills_30_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_30_Yr['Moody\'s Capital Markets Group'])
Treas_Bills_30_Yr['Moody\'s Analytics'] = Treas_Bills_30_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_30_Yr['Moody\'s Econmy.com'])
Treas_Bills_30_Yr['Moody\'s Analytics'] = Treas_Bills_30_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_30_Yr['Moody\'s Economy.com'])
Treas_Bills_30_Yr['Moody\'s Analytics'] = Treas_Bills_30_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_30_Yr['Moody\'s Investors Service'])
Treas_Bills_30_Yr['Moody\'s Analytics'] = Treas_Bills_30_Yr['Moody\'s Analytics'].combine_first(Treas_Bills_30_Yr['Moodys Investors Service'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Moody\'s Capital Markets', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Moody\'s Capital Markets Group', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Moody\'s Econmy.com', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Moody\'s Economy.com', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Moody\'s Investors Service', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Moodys Investors Service', axis=1)

Treas_Bills_30_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_30_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_30_Yr['Nat\'l Assn, of Realtors'])
Treas_Bills_30_Yr['Nat\'l Assn. of Realtors'] = Treas_Bills_30_Yr['Nat\'l Assn. of Realtors'].combine_first(Treas_Bills_30_Yr['Nat\'I Assn, of Realtors'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Nat\'l Assn, of Realtors', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Nat\'I Assn, of Realtors', axis=1)

Treas_Bills_30_Yr['National City Bank'] = Treas_Bills_30_Yr['National City Bank'].combine_first(Treas_Bills_30_Yr['National City Corporation'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('National City Corporation', axis=1)

Treas_Bills_30_Yr['Nomura Securities Inc.'] = Treas_Bills_30_Yr['Nomura Securities Inc.'].combine_first(Treas_Bills_30_Yr['Nomura Securities, Inc.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Nomura Securities, Inc.', axis=1)

Treas_Bills_30_Yr['October Consensus'] = Treas_Bills_30_Yr['October Consensus'].combine_first(Treas_Bills_30_Yr['Octoberber Consensus'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Octoberber Consensus', axis=1)

Treas_Bills_30_Yr['PNC Bank Corp.'] = Treas_Bills_30_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_30_Yr['PNC Financial Services'])
Treas_Bills_30_Yr['PNC Bank Corp.'] = Treas_Bills_30_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_30_Yr['PNC Financial Services Corp.'])
Treas_Bills_30_Yr['PNC Bank Corp.'] = Treas_Bills_30_Yr['PNC Bank Corp.'].combine_first(Treas_Bills_30_Yr['PNC Financial Services Group'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('PNC Financial Services', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('PNC Financial Services Corp.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('PNC Financial Services Group', axis=1)

Treas_Bills_30_Yr['Prudential Securities'] = Treas_Bills_30_Yr['Prudential Securities'].combine_first(Treas_Bills_30_Yr['Prudential Equity Group LLC'])
Treas_Bills_30_Yr['Prudential Securities'] = Treas_Bills_30_Yr['Prudential Securities'].combine_first(Treas_Bills_30_Yr['Prudential Insurance Co.'])
Treas_Bills_30_Yr['Prudential Securities'] = Treas_Bills_30_Yr['Prudential Securities'].combine_first(Treas_Bills_30_Yr['Prudential Financial'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Prudential Financial', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Prudential Insurance Co.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Prudential Equity Group LLC', axis=1)

Treas_Bills_30_Yr['RBS Greenwich Capital Econ.'] = Treas_Bills_30_Yr['RBS Greenwich Capital Econ.'].combine_first(Treas_Bills_30_Yr['RBS Securities'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('RBS Securities', axis=1)

Treas_Bills_30_Yr['RBC'] = Treas_Bills_30_Yr['RBC'].combine_first(Treas_Bills_30_Yr['RBC Capital Markets'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('RBC Capital Markets', axis=1)

Treas_Bills_30_Yr['RDQ Economics'] = Treas_Bills_30_Yr['RDQ Economics'].combine_first(Treas_Bills_30_Yr['RDQ'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('RDQ', axis=1)

Treas_Bills_30_Yr['RidgeWorth Investments'] = Treas_Bills_30_Yr['RidgeWorth Investments'].combine_first(Treas_Bills_30_Yr['RidgeWorth Capital Management'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('RidgeWorth Capital Management', axis=1)

Treas_Bills_30_Yr['S&P Global'] = Treas_Bills_30_Yr['S&P Global'].combine_first(Treas_Bills_30_Yr['S&P Global Market Intelligence'])
Treas_Bills_30_Yr['S&P Global'] = Treas_Bills_30_Yr['S&P Global'].combine_first(Treas_Bills_30_Yr['S&P Global Ratings'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('S&P Global Market Intelligence', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('S&P Global Ratings', axis=1)

Treas_Bills_30_Yr['Scotiabank Group'] = Treas_Bills_30_Yr['Scotiabank Group'].combine_first(Treas_Bills_30_Yr['Scotiabank'])
Treas_Bills_30_Yr['Scotiabank Group'] = Treas_Bills_30_Yr['Scotiabank Group'].combine_first(Treas_Bills_30_Yr['Scotia Capital'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Scotia Capital', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Scotiabank', axis=1)

Treas_Bills_30_Yr['September Consensus'] = Treas_Bills_30_Yr['September Consensus'].combine_first(Treas_Bills_30_Yr['Sept. Consensus'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Sept. Consensus', axis=1)

Treas_Bills_30_Yr['Standard & Poor\'s'] = Treas_Bills_30_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_30_Yr['Standard & Poor\'s Corp.'])
Treas_Bills_30_Yr['Standard & Poor\'s'] = Treas_Bills_30_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_30_Yr['Standard & Poors'])
Treas_Bills_30_Yr['Standard & Poor\'s'] = Treas_Bills_30_Yr['Standard & Poor\'s'].combine_first(Treas_Bills_30_Yr['Standard & Poor’s Corp.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Standard & Poor’s Corp.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Standard & Poor\'s Corp.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Standard & Poors', axis=1)

Treas_Bills_30_Yr['Swiss Re'] = Treas_Bills_30_Yr['Swiss Re'].combine_first(Treas_Bills_30_Yr['Sw iss Re'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Sw iss Re', axis=1)

Treas_Bills_30_Yr['Thredgold Economics'] = Treas_Bills_30_Yr['Thredgold Economics'].combine_first(Treas_Bills_30_Yr['Thredgold Economic Assoc.'])
Treas_Bills_30_Yr['Thredgold Economics'] = Treas_Bills_30_Yr['Thredgold Economics'].combine_first(Treas_Bills_30_Yr['Thredgota Economic Assoc.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Thredgold Economic Assoc.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Thredgota Economic Assoc.', axis=1)

Treas_Bills_30_Yr['Tokai Bank, Ltd.'] = Treas_Bills_30_Yr['Tokai Bank, Ltd.'].combine_first(Treas_Bills_30_Yr['Tokai Bank, Lid.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Tokai Bank, Lid.', axis=1)

Treas_Bills_30_Yr['Wayne Hummer & Co.'] = Treas_Bills_30_Yr['Wayne Hummer & Co.'].combine_first(Treas_Bills_30_Yr['Wayne Hummer Investments'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Wayne Hummer Investments', axis=1)

Treas_Bills_30_Yr['Wachovia'] = Treas_Bills_30_Yr['Wachovia'].combine_first(Treas_Bills_30_Yr['Wachovia Securities'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Wachovia Securities', axis=1)

Treas_Bills_30_Yr['Wells Fargo'] = Treas_Bills_30_Yr['Wells Fargo'].combine_first(Treas_Bills_30_Yr['Wells Capital Management'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Wells Capital Management', axis=1)

Treas_Bills_30_Yr['Woodworth Holdings'] = Treas_Bills_30_Yr['Woodworth Holdings'].combine_first(Treas_Bills_30_Yr['Woodw orth Holdings'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Woodw orth Holdings', axis=1)

Treas_Bills_30_Yr['independent Economic Advisory'] = Treas_Bills_30_Yr['independent Economic Advisory'].combine_first(Treas_Bills_30_Yr['independent Econ. Advisory'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('independent Econ. Advisory', axis=1)

Treas_Bills_30_Yr['MacroFin Analytics'] = Treas_Bills_30_Yr['MacroFin Analytics'].combine_first(Treas_Bills_30_Yr['MacroFin Analytics & RBS'])
Treas_Bills_30_Yr['MacroFin Analytics'] = Treas_Bills_30_Yr['MacroFin Analytics'].combine_first(Treas_Bills_30_Yr['MacroFin Analytics & Rutgers Bus School'])
Treas_Bills_30_Yr['MacroFin Analytics'] = Treas_Bills_30_Yr['MacroFin Analytics'].combine_first(Treas_Bills_30_Yr['MacroFin Analytics/Rutgers Bus School'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('MacroFin Analytics & RBS', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Treas_Bills_30_Yr['Mesirow Financial'] = Treas_Bills_30_Yr['Mesirow  Financial'].combine_first(Treas_Bills_30_Yr['Mesirow  Financial'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Mesirow  Financial', axis=1)

Treas_Bills_30_Yr['Merrill Lynch'] = Treas_Bills_30_Yr['Merrill Lynch'].combine_first(Treas_Bills_30_Yr['Merrill Lynch Economics'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Merrill Lynch Economics', axis=1)

Treas_Bills_30_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_30_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_30_Yr['LaSalle Nat\'l Bank'])
Treas_Bills_30_Yr['LaSalle Nat\'I Bank'] = Treas_Bills_30_Yr['LaSalle Nat\'I Bank'].combine_first(Treas_Bills_30_Yr['LaSalle Natl Bank'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('LaSalle Nat\'l Bank', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('LaSalle Natl Bank', axis=1)

Treas_Bills_30_Yr['Kellner Economic Advisers'] = Treas_Bills_30_Yr['Kellner Economic Advisers'].combine_first(Treas_Bills_30_Yr['Keller Economic Advisers'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Keller Economic Advisers', axis=1)

Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['J.P. Morgan Chase'])
Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['J.P. Morgan Chase'])
Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['JPMorgan Asset Mgt.'])
Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['JPMorgan Fleming Asset Mgt.'])
Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['JPMorgan Privare Client Services'])
Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['JPMorgan Privare Wealth Mgt.'])
Treas_Bills_30_Yr['J.P. Morgan'] = Treas_Bills_30_Yr['J.P. Morgan'].combine_first(Treas_Bills_30_Yr['JPMorgan Private Banking'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('JPMorgan Private Banking', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('JPMorgan Privare Client Services', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('JPMorgan Asset Mgt.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('J.P. Morgan Chase', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('J.P. MorganChase', axis=1)

Treas_Bills_30_Yr['Independent Economic Advisory'] = Treas_Bills_30_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_30_Yr['Independent Econ. Advisory'])
Treas_Bills_30_Yr['Independent Economic Advisory'] = Treas_Bills_30_Yr['Independent Economic Advisory'].combine_first(Treas_Bills_30_Yr['Investment Economics Advisory'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Independent Econ. Advisory', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Investment Economics Advisory', axis=1)
                                         
Treas_Bills_30_Yr['ING'] = Treas_Bills_30_Yr['ING'].combine_first(Treas_Bills_30_Yr['ING Investment Mgt.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('ING Investment Mgt.', axis=1)

Treas_Bills_30_Yr['Huntington Nat\'I Bank'] = Treas_Bills_30_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_30_Yr['Huntington Nat\'l Bank'])
Treas_Bills_30_Yr['Huntington Nat\'I Bank'] = Treas_Bills_30_Yr['Huntington Nat\'I Bank'].combine_first(Treas_Bills_30_Yr['Huntington Natl Bank'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Huntington Nat\'l Bank', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Huntington Natl Bank', axis=1)

Treas_Bills_30_Yr['Goldman Sachs'] = Treas_Bills_30_Yr['Goldman Sachs'].combine_first(Treas_Bills_30_Yr['Goldman Sachs & Co,'])
Treas_Bills_30_Yr['Goldman Sachs'] = Treas_Bills_30_Yr['Goldman Sachs'].combine_first(Treas_Bills_30_Yr['Goldman Sachs & Co.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Goldman Sachs & Co,', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Goldman Sachs & Co.', axis=1)

Treas_Bills_30_Yr['Genetski Financial Advisors'] = Treas_Bills_30_Yr['Genetski Financial Advisors'].combine_first(Treas_Bills_30_Yr['Genetski.com'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Genetski.com', axis=1)

Treas_Bills_30_Yr['Fannie Mae'] = Treas_Bills_30_Yr['Fannie Mae'].combine_first(Treas_Bills_30_Yr['Fannie Mae '])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Fannie Mae ', axis=1)

Treas_Bills_30_Yr['Deutsche Bank Securities'] = Treas_Bills_30_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_30_Yr['Deutsche Bank Securities, Inc.'])
Treas_Bills_30_Yr['Deutsche Bank Securities'] = Treas_Bills_30_Yr['Deutsche Bank Securities'].combine_first(Treas_Bills_30_Yr['Deutsche Bank Securities, inc.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Deutsche Bank Securities, Inc.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Deutsche Bank Securities, inc.', axis=1)

Treas_Bills_30_Yr['DePrince & Associates'] = Treas_Bills_30_Yr['DePrince & Associates'].combine_first(Treas_Bills_30_Yr['DePrince & Assoc.'])
Treas_Bills_30_Yr['DePrince & Associates'] = Treas_Bills_30_Yr['DePrince & Associates'].combine_first(Treas_Bills_30_Yr['DePrince Associates'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('DePrince & Assoc.', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('DePrince Associates', axis=1)

Treas_Bills_30_Yr['Aeltus Investment'] = Treas_Bills_30_Yr['Aeltus Investment'].combine_first(Treas_Bills_30_Yr['Aeitus Investment'])
Treas_Bills_30_Yr['Aeltus Investment'] = Treas_Bills_30_Yr['Aeltus Investment'].combine_first(Treas_Bills_30_Yr['Aeltus investment'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Aeitus Investment', axis=1)
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Aeltus investment', axis=1)

Treas_Bills_30_Yr['ASB Capital Management'] = Treas_Bills_30_Yr['ASB Capital Management'].combine_first(Treas_Bills_30_Yr['ASB Captial Management'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('ASB Captial Management', axis=1)

Treas_Bills_30_Yr['BMO Nesbitt Burns'] = Treas_Bills_30_Yr['BMO Nesbitt Burns'].combine_first(Treas_Bills_30_Yr['BMC Nesbitt Burns'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('BMC Nesbitt Burns', axis=1)

Treas_Bills_30_Yr['Banc One Invest. Advisors'] = Treas_Bills_30_Yr['Banc One Invest. Advisors'].combine_first(Treas_Bills_30_Yr['Banc One invest. Advisors'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Banc One invest. Advisors', axis=1)

Treas_Bills_30_Yr['Banc of America Securities'] = Treas_Bills_30_Yr['Banc of America Securities'].combine_first(Treas_Bills_30_Yr['Banc of Amercia Securities'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Banc of Amercia Securities', axis=1)

Treas_Bills_30_Yr['Banc of America Securities'] = Treas_Bills_30_Yr['Banc of America Securities'].combine_first(Treas_Bills_30_Yr['Banc of America Securities, LLC'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Banc of America Securities, LLC', axis=1)

Treas_Bills_30_Yr['Bank of America Merrill Lynch'] = Treas_Bills_30_Yr['Bank of America Merrill Lynch'].combine_first(Treas_Bills_30_Yr['Bank of America-Merrill Lynch'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Bank of America-Merrill Lynch', axis=1)
Treas_Bills_30_Yr['Bank of America Merrill Lynch'] = Treas_Bills_30_Yr['Banc of America-Merrill Lynch'].combine_first(Treas_Bills_30_Yr['Banc of America-Merrill Lynch'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Banc of America-Merrill Lynch', axis=1)

Treas_Bills_30_Yr['Bank of Toyko-Mitsubishi'] = Treas_Bills_30_Yr['Bank of Toyko-Mitsubishi'].combine_first(Treas_Bills_30_Yr['Bank of Toyko-Mitsubishi UFJ'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Treas_Bills_30_Yr['Barclays'] = Treas_Bills_30_Yr['Barclays'].combine_first(Treas_Bills_30_Yr['Barclays Capital'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Barclays Capital', axis=1)

Treas_Bills_30_Yr['Bear Stearns'] = Treas_Bills_30_Yr['Bear Stearns'].combine_first(Treas_Bills_30_Yr['Bear Stearns & Co.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Bear Stearns & Co.', axis=1)
Treas_Bills_30_Yr['Bear Stearns'] = Treas_Bills_30_Yr['Bear Stearns'].combine_first(Treas_Bills_30_Yr['Bear Steams & Co.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Bear Steams & Co.', axis=1)

Treas_Bills_30_Yr['Camilli Economics'] = Treas_Bills_30_Yr['Camilli Economics'].combine_first(Treas_Bills_30_Yr['Camilli Economics LLC'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Camilli Economics LLC', axis=1)
Treas_Bills_30_Yr['Camilli Economics'] = Treas_Bills_30_Yr['Camilli Economics'].combine_first(Treas_Bills_30_Yr['Camilli, Kathleen'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Camilli, Kathleen', axis=1)

Treas_Bills_30_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_30_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_30_Yr['Citibank Global Asset Mgmt.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Citibank Global Asset Mgmt.', axis=1)
Treas_Bills_30_Yr['Citibank Global Asset Mgmt'] = Treas_Bills_30_Yr['Citibank Global Asset Mgmt'].combine_first(Treas_Bills_30_Yr['Citigroup Asset Management'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Citigroup Asset Management', axis=1)

Treas_Bills_30_Yr['ClearView Economics'] = Treas_Bills_30_Yr['ClearView Economics'].combine_first(Treas_Bills_30_Yr['ClearView Associates'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('ClearView Associates', axis=1)
Treas_Bills_30_Yr['ClearView Economics'] = Treas_Bills_30_Yr['ClearView Economics'].combine_first(Treas_Bills_30_Yr['ClearView  Economics'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('ClearView  Economics', axis=1)

Treas_Bills_30_Yr['Comerica Bank'] = Treas_Bills_30_Yr['Comerica Bank'].combine_first(Treas_Bills_30_Yr['Commerica'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Commerica', axis=1)

Treas_Bills_30_Yr['Cycledata Corp.'] = Treas_Bills_30_Yr['Cycledata Corp.'].combine_first(Treas_Bills_30_Yr['Cycledata corp.'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Cycledata corp.', axis=1)

Treas_Bills_30_Yr['Daiwa Capital Markets America'] = Treas_Bills_30_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_30_Yr['Daiw a Capital Markets America'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Daiw a Capital Markets America', axis=1)
Treas_Bills_30_Yr['Daiwa Capital Markets America'] = Treas_Bills_30_Yr['Daiwa Capital Markets America'].combine_first(Treas_Bills_30_Yr['Daiwa Securities America'])
Treas_Bills_30_Yr = Treas_Bills_30_Yr.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Aaa_Corp_Bond['Moody\'s Analytics'] = Aaa_Corp_Bond['Moody\'s Analytics'].combine_first(Aaa_Corp_Bond['Moody\'s Capital Markets'])
Aaa_Corp_Bond['Moody\'s Analytics'] = Aaa_Corp_Bond['Moody\'s Analytics'].combine_first(Aaa_Corp_Bond['Moody\'s Capital Markets Group'])
Aaa_Corp_Bond['Moody\'s Analytics'] = Aaa_Corp_Bond['Moody\'s Analytics'].combine_first(Aaa_Corp_Bond['Moody\'s Econmy.com'])
Aaa_Corp_Bond['Moody\'s Analytics'] = Aaa_Corp_Bond['Moody\'s Analytics'].combine_first(Aaa_Corp_Bond['Moody\'s Economy.com'])
Aaa_Corp_Bond['Moody\'s Analytics'] = Aaa_Corp_Bond['Moody\'s Analytics'].combine_first(Aaa_Corp_Bond['Moody\'s Investors Service'])
Aaa_Corp_Bond['Moody\'s Analytics'] = Aaa_Corp_Bond['Moody\'s Analytics'].combine_first(Aaa_Corp_Bond['Moodys Investors Service'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Moody\'s Capital Markets', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Moody\'s Capital Markets Group', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Moody\'s Econmy.com', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Moody\'s Economy.com', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Moody\'s Investors Service', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Moodys Investors Service', axis=1)

Aaa_Corp_Bond['Nat\'l Assn. of Realtors'] = Aaa_Corp_Bond['Nat\'l Assn. of Realtors'].combine_first(Aaa_Corp_Bond['Nat\'l Assn, of Realtors'])
Aaa_Corp_Bond['Nat\'l Assn. of Realtors'] = Aaa_Corp_Bond['Nat\'l Assn. of Realtors'].combine_first(Aaa_Corp_Bond['Nat\'I Assn, of Realtors'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Nat\'l Assn, of Realtors', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Nat\'I Assn, of Realtors', axis=1)

Aaa_Corp_Bond['National City Bank'] = Aaa_Corp_Bond['National City Bank'].combine_first(Aaa_Corp_Bond['National City Corporation'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('National City Corporation', axis=1)

Aaa_Corp_Bond['Nomura Securities Inc.'] = Aaa_Corp_Bond['Nomura Securities Inc.'].combine_first(Aaa_Corp_Bond['Nomura Securities, Inc.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Nomura Securities, Inc.', axis=1)

Aaa_Corp_Bond['October Consensus'] = Aaa_Corp_Bond['October Consensus'].combine_first(Aaa_Corp_Bond['Octoberber Consensus'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Octoberber Consensus', axis=1)

Aaa_Corp_Bond['PNC Bank Corp.'] = Aaa_Corp_Bond['PNC Bank Corp.'].combine_first(Aaa_Corp_Bond['PNC Financial Services'])
Aaa_Corp_Bond['PNC Bank Corp.'] = Aaa_Corp_Bond['PNC Bank Corp.'].combine_first(Aaa_Corp_Bond['PNC Financial Services Corp.'])
Aaa_Corp_Bond['PNC Bank Corp.'] = Aaa_Corp_Bond['PNC Bank Corp.'].combine_first(Aaa_Corp_Bond['PNC Financial Services Group'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('PNC Financial Services', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('PNC Financial Services Corp.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('PNC Financial Services Group', axis=1)

Aaa_Corp_Bond['Prudential Securities'] = Aaa_Corp_Bond['Prudential Securities'].combine_first(Aaa_Corp_Bond['Prudential Equity Group LLC'])
Aaa_Corp_Bond['Prudential Securities'] = Aaa_Corp_Bond['Prudential Securities'].combine_first(Aaa_Corp_Bond['Prudential Insurance Co.'])
Aaa_Corp_Bond['Prudential Securities'] = Aaa_Corp_Bond['Prudential Securities'].combine_first(Aaa_Corp_Bond['Prudential Financial'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Prudential Financial', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Prudential Insurance Co.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Prudential Equity Group LLC', axis=1)

Aaa_Corp_Bond['RBS Greenwich Capital Econ.'] = Aaa_Corp_Bond['RBS Greenwich Capital Econ.'].combine_first(Aaa_Corp_Bond['RBS Securities'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('RBS Securities', axis=1)

Aaa_Corp_Bond['RBC'] = Aaa_Corp_Bond['RBC'].combine_first(Aaa_Corp_Bond['RBC Capital Markets'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('RBC Capital Markets', axis=1)

Aaa_Corp_Bond['RDQ Economics'] = Aaa_Corp_Bond['RDQ Economics'].combine_first(Aaa_Corp_Bond['RDQ'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('RDQ', axis=1)

Aaa_Corp_Bond['RidgeWorth Investments'] = Aaa_Corp_Bond['RidgeWorth Investments'].combine_first(Aaa_Corp_Bond['RidgeWorth Capital Management'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('RidgeWorth Capital Management', axis=1)

Aaa_Corp_Bond['S&P Global'] = Aaa_Corp_Bond['S&P Global'].combine_first(Aaa_Corp_Bond['S&P Global Market Intelligence'])
Aaa_Corp_Bond['S&P Global'] = Aaa_Corp_Bond['S&P Global'].combine_first(Aaa_Corp_Bond['S&P Global Ratings'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('S&P Global Market Intelligence', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('S&P Global Ratings', axis=1)

Aaa_Corp_Bond['Scotiabank Group'] = Aaa_Corp_Bond['Scotiabank Group'].combine_first(Aaa_Corp_Bond['Scotiabank'])
Aaa_Corp_Bond['Scotiabank Group'] = Aaa_Corp_Bond['Scotiabank Group'].combine_first(Aaa_Corp_Bond['Scotia Capital'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Scotia Capital', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Scotiabank', axis=1)

Aaa_Corp_Bond['September Consensus'] = Aaa_Corp_Bond['September Consensus'].combine_first(Aaa_Corp_Bond['Sept. Consensus'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Sept. Consensus', axis=1)

Aaa_Corp_Bond['Standard & Poor\'s'] = Aaa_Corp_Bond['Standard & Poor\'s'].combine_first(Aaa_Corp_Bond['Standard & Poor\'s Corp.'])
Aaa_Corp_Bond['Standard & Poor\'s'] = Aaa_Corp_Bond['Standard & Poor\'s'].combine_first(Aaa_Corp_Bond['Standard & Poors'])
Aaa_Corp_Bond['Standard & Poor\'s'] = Aaa_Corp_Bond['Standard & Poor\'s'].combine_first(Aaa_Corp_Bond['Standard & Poor’s Corp.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Standard & Poor’s Corp.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Standard & Poor\'s Corp.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Standard & Poors', axis=1)

Aaa_Corp_Bond['Swiss Re'] = Aaa_Corp_Bond['Swiss Re'].combine_first(Aaa_Corp_Bond['Sw iss Re'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Sw iss Re', axis=1)

Aaa_Corp_Bond['Thredgold Economics'] = Aaa_Corp_Bond['Thredgold Economics'].combine_first(Aaa_Corp_Bond['Thredgold Economic Assoc.'])
Aaa_Corp_Bond['Thredgold Economics'] = Aaa_Corp_Bond['Thredgold Economics'].combine_first(Aaa_Corp_Bond['Thredgota Economic Assoc.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Thredgold Economic Assoc.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Thredgota Economic Assoc.', axis=1)

Aaa_Corp_Bond['Tokai Bank, Ltd.'] = Aaa_Corp_Bond['Tokai Bank, Ltd.'].combine_first(Aaa_Corp_Bond['Tokai Bank, Lid.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Tokai Bank, Lid.', axis=1)

Aaa_Corp_Bond['Wayne Hummer & Co.'] = Aaa_Corp_Bond['Wayne Hummer & Co.'].combine_first(Aaa_Corp_Bond['Wayne Hummer Investments'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Wayne Hummer Investments', axis=1)

Aaa_Corp_Bond['Wachovia'] = Aaa_Corp_Bond['Wachovia'].combine_first(Aaa_Corp_Bond['Wachovia Securities'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Wachovia Securities', axis=1)

Aaa_Corp_Bond['Wells Fargo'] = Aaa_Corp_Bond['Wells Fargo'].combine_first(Aaa_Corp_Bond['Wells Capital Management'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Wells Capital Management', axis=1)

Aaa_Corp_Bond['Woodworth Holdings'] = Aaa_Corp_Bond['Woodworth Holdings'].combine_first(Aaa_Corp_Bond['Woodw orth Holdings'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Woodw orth Holdings', axis=1)

Aaa_Corp_Bond['independent Economic Advisory'] = Aaa_Corp_Bond['independent Economic Advisory'].combine_first(Aaa_Corp_Bond['independent Econ. Advisory'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('independent Econ. Advisory', axis=1)

Aaa_Corp_Bond['MacroFin Analytics'] = Aaa_Corp_Bond['MacroFin Analytics'].combine_first(Aaa_Corp_Bond['MacroFin Analytics & RBS'])
Aaa_Corp_Bond['MacroFin Analytics'] = Aaa_Corp_Bond['MacroFin Analytics'].combine_first(Aaa_Corp_Bond['MacroFin Analytics & Rutgers Bus School'])
Aaa_Corp_Bond['MacroFin Analytics'] = Aaa_Corp_Bond['MacroFin Analytics'].combine_first(Aaa_Corp_Bond['MacroFin Analytics/Rutgers Bus School'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('MacroFin Analytics & RBS', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Aaa_Corp_Bond['Mesirow Financial'] = Aaa_Corp_Bond['Mesirow  Financial'].combine_first(Aaa_Corp_Bond['Mesirow  Financial'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Mesirow  Financial', axis=1)

Aaa_Corp_Bond['Merrill Lynch'] = Aaa_Corp_Bond['Merrill Lynch'].combine_first(Aaa_Corp_Bond['Merrill Lynch Economics'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Merrill Lynch Economics', axis=1)

Aaa_Corp_Bond['LaSalle Nat\'I Bank'] = Aaa_Corp_Bond['LaSalle Nat\'I Bank'].combine_first(Aaa_Corp_Bond['LaSalle Nat\'l Bank'])
Aaa_Corp_Bond['LaSalle Nat\'I Bank'] = Aaa_Corp_Bond['LaSalle Nat\'I Bank'].combine_first(Aaa_Corp_Bond['LaSalle Natl Bank'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('LaSalle Nat\'l Bank', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('LaSalle Natl Bank', axis=1)

Aaa_Corp_Bond['Kellner Economic Advisers'] = Aaa_Corp_Bond['Kellner Economic Advisers'].combine_first(Aaa_Corp_Bond['Keller Economic Advisers'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Keller Economic Advisers', axis=1)

Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['J.P. Morgan Chase'])
Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['J.P. Morgan Chase'])
Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['JPMorgan Asset Mgt.'])
Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['JPMorgan Fleming Asset Mgt.'])
Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['JPMorgan Privare Client Services'])
Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['JPMorgan Privare Wealth Mgt.'])
Aaa_Corp_Bond['J.P. Morgan'] = Aaa_Corp_Bond['J.P. Morgan'].combine_first(Aaa_Corp_Bond['JPMorgan Private Banking'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('JPMorgan Private Banking', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('JPMorgan Privare Client Services', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('JPMorgan Asset Mgt.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('J.P. Morgan Chase', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('J.P. MorganChase', axis=1)

Aaa_Corp_Bond['Independent Economic Advisory'] = Aaa_Corp_Bond['Independent Economic Advisory'].combine_first(Aaa_Corp_Bond['Independent Econ. Advisory'])
Aaa_Corp_Bond['Independent Economic Advisory'] = Aaa_Corp_Bond['Independent Economic Advisory'].combine_first(Aaa_Corp_Bond['Investment Economics Advisory'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Independent Econ. Advisory', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Investment Economics Advisory', axis=1)
                                         
Aaa_Corp_Bond['ING'] = Aaa_Corp_Bond['ING'].combine_first(Aaa_Corp_Bond['ING Investment Mgt.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('ING Investment Mgt.', axis=1)

Aaa_Corp_Bond['Huntington Nat\'I Bank'] = Aaa_Corp_Bond['Huntington Nat\'I Bank'].combine_first(Aaa_Corp_Bond['Huntington Nat\'l Bank'])
Aaa_Corp_Bond['Huntington Nat\'I Bank'] = Aaa_Corp_Bond['Huntington Nat\'I Bank'].combine_first(Aaa_Corp_Bond['Huntington Natl Bank'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Huntington Nat\'l Bank', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Huntington Natl Bank', axis=1)

Aaa_Corp_Bond['Goldman Sachs'] = Aaa_Corp_Bond['Goldman Sachs'].combine_first(Aaa_Corp_Bond['Goldman Sachs & Co,'])
Aaa_Corp_Bond['Goldman Sachs'] = Aaa_Corp_Bond['Goldman Sachs'].combine_first(Aaa_Corp_Bond['Goldman Sachs & Co.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Goldman Sachs & Co,', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Goldman Sachs & Co.', axis=1)

Aaa_Corp_Bond['Genetski Financial Advisors'] = Aaa_Corp_Bond['Genetski Financial Advisors'].combine_first(Aaa_Corp_Bond['Genetski.com'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Genetski.com', axis=1)

Aaa_Corp_Bond['Fannie Mae'] = Aaa_Corp_Bond['Fannie Mae'].combine_first(Aaa_Corp_Bond['Fannie Mae '])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Fannie Mae ', axis=1)

Aaa_Corp_Bond['Deutsche Bank Securities'] = Aaa_Corp_Bond['Deutsche Bank Securities'].combine_first(Aaa_Corp_Bond['Deutsche Bank Securities, Inc.'])
Aaa_Corp_Bond['Deutsche Bank Securities'] = Aaa_Corp_Bond['Deutsche Bank Securities'].combine_first(Aaa_Corp_Bond['Deutsche Bank Securities, inc.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Deutsche Bank Securities, Inc.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Deutsche Bank Securities, inc.', axis=1)

Aaa_Corp_Bond['DePrince & Associates'] = Aaa_Corp_Bond['DePrince & Associates'].combine_first(Aaa_Corp_Bond['DePrince & Assoc.'])
Aaa_Corp_Bond['DePrince & Associates'] = Aaa_Corp_Bond['DePrince & Associates'].combine_first(Aaa_Corp_Bond['DePrince Associates'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('DePrince & Assoc.', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('DePrince Associates', axis=1)

Aaa_Corp_Bond['Aeltus Investment'] = Aaa_Corp_Bond['Aeltus Investment'].combine_first(Aaa_Corp_Bond['Aeitus Investment'])
Aaa_Corp_Bond['Aeltus Investment'] = Aaa_Corp_Bond['Aeltus Investment'].combine_first(Aaa_Corp_Bond['Aeltus investment'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Aeitus Investment', axis=1)
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Aeltus investment', axis=1)

Aaa_Corp_Bond['ASB Capital Management'] = Aaa_Corp_Bond['ASB Capital Management'].combine_first(Aaa_Corp_Bond['ASB Captial Management'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('ASB Captial Management', axis=1)

Aaa_Corp_Bond['BMO Nesbitt Burns'] = Aaa_Corp_Bond['BMO Nesbitt Burns'].combine_first(Aaa_Corp_Bond['BMC Nesbitt Burns'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('BMC Nesbitt Burns', axis=1)

Aaa_Corp_Bond['Banc One Invest. Advisors'] = Aaa_Corp_Bond['Banc One Invest. Advisors'].combine_first(Aaa_Corp_Bond['Banc One invest. Advisors'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Banc One invest. Advisors', axis=1)

Aaa_Corp_Bond['Banc of America Securities'] = Aaa_Corp_Bond['Banc of America Securities'].combine_first(Aaa_Corp_Bond['Banc of Amercia Securities'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Banc of Amercia Securities', axis=1)

Aaa_Corp_Bond['Banc of America Securities'] = Aaa_Corp_Bond['Banc of America Securities'].combine_first(Aaa_Corp_Bond['Banc of America Securities, LLC'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Banc of America Securities, LLC', axis=1)

Aaa_Corp_Bond['Bank of America Merrill Lynch'] = Aaa_Corp_Bond['Bank of America Merrill Lynch'].combine_first(Aaa_Corp_Bond['Bank of America-Merrill Lynch'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Bank of America-Merrill Lynch', axis=1)
Aaa_Corp_Bond['Bank of America Merrill Lynch'] = Aaa_Corp_Bond['Banc of America-Merrill Lynch'].combine_first(Aaa_Corp_Bond['Banc of America-Merrill Lynch'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Banc of America-Merrill Lynch', axis=1)

Aaa_Corp_Bond['Bank of Toyko-Mitsubishi'] = Aaa_Corp_Bond['Bank of Toyko-Mitsubishi'].combine_first(Aaa_Corp_Bond['Bank of Toyko-Mitsubishi UFJ'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Aaa_Corp_Bond['Barclays'] = Aaa_Corp_Bond['Barclays'].combine_first(Aaa_Corp_Bond['Barclays Capital'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Barclays Capital', axis=1)

Aaa_Corp_Bond['Bear Stearns'] = Aaa_Corp_Bond['Bear Stearns'].combine_first(Aaa_Corp_Bond['Bear Stearns & Co.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Bear Stearns & Co.', axis=1)
Aaa_Corp_Bond['Bear Stearns'] = Aaa_Corp_Bond['Bear Stearns'].combine_first(Aaa_Corp_Bond['Bear Steams & Co.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Bear Steams & Co.', axis=1)

Aaa_Corp_Bond['Camilli Economics'] = Aaa_Corp_Bond['Camilli Economics'].combine_first(Aaa_Corp_Bond['Camilli Economics LLC'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Camilli Economics LLC', axis=1)
Aaa_Corp_Bond['Camilli Economics'] = Aaa_Corp_Bond['Camilli Economics'].combine_first(Aaa_Corp_Bond['Camilli, Kathleen'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Camilli, Kathleen', axis=1)

Aaa_Corp_Bond['Citibank Global Asset Mgmt'] = Aaa_Corp_Bond['Citibank Global Asset Mgmt'].combine_first(Aaa_Corp_Bond['Citibank Global Asset Mgmt.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Citibank Global Asset Mgmt.', axis=1)
Aaa_Corp_Bond['Citibank Global Asset Mgmt'] = Aaa_Corp_Bond['Citibank Global Asset Mgmt'].combine_first(Aaa_Corp_Bond['Citigroup Asset Management'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Citigroup Asset Management', axis=1)

Aaa_Corp_Bond['ClearView Economics'] = Aaa_Corp_Bond['ClearView Economics'].combine_first(Aaa_Corp_Bond['ClearView Associates'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('ClearView Associates', axis=1)
Aaa_Corp_Bond['ClearView Economics'] = Aaa_Corp_Bond['ClearView Economics'].combine_first(Aaa_Corp_Bond['ClearView  Economics'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('ClearView  Economics', axis=1)

Aaa_Corp_Bond['Comerica Bank'] = Aaa_Corp_Bond['Comerica Bank'].combine_first(Aaa_Corp_Bond['Commerica'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Commerica', axis=1)

Aaa_Corp_Bond['Cycledata Corp.'] = Aaa_Corp_Bond['Cycledata Corp.'].combine_first(Aaa_Corp_Bond['Cycledata corp.'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Cycledata corp.', axis=1)

Aaa_Corp_Bond['Daiwa Capital Markets America'] = Aaa_Corp_Bond['Daiwa Capital Markets America'].combine_first(Aaa_Corp_Bond['Daiw a Capital Markets America'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Daiw a Capital Markets America', axis=1)
Aaa_Corp_Bond['Daiwa Capital Markets America'] = Aaa_Corp_Bond['Daiwa Capital Markets America'].combine_first(Aaa_Corp_Bond['Daiwa Securities America'])
Aaa_Corp_Bond = Aaa_Corp_Bond.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Baa_Corp_Bond['Moody\'s Analytics'] = Baa_Corp_Bond['Moody\'s Analytics'].combine_first(Baa_Corp_Bond['Moody\'s Capital Markets'])
Baa_Corp_Bond['Moody\'s Analytics'] = Baa_Corp_Bond['Moody\'s Analytics'].combine_first(Baa_Corp_Bond['Moody\'s Capital Markets Group'])
Baa_Corp_Bond['Moody\'s Analytics'] = Baa_Corp_Bond['Moody\'s Analytics'].combine_first(Baa_Corp_Bond['Moody\'s Econmy.com'])
Baa_Corp_Bond['Moody\'s Analytics'] = Baa_Corp_Bond['Moody\'s Analytics'].combine_first(Baa_Corp_Bond['Moody\'s Economy.com'])
Baa_Corp_Bond['Moody\'s Analytics'] = Baa_Corp_Bond['Moody\'s Analytics'].combine_first(Baa_Corp_Bond['Moody\'s Investors Service'])
Baa_Corp_Bond['Moody\'s Analytics'] = Baa_Corp_Bond['Moody\'s Analytics'].combine_first(Baa_Corp_Bond['Moodys Investors Service'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Moody\'s Capital Markets', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Moody\'s Capital Markets Group', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Moody\'s Econmy.com', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Moody\'s Economy.com', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Moody\'s Investors Service', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Moodys Investors Service', axis=1)

Baa_Corp_Bond['Nat\'l Assn. of Realtors'] = Baa_Corp_Bond['Nat\'l Assn. of Realtors'].combine_first(Baa_Corp_Bond['Nat\'l Assn, of Realtors'])
Baa_Corp_Bond['Nat\'l Assn. of Realtors'] = Baa_Corp_Bond['Nat\'l Assn. of Realtors'].combine_first(Baa_Corp_Bond['Nat\'I Assn, of Realtors'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Nat\'l Assn, of Realtors', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Nat\'I Assn, of Realtors', axis=1)

Baa_Corp_Bond['National City Bank'] = Baa_Corp_Bond['National City Bank'].combine_first(Baa_Corp_Bond['National City Corporation'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('National City Corporation', axis=1)

Baa_Corp_Bond['Nomura Securities Inc.'] = Baa_Corp_Bond['Nomura Securities Inc.'].combine_first(Baa_Corp_Bond['Nomura Securities, Inc.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Nomura Securities, Inc.', axis=1)

Baa_Corp_Bond['October Consensus'] = Baa_Corp_Bond['October Consensus'].combine_first(Baa_Corp_Bond['Octoberber Consensus'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Octoberber Consensus', axis=1)

Baa_Corp_Bond['PNC Bank Corp.'] = Baa_Corp_Bond['PNC Bank Corp.'].combine_first(Baa_Corp_Bond['PNC Financial Services'])
Baa_Corp_Bond['PNC Bank Corp.'] = Baa_Corp_Bond['PNC Bank Corp.'].combine_first(Baa_Corp_Bond['PNC Financial Services Corp.'])
Baa_Corp_Bond['PNC Bank Corp.'] = Baa_Corp_Bond['PNC Bank Corp.'].combine_first(Baa_Corp_Bond['PNC Financial Services Group'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('PNC Financial Services', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('PNC Financial Services Corp.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('PNC Financial Services Group', axis=1)

Baa_Corp_Bond['Prudential Securities'] = Baa_Corp_Bond['Prudential Securities'].combine_first(Baa_Corp_Bond['Prudential Equity Group LLC'])
Baa_Corp_Bond['Prudential Securities'] = Baa_Corp_Bond['Prudential Securities'].combine_first(Baa_Corp_Bond['Prudential Insurance Co.'])
Baa_Corp_Bond['Prudential Securities'] = Baa_Corp_Bond['Prudential Securities'].combine_first(Baa_Corp_Bond['Prudential Financial'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Prudential Financial', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Prudential Insurance Co.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Prudential Equity Group LLC', axis=1)

Baa_Corp_Bond['RBS Greenwich Capital Econ.'] = Baa_Corp_Bond['RBS Greenwich Capital Econ.'].combine_first(Baa_Corp_Bond['RBS Securities'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('RBS Securities', axis=1)

Baa_Corp_Bond['RBC'] = Baa_Corp_Bond['RBC'].combine_first(Baa_Corp_Bond['RBC Capital Markets'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('RBC Capital Markets', axis=1)

Baa_Corp_Bond['RDQ Economics'] = Baa_Corp_Bond['RDQ Economics'].combine_first(Baa_Corp_Bond['RDQ'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('RDQ', axis=1)

Baa_Corp_Bond['RidgeWorth Investments'] = Baa_Corp_Bond['RidgeWorth Investments'].combine_first(Baa_Corp_Bond['RidgeWorth Capital Management'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('RidgeWorth Capital Management', axis=1)

Baa_Corp_Bond['S&P Global'] = Baa_Corp_Bond['S&P Global'].combine_first(Baa_Corp_Bond['S&P Global Market Intelligence'])
Baa_Corp_Bond['S&P Global'] = Baa_Corp_Bond['S&P Global'].combine_first(Baa_Corp_Bond['S&P Global Ratings'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('S&P Global Market Intelligence', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('S&P Global Ratings', axis=1)

Baa_Corp_Bond['Scotiabank Group'] = Baa_Corp_Bond['Scotiabank Group'].combine_first(Baa_Corp_Bond['Scotiabank'])
Baa_Corp_Bond['Scotiabank Group'] = Baa_Corp_Bond['Scotiabank Group'].combine_first(Baa_Corp_Bond['Scotia Capital'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Scotia Capital', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Scotiabank', axis=1)

Baa_Corp_Bond['September Consensus'] = Baa_Corp_Bond['September Consensus'].combine_first(Baa_Corp_Bond['Sept. Consensus'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Sept. Consensus', axis=1)

Baa_Corp_Bond['Standard & Poor\'s'] = Baa_Corp_Bond['Standard & Poor\'s'].combine_first(Baa_Corp_Bond['Standard & Poor\'s Corp.'])
Baa_Corp_Bond['Standard & Poor\'s'] = Baa_Corp_Bond['Standard & Poor\'s'].combine_first(Baa_Corp_Bond['Standard & Poors'])
Baa_Corp_Bond['Standard & Poor\'s'] = Baa_Corp_Bond['Standard & Poor\'s'].combine_first(Baa_Corp_Bond['Standard & Poor’s Corp.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Standard & Poor’s Corp.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Standard & Poor\'s Corp.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Standard & Poors', axis=1)

Baa_Corp_Bond['Swiss Re'] = Baa_Corp_Bond['Swiss Re'].combine_first(Baa_Corp_Bond['Sw iss Re'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Sw iss Re', axis=1)

Baa_Corp_Bond['Thredgold Economics'] = Baa_Corp_Bond['Thredgold Economics'].combine_first(Baa_Corp_Bond['Thredgold Economic Assoc.'])
Baa_Corp_Bond['Thredgold Economics'] = Baa_Corp_Bond['Thredgold Economics'].combine_first(Baa_Corp_Bond['Thredgota Economic Assoc.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Thredgold Economic Assoc.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Thredgota Economic Assoc.', axis=1)

Baa_Corp_Bond['Tokai Bank, Ltd.'] = Baa_Corp_Bond['Tokai Bank, Ltd.'].combine_first(Baa_Corp_Bond['Tokai Bank, Lid.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Tokai Bank, Lid.', axis=1)

Baa_Corp_Bond['Wayne Hummer & Co.'] = Baa_Corp_Bond['Wayne Hummer & Co.'].combine_first(Baa_Corp_Bond['Wayne Hummer Investments'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Wayne Hummer Investments', axis=1)

Baa_Corp_Bond['Wachovia'] = Baa_Corp_Bond['Wachovia'].combine_first(Baa_Corp_Bond['Wachovia Securities'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Wachovia Securities', axis=1)

Baa_Corp_Bond['Wells Fargo'] = Baa_Corp_Bond['Wells Fargo'].combine_first(Baa_Corp_Bond['Wells Capital Management'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Wells Capital Management', axis=1)

Baa_Corp_Bond['Woodworth Holdings'] = Baa_Corp_Bond['Woodworth Holdings'].combine_first(Baa_Corp_Bond['Woodw orth Holdings'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Woodw orth Holdings', axis=1)

Baa_Corp_Bond['independent Economic Advisory'] = Baa_Corp_Bond['independent Economic Advisory'].combine_first(Baa_Corp_Bond['independent Econ. Advisory'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('independent Econ. Advisory', axis=1)

Baa_Corp_Bond['MacroFin Analytics'] = Baa_Corp_Bond['MacroFin Analytics'].combine_first(Baa_Corp_Bond['MacroFin Analytics & RBS'])
Baa_Corp_Bond['MacroFin Analytics'] = Baa_Corp_Bond['MacroFin Analytics'].combine_first(Baa_Corp_Bond['MacroFin Analytics & Rutgers Bus School'])
Baa_Corp_Bond['MacroFin Analytics'] = Baa_Corp_Bond['MacroFin Analytics'].combine_first(Baa_Corp_Bond['MacroFin Analytics/Rutgers Bus School'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('MacroFin Analytics & RBS', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Baa_Corp_Bond['Mesirow Financial'] = Baa_Corp_Bond['Mesirow  Financial'].combine_first(Baa_Corp_Bond['Mesirow  Financial'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Mesirow  Financial', axis=1)

Baa_Corp_Bond['Merrill Lynch'] = Baa_Corp_Bond['Merrill Lynch'].combine_first(Baa_Corp_Bond['Merrill Lynch Economics'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Merrill Lynch Economics', axis=1)

Baa_Corp_Bond['LaSalle Nat\'I Bank'] = Baa_Corp_Bond['LaSalle Nat\'I Bank'].combine_first(Baa_Corp_Bond['LaSalle Nat\'l Bank'])
Baa_Corp_Bond['LaSalle Nat\'I Bank'] = Baa_Corp_Bond['LaSalle Nat\'I Bank'].combine_first(Baa_Corp_Bond['LaSalle Natl Bank'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('LaSalle Nat\'l Bank', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('LaSalle Natl Bank', axis=1)

Baa_Corp_Bond['Kellner Economic Advisers'] = Baa_Corp_Bond['Kellner Economic Advisers'].combine_first(Baa_Corp_Bond['Keller Economic Advisers'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Keller Economic Advisers', axis=1)

Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['J.P. Morgan Chase'])
Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['J.P. Morgan Chase'])
Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['JPMorgan Asset Mgt.'])
Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['JPMorgan Fleming Asset Mgt.'])
Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['JPMorgan Privare Client Services'])
Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['JPMorgan Privare Wealth Mgt.'])
Baa_Corp_Bond['J.P. Morgan'] = Baa_Corp_Bond['J.P. Morgan'].combine_first(Baa_Corp_Bond['JPMorgan Private Banking'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('JPMorgan Private Banking', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('JPMorgan Privare Client Services', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('JPMorgan Asset Mgt.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('J.P. Morgan Chase', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('J.P. MorganChase', axis=1)

Baa_Corp_Bond['Independent Economic Advisory'] = Baa_Corp_Bond['Independent Economic Advisory'].combine_first(Baa_Corp_Bond['Independent Econ. Advisory'])
Baa_Corp_Bond['Independent Economic Advisory'] = Baa_Corp_Bond['Independent Economic Advisory'].combine_first(Baa_Corp_Bond['Investment Economics Advisory'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Independent Econ. Advisory', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Investment Economics Advisory', axis=1)
                                         
Baa_Corp_Bond['ING'] = Baa_Corp_Bond['ING'].combine_first(Baa_Corp_Bond['ING Investment Mgt.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('ING Investment Mgt.', axis=1)

Baa_Corp_Bond['Huntington Nat\'I Bank'] = Baa_Corp_Bond['Huntington Nat\'I Bank'].combine_first(Baa_Corp_Bond['Huntington Nat\'l Bank'])
Baa_Corp_Bond['Huntington Nat\'I Bank'] = Baa_Corp_Bond['Huntington Nat\'I Bank'].combine_first(Baa_Corp_Bond['Huntington Natl Bank'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Huntington Nat\'l Bank', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Huntington Natl Bank', axis=1)

Baa_Corp_Bond['Goldman Sachs'] = Baa_Corp_Bond['Goldman Sachs'].combine_first(Baa_Corp_Bond['Goldman Sachs & Co,'])
Baa_Corp_Bond['Goldman Sachs'] = Baa_Corp_Bond['Goldman Sachs'].combine_first(Baa_Corp_Bond['Goldman Sachs & Co.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Goldman Sachs & Co,', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Goldman Sachs & Co.', axis=1)

Baa_Corp_Bond['Genetski Financial Advisors'] = Baa_Corp_Bond['Genetski Financial Advisors'].combine_first(Baa_Corp_Bond['Genetski.com'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Genetski.com', axis=1)

Baa_Corp_Bond['Fannie Mae'] = Baa_Corp_Bond['Fannie Mae'].combine_first(Baa_Corp_Bond['Fannie Mae '])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Fannie Mae ', axis=1)

Baa_Corp_Bond['Deutsche Bank Securities'] = Baa_Corp_Bond['Deutsche Bank Securities'].combine_first(Baa_Corp_Bond['Deutsche Bank Securities, Inc.'])
Baa_Corp_Bond['Deutsche Bank Securities'] = Baa_Corp_Bond['Deutsche Bank Securities'].combine_first(Baa_Corp_Bond['Deutsche Bank Securities, inc.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Deutsche Bank Securities, Inc.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Deutsche Bank Securities, inc.', axis=1)

Baa_Corp_Bond['DePrince & Associates'] = Baa_Corp_Bond['DePrince & Associates'].combine_first(Baa_Corp_Bond['DePrince & Assoc.'])
Baa_Corp_Bond['DePrince & Associates'] = Baa_Corp_Bond['DePrince & Associates'].combine_first(Baa_Corp_Bond['DePrince Associates'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('DePrince & Assoc.', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('DePrince Associates', axis=1)

Baa_Corp_Bond['Aeltus Investment'] = Baa_Corp_Bond['Aeltus Investment'].combine_first(Baa_Corp_Bond['Aeitus Investment'])
Baa_Corp_Bond['Aeltus Investment'] = Baa_Corp_Bond['Aeltus Investment'].combine_first(Baa_Corp_Bond['Aeltus investment'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Aeitus Investment', axis=1)
Baa_Corp_Bond = Baa_Corp_Bond.drop('Aeltus investment', axis=1)

Baa_Corp_Bond['ASB Capital Management'] = Baa_Corp_Bond['ASB Capital Management'].combine_first(Baa_Corp_Bond['ASB Captial Management'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('ASB Captial Management', axis=1)

Baa_Corp_Bond['BMO Nesbitt Burns'] = Baa_Corp_Bond['BMO Nesbitt Burns'].combine_first(Baa_Corp_Bond['BMC Nesbitt Burns'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('BMC Nesbitt Burns', axis=1)

Baa_Corp_Bond['Banc One Invest. Advisors'] = Baa_Corp_Bond['Banc One Invest. Advisors'].combine_first(Baa_Corp_Bond['Banc One invest. Advisors'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Banc One invest. Advisors', axis=1)

Baa_Corp_Bond['Banc of America Securities'] = Baa_Corp_Bond['Banc of America Securities'].combine_first(Baa_Corp_Bond['Banc of Amercia Securities'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Banc of Amercia Securities', axis=1)

Baa_Corp_Bond['Banc of America Securities'] = Baa_Corp_Bond['Banc of America Securities'].combine_first(Baa_Corp_Bond['Banc of America Securities, LLC'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Banc of America Securities, LLC', axis=1)

Baa_Corp_Bond['Bank of America Merrill Lynch'] = Baa_Corp_Bond['Bank of America Merrill Lynch'].combine_first(Baa_Corp_Bond['Bank of America-Merrill Lynch'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Bank of America-Merrill Lynch', axis=1)
Baa_Corp_Bond['Bank of America Merrill Lynch'] = Baa_Corp_Bond['Banc of America-Merrill Lynch'].combine_first(Baa_Corp_Bond['Banc of America-Merrill Lynch'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Banc of America-Merrill Lynch', axis=1)

Baa_Corp_Bond['Bank of Toyko-Mitsubishi'] = Baa_Corp_Bond['Bank of Toyko-Mitsubishi'].combine_first(Baa_Corp_Bond['Bank of Toyko-Mitsubishi UFJ'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Baa_Corp_Bond['Barclays'] = Baa_Corp_Bond['Barclays'].combine_first(Baa_Corp_Bond['Barclays Capital'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Barclays Capital', axis=1)

Baa_Corp_Bond['Bear Stearns'] = Baa_Corp_Bond['Bear Stearns'].combine_first(Baa_Corp_Bond['Bear Stearns & Co.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Bear Stearns & Co.', axis=1)
Baa_Corp_Bond['Bear Stearns'] = Baa_Corp_Bond['Bear Stearns'].combine_first(Baa_Corp_Bond['Bear Steams & Co.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Bear Steams & Co.', axis=1)

Baa_Corp_Bond['Camilli Economics'] = Baa_Corp_Bond['Camilli Economics'].combine_first(Baa_Corp_Bond['Camilli Economics LLC'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Camilli Economics LLC', axis=1)
Baa_Corp_Bond['Camilli Economics'] = Baa_Corp_Bond['Camilli Economics'].combine_first(Baa_Corp_Bond['Camilli, Kathleen'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Camilli, Kathleen', axis=1)

Baa_Corp_Bond['Citibank Global Asset Mgmt'] = Baa_Corp_Bond['Citibank Global Asset Mgmt'].combine_first(Baa_Corp_Bond['Citibank Global Asset Mgmt.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Citibank Global Asset Mgmt.', axis=1)
Baa_Corp_Bond['Citibank Global Asset Mgmt'] = Baa_Corp_Bond['Citibank Global Asset Mgmt'].combine_first(Baa_Corp_Bond['Citigroup Asset Management'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Citigroup Asset Management', axis=1)

Baa_Corp_Bond['ClearView Economics'] = Baa_Corp_Bond['ClearView Economics'].combine_first(Baa_Corp_Bond['ClearView Associates'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('ClearView Associates', axis=1)
Baa_Corp_Bond['ClearView Economics'] = Baa_Corp_Bond['ClearView Economics'].combine_first(Baa_Corp_Bond['ClearView  Economics'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('ClearView  Economics', axis=1)

Baa_Corp_Bond['Comerica Bank'] = Baa_Corp_Bond['Comerica Bank'].combine_first(Baa_Corp_Bond['Commerica'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Commerica', axis=1)

Baa_Corp_Bond['Cycledata Corp.'] = Baa_Corp_Bond['Cycledata Corp.'].combine_first(Baa_Corp_Bond['Cycledata corp.'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Cycledata corp.', axis=1)

Baa_Corp_Bond['Daiwa Capital Markets America'] = Baa_Corp_Bond['Daiwa Capital Markets America'].combine_first(Baa_Corp_Bond['Daiw a Capital Markets America'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Daiw a Capital Markets America', axis=1)
Baa_Corp_Bond['Daiwa Capital Markets America'] = Baa_Corp_Bond['Daiwa Capital Markets America'].combine_first(Baa_Corp_Bond['Daiwa Securities America'])
Baa_Corp_Bond = Baa_Corp_Bond.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
State_Local_Bonds['Moody\'s Analytics'] = State_Local_Bonds['Moody\'s Analytics'].combine_first(State_Local_Bonds['Moody\'s Capital Markets'])
State_Local_Bonds['Moody\'s Analytics'] = State_Local_Bonds['Moody\'s Analytics'].combine_first(State_Local_Bonds['Moody\'s Capital Markets Group'])
State_Local_Bonds['Moody\'s Analytics'] = State_Local_Bonds['Moody\'s Analytics'].combine_first(State_Local_Bonds['Moody\'s Econmy.com'])
State_Local_Bonds['Moody\'s Analytics'] = State_Local_Bonds['Moody\'s Analytics'].combine_first(State_Local_Bonds['Moody\'s Economy.com'])
State_Local_Bonds['Moody\'s Analytics'] = State_Local_Bonds['Moody\'s Analytics'].combine_first(State_Local_Bonds['Moody\'s Investors Service'])
State_Local_Bonds['Moody\'s Analytics'] = State_Local_Bonds['Moody\'s Analytics'].combine_first(State_Local_Bonds['Moodys Investors Service'])
State_Local_Bonds = State_Local_Bonds.drop('Moody\'s Capital Markets', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Moody\'s Capital Markets Group', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Moody\'s Econmy.com', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Moody\'s Economy.com', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Moody\'s Investors Service', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Moodys Investors Service', axis=1)

State_Local_Bonds['Nat\'l Assn. of Realtors'] = State_Local_Bonds['Nat\'l Assn. of Realtors'].combine_first(State_Local_Bonds['Nat\'l Assn, of Realtors'])
State_Local_Bonds['Nat\'l Assn. of Realtors'] = State_Local_Bonds['Nat\'l Assn. of Realtors'].combine_first(State_Local_Bonds['Nat\'I Assn, of Realtors'])
State_Local_Bonds = State_Local_Bonds.drop('Nat\'l Assn, of Realtors', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Nat\'I Assn, of Realtors', axis=1)

State_Local_Bonds['National City Bank'] = State_Local_Bonds['National City Bank'].combine_first(State_Local_Bonds['National City Corporation'])
State_Local_Bonds = State_Local_Bonds.drop('National City Corporation', axis=1)

State_Local_Bonds['Nomura Securities Inc.'] = State_Local_Bonds['Nomura Securities Inc.'].combine_first(State_Local_Bonds['Nomura Securities, Inc.'])
State_Local_Bonds = State_Local_Bonds.drop('Nomura Securities, Inc.', axis=1)

State_Local_Bonds['October Consensus'] = State_Local_Bonds['October Consensus'].combine_first(State_Local_Bonds['Octoberber Consensus'])
State_Local_Bonds = State_Local_Bonds.drop('Octoberber Consensus', axis=1)

State_Local_Bonds['PNC Bank Corp.'] = State_Local_Bonds['PNC Bank Corp.'].combine_first(State_Local_Bonds['PNC Financial Services'])
State_Local_Bonds['PNC Bank Corp.'] = State_Local_Bonds['PNC Bank Corp.'].combine_first(State_Local_Bonds['PNC Financial Services Corp.'])
State_Local_Bonds['PNC Bank Corp.'] = State_Local_Bonds['PNC Bank Corp.'].combine_first(State_Local_Bonds['PNC Financial Services Group'])
State_Local_Bonds = State_Local_Bonds.drop('PNC Financial Services', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('PNC Financial Services Corp.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('PNC Financial Services Group', axis=1)

State_Local_Bonds['Prudential Securities'] = State_Local_Bonds['Prudential Securities'].combine_first(State_Local_Bonds['Prudential Equity Group LLC'])
State_Local_Bonds['Prudential Securities'] = State_Local_Bonds['Prudential Securities'].combine_first(State_Local_Bonds['Prudential Insurance Co.'])
State_Local_Bonds['Prudential Securities'] = State_Local_Bonds['Prudential Securities'].combine_first(State_Local_Bonds['Prudential Financial'])
State_Local_Bonds = State_Local_Bonds.drop('Prudential Financial', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Prudential Insurance Co.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Prudential Equity Group LLC', axis=1)

State_Local_Bonds['RBS Greenwich Capital Econ.'] = State_Local_Bonds['RBS Greenwich Capital Econ.'].combine_first(State_Local_Bonds['RBS Securities'])
State_Local_Bonds = State_Local_Bonds.drop('RBS Securities', axis=1)

State_Local_Bonds['RBC'] = State_Local_Bonds['RBC'].combine_first(State_Local_Bonds['RBC Capital Markets'])
State_Local_Bonds = State_Local_Bonds.drop('RBC Capital Markets', axis=1)

State_Local_Bonds['RDQ Economics'] = State_Local_Bonds['RDQ Economics'].combine_first(State_Local_Bonds['RDQ'])
State_Local_Bonds = State_Local_Bonds.drop('RDQ', axis=1)

State_Local_Bonds['RidgeWorth Investments'] = State_Local_Bonds['RidgeWorth Investments'].combine_first(State_Local_Bonds['RidgeWorth Capital Management'])
State_Local_Bonds = State_Local_Bonds.drop('RidgeWorth Capital Management', axis=1)

State_Local_Bonds['S&P Global'] = State_Local_Bonds['S&P Global'].combine_first(State_Local_Bonds['S&P Global Market Intelligence'])
State_Local_Bonds['S&P Global'] = State_Local_Bonds['S&P Global'].combine_first(State_Local_Bonds['S&P Global Ratings'])
State_Local_Bonds = State_Local_Bonds.drop('S&P Global Market Intelligence', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('S&P Global Ratings', axis=1)

State_Local_Bonds['Scotiabank Group'] = State_Local_Bonds['Scotiabank Group'].combine_first(State_Local_Bonds['Scotiabank'])
State_Local_Bonds['Scotiabank Group'] = State_Local_Bonds['Scotiabank Group'].combine_first(State_Local_Bonds['Scotia Capital'])
State_Local_Bonds = State_Local_Bonds.drop('Scotia Capital', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Scotiabank', axis=1)

State_Local_Bonds['September Consensus'] = State_Local_Bonds['September Consensus'].combine_first(State_Local_Bonds['Sept. Consensus'])
State_Local_Bonds = State_Local_Bonds.drop('Sept. Consensus', axis=1)

State_Local_Bonds['Standard & Poor\'s'] = State_Local_Bonds['Standard & Poor\'s'].combine_first(State_Local_Bonds['Standard & Poor\'s Corp.'])
State_Local_Bonds['Standard & Poor\'s'] = State_Local_Bonds['Standard & Poor\'s'].combine_first(State_Local_Bonds['Standard & Poors'])
State_Local_Bonds['Standard & Poor\'s'] = State_Local_Bonds['Standard & Poor\'s'].combine_first(State_Local_Bonds['Standard & Poor’s Corp.'])
State_Local_Bonds = State_Local_Bonds.drop('Standard & Poor’s Corp.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Standard & Poor\'s Corp.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Standard & Poors', axis=1)

State_Local_Bonds['Swiss Re'] = State_Local_Bonds['Swiss Re'].combine_first(State_Local_Bonds['Sw iss Re'])
State_Local_Bonds = State_Local_Bonds.drop('Sw iss Re', axis=1)

State_Local_Bonds['Thredgold Economics'] = State_Local_Bonds['Thredgold Economics'].combine_first(State_Local_Bonds['Thredgold Economic Assoc.'])
State_Local_Bonds['Thredgold Economics'] = State_Local_Bonds['Thredgold Economics'].combine_first(State_Local_Bonds['Thredgota Economic Assoc.'])
State_Local_Bonds = State_Local_Bonds.drop('Thredgold Economic Assoc.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Thredgota Economic Assoc.', axis=1)

State_Local_Bonds['Tokai Bank, Ltd.'] = State_Local_Bonds['Tokai Bank, Ltd.'].combine_first(State_Local_Bonds['Tokai Bank, Lid.'])
State_Local_Bonds = State_Local_Bonds.drop('Tokai Bank, Lid.', axis=1)

State_Local_Bonds['Wayne Hummer & Co.'] = State_Local_Bonds['Wayne Hummer & Co.'].combine_first(State_Local_Bonds['Wayne Hummer Investments'])
State_Local_Bonds = State_Local_Bonds.drop('Wayne Hummer Investments', axis=1)

State_Local_Bonds['Wachovia'] = State_Local_Bonds['Wachovia'].combine_first(State_Local_Bonds['Wachovia Securities'])
State_Local_Bonds = State_Local_Bonds.drop('Wachovia Securities', axis=1)

State_Local_Bonds['Wells Fargo'] = State_Local_Bonds['Wells Fargo'].combine_first(State_Local_Bonds['Wells Capital Management'])
State_Local_Bonds = State_Local_Bonds.drop('Wells Capital Management', axis=1)

State_Local_Bonds['Woodworth Holdings'] = State_Local_Bonds['Woodworth Holdings'].combine_first(State_Local_Bonds['Woodw orth Holdings'])
State_Local_Bonds = State_Local_Bonds.drop('Woodw orth Holdings', axis=1)

State_Local_Bonds['independent Economic Advisory'] = State_Local_Bonds['independent Economic Advisory'].combine_first(State_Local_Bonds['independent Econ. Advisory'])
State_Local_Bonds = State_Local_Bonds.drop('independent Econ. Advisory', axis=1)

State_Local_Bonds['MacroFin Analytics'] = State_Local_Bonds['MacroFin Analytics'].combine_first(State_Local_Bonds['MacroFin Analytics & RBS'])
State_Local_Bonds['MacroFin Analytics'] = State_Local_Bonds['MacroFin Analytics'].combine_first(State_Local_Bonds['MacroFin Analytics & Rutgers Bus School'])
State_Local_Bonds['MacroFin Analytics'] = State_Local_Bonds['MacroFin Analytics'].combine_first(State_Local_Bonds['MacroFin Analytics/Rutgers Bus School'])
State_Local_Bonds = State_Local_Bonds.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('MacroFin Analytics & RBS', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

State_Local_Bonds['Mesirow Financial'] = State_Local_Bonds['Mesirow  Financial'].combine_first(State_Local_Bonds['Mesirow  Financial'])
State_Local_Bonds = State_Local_Bonds.drop('Mesirow  Financial', axis=1)

State_Local_Bonds['Merrill Lynch'] = State_Local_Bonds['Merrill Lynch'].combine_first(State_Local_Bonds['Merrill Lynch Economics'])
State_Local_Bonds = State_Local_Bonds.drop('Merrill Lynch Economics', axis=1)

State_Local_Bonds['LaSalle Nat\'I Bank'] = State_Local_Bonds['LaSalle Nat\'I Bank'].combine_first(State_Local_Bonds['LaSalle Nat\'l Bank'])
State_Local_Bonds['LaSalle Nat\'I Bank'] = State_Local_Bonds['LaSalle Nat\'I Bank'].combine_first(State_Local_Bonds['LaSalle Natl Bank'])
State_Local_Bonds = State_Local_Bonds.drop('LaSalle Nat\'l Bank', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('LaSalle Natl Bank', axis=1)

State_Local_Bonds['Kellner Economic Advisers'] = State_Local_Bonds['Kellner Economic Advisers'].combine_first(State_Local_Bonds['Keller Economic Advisers'])
State_Local_Bonds = State_Local_Bonds.drop('Keller Economic Advisers', axis=1)

State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['J.P. Morgan Chase'])
State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['J.P. Morgan Chase'])
State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['JPMorgan Asset Mgt.'])
State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['JPMorgan Fleming Asset Mgt.'])
State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['JPMorgan Privare Client Services'])
State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['JPMorgan Privare Wealth Mgt.'])
State_Local_Bonds['J.P. Morgan'] = State_Local_Bonds['J.P. Morgan'].combine_first(State_Local_Bonds['JPMorgan Private Banking'])
State_Local_Bonds = State_Local_Bonds.drop('JPMorgan Private Banking', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('JPMorgan Privare Wealth Mgt.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('JPMorgan Privare Client Services', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('JPMorgan Fleming Asset Mgt.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('JPMorgan Asset Mgt.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('J.P. Morgan Chase', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('J.P. MorganChase', axis=1)

State_Local_Bonds['Independent Economic Advisory'] = State_Local_Bonds['Independent Economic Advisory'].combine_first(State_Local_Bonds['Independent Econ. Advisory'])
State_Local_Bonds['Independent Economic Advisory'] = State_Local_Bonds['Independent Economic Advisory'].combine_first(State_Local_Bonds['Investment Economics Advisory'])
State_Local_Bonds = State_Local_Bonds.drop('Independent Econ. Advisory', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Investment Economics Advisory', axis=1)
                                         
State_Local_Bonds['ING'] = State_Local_Bonds['ING'].combine_first(State_Local_Bonds['ING Investment Mgt.'])
State_Local_Bonds = State_Local_Bonds.drop('ING Investment Mgt.', axis=1)

State_Local_Bonds['Huntington Nat\'I Bank'] = State_Local_Bonds['Huntington Nat\'I Bank'].combine_first(State_Local_Bonds['Huntington Nat\'l Bank'])
State_Local_Bonds['Huntington Nat\'I Bank'] = State_Local_Bonds['Huntington Nat\'I Bank'].combine_first(State_Local_Bonds['Huntington Natl Bank'])
State_Local_Bonds = State_Local_Bonds.drop('Huntington Nat\'l Bank', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Huntington Natl Bank', axis=1)

State_Local_Bonds['Goldman Sachs'] = State_Local_Bonds['Goldman Sachs'].combine_first(State_Local_Bonds['Goldman Sachs & Co,'])
State_Local_Bonds['Goldman Sachs'] = State_Local_Bonds['Goldman Sachs'].combine_first(State_Local_Bonds['Goldman Sachs & Co.'])
State_Local_Bonds = State_Local_Bonds.drop('Goldman Sachs & Co,', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Goldman Sachs & Co.', axis=1)

State_Local_Bonds['Genetski Financial Advisors'] = State_Local_Bonds['Genetski Financial Advisors'].combine_first(State_Local_Bonds['Genetski.com'])
State_Local_Bonds = State_Local_Bonds.drop('Genetski.com', axis=1)

State_Local_Bonds['Fannie Mae'] = State_Local_Bonds['Fannie Mae'].combine_first(State_Local_Bonds['Fannie Mae '])
State_Local_Bonds = State_Local_Bonds.drop('Fannie Mae ', axis=1)

State_Local_Bonds['Deutsche Bank Securities'] = State_Local_Bonds['Deutsche Bank Securities'].combine_first(State_Local_Bonds['Deutsche Bank Securities, Inc.'])
State_Local_Bonds['Deutsche Bank Securities'] = State_Local_Bonds['Deutsche Bank Securities'].combine_first(State_Local_Bonds['Deutsche Bank Securities, inc.'])
State_Local_Bonds = State_Local_Bonds.drop('Deutsche Bank Securities, Inc.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Deutsche Bank Securities, inc.', axis=1)

State_Local_Bonds['DePrince & Associates'] = State_Local_Bonds['DePrince & Associates'].combine_first(State_Local_Bonds['DePrince & Assoc.'])
State_Local_Bonds['DePrince & Associates'] = State_Local_Bonds['DePrince & Associates'].combine_first(State_Local_Bonds['DePrince Associates'])
State_Local_Bonds = State_Local_Bonds.drop('DePrince & Assoc.', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('DePrince Associates', axis=1)

State_Local_Bonds['Aeltus Investment'] = State_Local_Bonds['Aeltus Investment'].combine_first(State_Local_Bonds['Aeitus Investment'])
State_Local_Bonds['Aeltus Investment'] = State_Local_Bonds['Aeltus Investment'].combine_first(State_Local_Bonds['Aeltus investment'])
State_Local_Bonds = State_Local_Bonds.drop('Aeitus Investment', axis=1)
State_Local_Bonds = State_Local_Bonds.drop('Aeltus investment', axis=1)

State_Local_Bonds['ASB Capital Management'] = State_Local_Bonds['ASB Capital Management'].combine_first(State_Local_Bonds['ASB Captial Management'])
State_Local_Bonds = State_Local_Bonds.drop('ASB Captial Management', axis=1)

State_Local_Bonds['BMO Nesbitt Burns'] = State_Local_Bonds['BMO Nesbitt Burns'].combine_first(State_Local_Bonds['BMC Nesbitt Burns'])
State_Local_Bonds = State_Local_Bonds.drop('BMC Nesbitt Burns', axis=1)

State_Local_Bonds['Banc One Invest. Advisors'] = State_Local_Bonds['Banc One Invest. Advisors'].combine_first(State_Local_Bonds['Banc One invest. Advisors'])
State_Local_Bonds = State_Local_Bonds.drop('Banc One invest. Advisors', axis=1)

State_Local_Bonds['Banc of America Securities'] = State_Local_Bonds['Banc of America Securities'].combine_first(State_Local_Bonds['Banc of Amercia Securities'])
State_Local_Bonds = State_Local_Bonds.drop('Banc of Amercia Securities', axis=1)

State_Local_Bonds['Banc of America Securities'] = State_Local_Bonds['Banc of America Securities'].combine_first(State_Local_Bonds['Banc of America Securities, LLC'])
State_Local_Bonds = State_Local_Bonds.drop('Banc of America Securities, LLC', axis=1)

State_Local_Bonds['Bank of America Merrill Lynch'] = State_Local_Bonds['Bank of America Merrill Lynch'].combine_first(State_Local_Bonds['Bank of America-Merrill Lynch'])
State_Local_Bonds = State_Local_Bonds.drop('Bank of America-Merrill Lynch', axis=1)
State_Local_Bonds['Bank of America Merrill Lynch'] = State_Local_Bonds['Banc of America-Merrill Lynch'].combine_first(State_Local_Bonds['Banc of America-Merrill Lynch'])
State_Local_Bonds = State_Local_Bonds.drop('Banc of America-Merrill Lynch', axis=1)

State_Local_Bonds['Bank of Toyko-Mitsubishi'] = State_Local_Bonds['Bank of Toyko-Mitsubishi'].combine_first(State_Local_Bonds['Bank of Toyko-Mitsubishi UFJ'])
State_Local_Bonds = State_Local_Bonds.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

State_Local_Bonds['Barclays'] = State_Local_Bonds['Barclays'].combine_first(State_Local_Bonds['Barclays Capital'])
State_Local_Bonds = State_Local_Bonds.drop('Barclays Capital', axis=1)

State_Local_Bonds['Bear Stearns'] = State_Local_Bonds['Bear Stearns'].combine_first(State_Local_Bonds['Bear Stearns & Co.'])
State_Local_Bonds = State_Local_Bonds.drop('Bear Stearns & Co.', axis=1)
State_Local_Bonds['Bear Stearns'] = State_Local_Bonds['Bear Stearns'].combine_first(State_Local_Bonds['Bear Steams & Co.'])
State_Local_Bonds = State_Local_Bonds.drop('Bear Steams & Co.', axis=1)

State_Local_Bonds['Camilli Economics'] = State_Local_Bonds['Camilli Economics'].combine_first(State_Local_Bonds['Camilli Economics LLC'])
State_Local_Bonds = State_Local_Bonds.drop('Camilli Economics LLC', axis=1)
State_Local_Bonds['Camilli Economics'] = State_Local_Bonds['Camilli Economics'].combine_first(State_Local_Bonds['Camilli, Kathleen'])
State_Local_Bonds = State_Local_Bonds.drop('Camilli, Kathleen', axis=1)

State_Local_Bonds['Citibank Global Asset Mgmt'] = State_Local_Bonds['Citibank Global Asset Mgmt'].combine_first(State_Local_Bonds['Citibank Global Asset Mgmt.'])
State_Local_Bonds = State_Local_Bonds.drop('Citibank Global Asset Mgmt.', axis=1)
State_Local_Bonds['Citibank Global Asset Mgmt'] = State_Local_Bonds['Citibank Global Asset Mgmt'].combine_first(State_Local_Bonds['Citigroup Asset Management'])
State_Local_Bonds = State_Local_Bonds.drop('Citigroup Asset Management', axis=1)

State_Local_Bonds['ClearView Economics'] = State_Local_Bonds['ClearView Economics'].combine_first(State_Local_Bonds['ClearView Associates'])
State_Local_Bonds = State_Local_Bonds.drop('ClearView Associates', axis=1)
State_Local_Bonds['ClearView Economics'] = State_Local_Bonds['ClearView Economics'].combine_first(State_Local_Bonds['ClearView  Economics'])
State_Local_Bonds = State_Local_Bonds.drop('ClearView  Economics', axis=1)

State_Local_Bonds['Comerica Bank'] = State_Local_Bonds['Comerica Bank'].combine_first(State_Local_Bonds['Commerica'])
State_Local_Bonds = State_Local_Bonds.drop('Commerica', axis=1)

State_Local_Bonds['Cycledata Corp.'] = State_Local_Bonds['Cycledata Corp.'].combine_first(State_Local_Bonds['Cycledata corp.'])
State_Local_Bonds = State_Local_Bonds.drop('Cycledata corp.', axis=1)

State_Local_Bonds['Daiwa Capital Markets America'] = State_Local_Bonds['Daiwa Capital Markets America'].combine_first(State_Local_Bonds['Daiw a Capital Markets America'])
State_Local_Bonds = State_Local_Bonds.drop('Daiw a Capital Markets America', axis=1)
State_Local_Bonds['Daiwa Capital Markets America'] = State_Local_Bonds['Daiwa Capital Markets America'].combine_first(State_Local_Bonds['Daiwa Securities America'])
State_Local_Bonds = State_Local_Bonds.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Home_Mtg_Rate['Moody\'s Analytics'] = Home_Mtg_Rate['Moody\'s Analytics'].combine_first(Home_Mtg_Rate['Moody\'s Capital Markets'])
Home_Mtg_Rate['Moody\'s Analytics'] = Home_Mtg_Rate['Moody\'s Analytics'].combine_first(Home_Mtg_Rate['Moody\'s Capital Markets Group'])
Home_Mtg_Rate['Moody\'s Analytics'] = Home_Mtg_Rate['Moody\'s Analytics'].combine_first(Home_Mtg_Rate['Moody\'s Econmy.com'])
Home_Mtg_Rate['Moody\'s Analytics'] = Home_Mtg_Rate['Moody\'s Analytics'].combine_first(Home_Mtg_Rate['Moody\'s Economy.com'])
Home_Mtg_Rate['Moody\'s Analytics'] = Home_Mtg_Rate['Moody\'s Analytics'].combine_first(Home_Mtg_Rate['Moody\'s Investors Service'])
Home_Mtg_Rate['Moody\'s Analytics'] = Home_Mtg_Rate['Moody\'s Analytics'].combine_first(Home_Mtg_Rate['Moodys Investors Service'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Moody\'s Capital Markets', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Moody\'s Capital Markets Group', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Moody\'s Econmy.com', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Moody\'s Economy.com', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Moody\'s Investors Service', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Moodys Investors Service', axis=1)

Home_Mtg_Rate['Nat\'l Assn. of Realtors'] = Home_Mtg_Rate['Nat\'l Assn. of Realtors'].combine_first(Home_Mtg_Rate['Nat\'l Assn, of Realtors'])
Home_Mtg_Rate['Nat\'l Assn. of Realtors'] = Home_Mtg_Rate['Nat\'l Assn. of Realtors'].combine_first(Home_Mtg_Rate['Nat\'I Assn, of Realtors'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Nat\'l Assn, of Realtors', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Nat\'I Assn, of Realtors', axis=1)

Home_Mtg_Rate['National City Bank'] = Home_Mtg_Rate['National City Bank'].combine_first(Home_Mtg_Rate['National City Corporation'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('National City Corporation', axis=1)

Home_Mtg_Rate['Nomura Securities Inc.'] = Home_Mtg_Rate['Nomura Securities Inc.'].combine_first(Home_Mtg_Rate['Nomura Securities, Inc.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Nomura Securities, Inc.', axis=1)

Home_Mtg_Rate['October Consensus'] = Home_Mtg_Rate['October Consensus'].combine_first(Home_Mtg_Rate['Octoberber Consensus'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Octoberber Consensus', axis=1)

Home_Mtg_Rate['PNC Bank Corp.'] = Home_Mtg_Rate['PNC Bank Corp.'].combine_first(Home_Mtg_Rate['PNC Financial Services'])
Home_Mtg_Rate['PNC Bank Corp.'] = Home_Mtg_Rate['PNC Bank Corp.'].combine_first(Home_Mtg_Rate['PNC Financial Services Corp.'])
Home_Mtg_Rate['PNC Bank Corp.'] = Home_Mtg_Rate['PNC Bank Corp.'].combine_first(Home_Mtg_Rate['PNC Financial Services Group'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('PNC Financial Services', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('PNC Financial Services Corp.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('PNC Financial Services Group', axis=1)

Home_Mtg_Rate['Prudential Securities'] = Home_Mtg_Rate['Prudential Securities'].combine_first(Home_Mtg_Rate['Prudential Equity Group LLC'])
Home_Mtg_Rate['Prudential Securities'] = Home_Mtg_Rate['Prudential Securities'].combine_first(Home_Mtg_Rate['Prudential Insurance Co.'])
Home_Mtg_Rate['Prudential Securities'] = Home_Mtg_Rate['Prudential Securities'].combine_first(Home_Mtg_Rate['Prudential Financial'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Prudential Financial', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Prudential Insurance Co.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Prudential Equity Group LLC', axis=1)

Home_Mtg_Rate['RBS Greenwich Capital Econ.'] = Home_Mtg_Rate['RBS Greenwich Capital Econ.'].combine_first(Home_Mtg_Rate['RBS Securities'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('RBS Securities', axis=1)

Home_Mtg_Rate['RBC'] = Home_Mtg_Rate['RBC'].combine_first(Home_Mtg_Rate['RBC Capital Markets'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('RBC Capital Markets', axis=1)

Home_Mtg_Rate['RDQ Economics'] = Home_Mtg_Rate['RDQ Economics'].combine_first(Home_Mtg_Rate['RDQ'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('RDQ', axis=1)

Home_Mtg_Rate['RidgeWorth Investments'] = Home_Mtg_Rate['RidgeWorth Investments'].combine_first(Home_Mtg_Rate['RidgeWorth Capital Management'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('RidgeWorth Capital Management', axis=1)

Home_Mtg_Rate['S&P Global'] = Home_Mtg_Rate['S&P Global'].combine_first(Home_Mtg_Rate['S&P Global Market Intelligence'])
Home_Mtg_Rate['S&P Global'] = Home_Mtg_Rate['S&P Global'].combine_first(Home_Mtg_Rate['S&P Global Ratings'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('S&P Global Market Intelligence', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('S&P Global Ratings', axis=1)

Home_Mtg_Rate['Scotiabank Group'] = Home_Mtg_Rate['Scotiabank Group'].combine_first(Home_Mtg_Rate['Scotiabank'])
Home_Mtg_Rate['Scotiabank Group'] = Home_Mtg_Rate['Scotiabank Group'].combine_first(Home_Mtg_Rate['Scotia Capital'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Scotia Capital', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Scotiabank', axis=1)

Home_Mtg_Rate['September Consensus'] = Home_Mtg_Rate['September Consensus'].combine_first(Home_Mtg_Rate['Sept. Consensus'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Sept. Consensus', axis=1)

Home_Mtg_Rate['Standard & Poor\'s'] = Home_Mtg_Rate['Standard & Poor\'s'].combine_first(Home_Mtg_Rate['Standard & Poor\'s Corp.'])
Home_Mtg_Rate['Standard & Poor\'s'] = Home_Mtg_Rate['Standard & Poor\'s'].combine_first(Home_Mtg_Rate['Standard & Poors'])
Home_Mtg_Rate['Standard & Poor\'s'] = Home_Mtg_Rate['Standard & Poor\'s'].combine_first(Home_Mtg_Rate['Standard & Poor’s Corp.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Standard & Poor’s Corp.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Standard & Poor\'s Corp.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Standard & Poors', axis=1)

Home_Mtg_Rate['Swiss Re'] = Home_Mtg_Rate['Swiss Re'].combine_first(Home_Mtg_Rate['Sw iss Re'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Sw iss Re', axis=1)

Home_Mtg_Rate['Thredgold Economics'] = Home_Mtg_Rate['Thredgold Economics'].combine_first(Home_Mtg_Rate['Thredgold Economic Assoc.'])
Home_Mtg_Rate['Thredgold Economics'] = Home_Mtg_Rate['Thredgold Economics'].combine_first(Home_Mtg_Rate['Thredgota Economic Assoc.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Thredgold Economic Assoc.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Thredgota Economic Assoc.', axis=1)

Home_Mtg_Rate['Tokai Bank, Ltd.'] = Home_Mtg_Rate['Tokai Bank, Ltd.'].combine_first(Home_Mtg_Rate['Tokai Bank, Lid.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Tokai Bank, Lid.', axis=1)

Home_Mtg_Rate['Wayne Hummer & Co.'] = Home_Mtg_Rate['Wayne Hummer & Co.'].combine_first(Home_Mtg_Rate['Wayne Hummer Investments'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Wayne Hummer Investments', axis=1)

Home_Mtg_Rate['Wachovia'] = Home_Mtg_Rate['Wachovia'].combine_first(Home_Mtg_Rate['Wachovia Securities'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Wachovia Securities', axis=1)

Home_Mtg_Rate['Wells Fargo'] = Home_Mtg_Rate['Wells Fargo'].combine_first(Home_Mtg_Rate['Wells Capital Management'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Wells Capital Management', axis=1)

Home_Mtg_Rate['Woodworth Holdings'] = Home_Mtg_Rate['Woodworth Holdings'].combine_first(Home_Mtg_Rate['Woodw orth Holdings'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Woodw orth Holdings', axis=1)

Home_Mtg_Rate['independent Economic Advisory'] = Home_Mtg_Rate['independent Economic Advisory'].combine_first(Home_Mtg_Rate['independent Econ. Advisory'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('independent Econ. Advisory', axis=1)

Home_Mtg_Rate['MacroFin Analytics'] = Home_Mtg_Rate['MacroFin Analytics'].combine_first(Home_Mtg_Rate['MacroFin Analytics & RBS'])
Home_Mtg_Rate['MacroFin Analytics'] = Home_Mtg_Rate['MacroFin Analytics'].combine_first(Home_Mtg_Rate['MacroFin Analytics & Rutgers Bus School'])
Home_Mtg_Rate['MacroFin Analytics'] = Home_Mtg_Rate['MacroFin Analytics'].combine_first(Home_Mtg_Rate['MacroFin Analytics/Rutgers Bus School'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('MacroFin Analytics & RBS', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Home_Mtg_Rate['Mesirow Financial'] = Home_Mtg_Rate['Mesirow  Financial'].combine_first(Home_Mtg_Rate['Mesirow  Financial'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Mesirow  Financial', axis=1)

Home_Mtg_Rate['Merrill Lynch'] = Home_Mtg_Rate['Merrill Lynch'].combine_first(Home_Mtg_Rate['Merrill Lynch Economics'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Merrill Lynch Economics', axis=1)

Home_Mtg_Rate['LaSalle Nat\'I Bank'] = Home_Mtg_Rate['LaSalle Nat\'I Bank'].combine_first(Home_Mtg_Rate['LaSalle Nat\'l Bank'])
Home_Mtg_Rate['LaSalle Nat\'I Bank'] = Home_Mtg_Rate['LaSalle Nat\'I Bank'].combine_first(Home_Mtg_Rate['LaSalle Natl Bank'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('LaSalle Nat\'l Bank', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('LaSalle Natl Bank', axis=1)

Home_Mtg_Rate['Kellner Economic Advisers'] = Home_Mtg_Rate['Kellner Economic Advisers'].combine_first(Home_Mtg_Rate['Keller Economic Advisers'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Keller Economic Advisers', axis=1)

Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['J.P. Morgan Chase'])
Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['J.P. Morgan Chase'])
Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['JPMorgan Asset Mgt.'])
Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['JPMorgan Fleming Asset Mgt.'])
Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['JPMorgan Privare Client Services'])
Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['JPMorgan Privare Wealth Mgt.'])
Home_Mtg_Rate['J.P. Morgan'] = Home_Mtg_Rate['J.P. Morgan'].combine_first(Home_Mtg_Rate['JPMorgan Private Banking'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('JPMorgan Private Banking', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('JPMorgan Privare Client Services', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('JPMorgan Asset Mgt.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('J.P. Morgan Chase', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('J.P. MorganChase', axis=1)

Home_Mtg_Rate['Independent Economic Advisory'] = Home_Mtg_Rate['Independent Economic Advisory'].combine_first(Home_Mtg_Rate['Independent Econ. Advisory'])
Home_Mtg_Rate['Independent Economic Advisory'] = Home_Mtg_Rate['Independent Economic Advisory'].combine_first(Home_Mtg_Rate['Investment Economics Advisory'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Independent Econ. Advisory', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Investment Economics Advisory', axis=1)
                                         
Home_Mtg_Rate['ING'] = Home_Mtg_Rate['ING'].combine_first(Home_Mtg_Rate['ING Investment Mgt.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('ING Investment Mgt.', axis=1)

Home_Mtg_Rate['Huntington Nat\'I Bank'] = Home_Mtg_Rate['Huntington Nat\'I Bank'].combine_first(Home_Mtg_Rate['Huntington Nat\'l Bank'])
Home_Mtg_Rate['Huntington Nat\'I Bank'] = Home_Mtg_Rate['Huntington Nat\'I Bank'].combine_first(Home_Mtg_Rate['Huntington Natl Bank'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Huntington Nat\'l Bank', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Huntington Natl Bank', axis=1)

Home_Mtg_Rate['Goldman Sachs'] = Home_Mtg_Rate['Goldman Sachs'].combine_first(Home_Mtg_Rate['Goldman Sachs & Co,'])
Home_Mtg_Rate['Goldman Sachs'] = Home_Mtg_Rate['Goldman Sachs'].combine_first(Home_Mtg_Rate['Goldman Sachs & Co.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Goldman Sachs & Co,', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Goldman Sachs & Co.', axis=1)

Home_Mtg_Rate['Genetski Financial Advisors'] = Home_Mtg_Rate['Genetski Financial Advisors'].combine_first(Home_Mtg_Rate['Genetski.com'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Genetski.com', axis=1)

Home_Mtg_Rate['Fannie Mae'] = Home_Mtg_Rate['Fannie Mae'].combine_first(Home_Mtg_Rate['Fannie Mae '])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Fannie Mae ', axis=1)

Home_Mtg_Rate['Deutsche Bank Securities'] = Home_Mtg_Rate['Deutsche Bank Securities'].combine_first(Home_Mtg_Rate['Deutsche Bank Securities, Inc.'])
Home_Mtg_Rate['Deutsche Bank Securities'] = Home_Mtg_Rate['Deutsche Bank Securities'].combine_first(Home_Mtg_Rate['Deutsche Bank Securities, inc.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Deutsche Bank Securities, Inc.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Deutsche Bank Securities, inc.', axis=1)

Home_Mtg_Rate['DePrince & Associates'] = Home_Mtg_Rate['DePrince & Associates'].combine_first(Home_Mtg_Rate['DePrince & Assoc.'])
Home_Mtg_Rate['DePrince & Associates'] = Home_Mtg_Rate['DePrince & Associates'].combine_first(Home_Mtg_Rate['DePrince Associates'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('DePrince & Assoc.', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('DePrince Associates', axis=1)

Home_Mtg_Rate['Aeltus Investment'] = Home_Mtg_Rate['Aeltus Investment'].combine_first(Home_Mtg_Rate['Aeitus Investment'])
Home_Mtg_Rate['Aeltus Investment'] = Home_Mtg_Rate['Aeltus Investment'].combine_first(Home_Mtg_Rate['Aeltus investment'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Aeitus Investment', axis=1)
Home_Mtg_Rate = Home_Mtg_Rate.drop('Aeltus investment', axis=1)

Home_Mtg_Rate['ASB Capital Management'] = Home_Mtg_Rate['ASB Capital Management'].combine_first(Home_Mtg_Rate['ASB Captial Management'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('ASB Captial Management', axis=1)

Home_Mtg_Rate['BMO Nesbitt Burns'] = Home_Mtg_Rate['BMO Nesbitt Burns'].combine_first(Home_Mtg_Rate['BMC Nesbitt Burns'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('BMC Nesbitt Burns', axis=1)

Home_Mtg_Rate['Banc One Invest. Advisors'] = Home_Mtg_Rate['Banc One Invest. Advisors'].combine_first(Home_Mtg_Rate['Banc One invest. Advisors'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Banc One invest. Advisors', axis=1)

Home_Mtg_Rate['Banc of America Securities'] = Home_Mtg_Rate['Banc of America Securities'].combine_first(Home_Mtg_Rate['Banc of Amercia Securities'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Banc of Amercia Securities', axis=1)

Home_Mtg_Rate['Banc of America Securities'] = Home_Mtg_Rate['Banc of America Securities'].combine_first(Home_Mtg_Rate['Banc of America Securities, LLC'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Banc of America Securities, LLC', axis=1)

Home_Mtg_Rate['Bank of America Merrill Lynch'] = Home_Mtg_Rate['Bank of America Merrill Lynch'].combine_first(Home_Mtg_Rate['Bank of America-Merrill Lynch'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Bank of America-Merrill Lynch', axis=1)
Home_Mtg_Rate['Bank of America Merrill Lynch'] = Home_Mtg_Rate['Banc of America-Merrill Lynch'].combine_first(Home_Mtg_Rate['Banc of America-Merrill Lynch'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Banc of America-Merrill Lynch', axis=1)

Home_Mtg_Rate['Bank of Toyko-Mitsubishi'] = Home_Mtg_Rate['Bank of Toyko-Mitsubishi'].combine_first(Home_Mtg_Rate['Bank of Toyko-Mitsubishi UFJ'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Home_Mtg_Rate['Barclays'] = Home_Mtg_Rate['Barclays'].combine_first(Home_Mtg_Rate['Barclays Capital'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Barclays Capital', axis=1)

Home_Mtg_Rate['Bear Stearns'] = Home_Mtg_Rate['Bear Stearns'].combine_first(Home_Mtg_Rate['Bear Stearns & Co.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Bear Stearns & Co.', axis=1)
Home_Mtg_Rate['Bear Stearns'] = Home_Mtg_Rate['Bear Stearns'].combine_first(Home_Mtg_Rate['Bear Steams & Co.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Bear Steams & Co.', axis=1)

Home_Mtg_Rate['Camilli Economics'] = Home_Mtg_Rate['Camilli Economics'].combine_first(Home_Mtg_Rate['Camilli Economics LLC'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Camilli Economics LLC', axis=1)
Home_Mtg_Rate['Camilli Economics'] = Home_Mtg_Rate['Camilli Economics'].combine_first(Home_Mtg_Rate['Camilli, Kathleen'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Camilli, Kathleen', axis=1)

Home_Mtg_Rate['Citibank Global Asset Mgmt'] = Home_Mtg_Rate['Citibank Global Asset Mgmt'].combine_first(Home_Mtg_Rate['Citibank Global Asset Mgmt.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Citibank Global Asset Mgmt.', axis=1)
Home_Mtg_Rate['Citibank Global Asset Mgmt'] = Home_Mtg_Rate['Citibank Global Asset Mgmt'].combine_first(Home_Mtg_Rate['Citigroup Asset Management'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Citigroup Asset Management', axis=1)

Home_Mtg_Rate['ClearView Economics'] = Home_Mtg_Rate['ClearView Economics'].combine_first(Home_Mtg_Rate['ClearView Associates'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('ClearView Associates', axis=1)
Home_Mtg_Rate['ClearView Economics'] = Home_Mtg_Rate['ClearView Economics'].combine_first(Home_Mtg_Rate['ClearView  Economics'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('ClearView  Economics', axis=1)

Home_Mtg_Rate['Comerica Bank'] = Home_Mtg_Rate['Comerica Bank'].combine_first(Home_Mtg_Rate['Commerica'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Commerica', axis=1)

Home_Mtg_Rate['Cycledata Corp.'] = Home_Mtg_Rate['Cycledata Corp.'].combine_first(Home_Mtg_Rate['Cycledata corp.'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Cycledata corp.', axis=1)

Home_Mtg_Rate['Daiwa Capital Markets America'] = Home_Mtg_Rate['Daiwa Capital Markets America'].combine_first(Home_Mtg_Rate['Daiw a Capital Markets America'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Daiw a Capital Markets America', axis=1)
Home_Mtg_Rate['Daiwa Capital Markets America'] = Home_Mtg_Rate['Daiwa Capital Markets America'].combine_first(Home_Mtg_Rate['Daiwa Securities America'])
Home_Mtg_Rate = Home_Mtg_Rate.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Feds_Major_Currency_Index['Moody\'s Analytics'] = Feds_Major_Currency_Index['Moody\'s Analytics'].combine_first(Feds_Major_Currency_Index['Moody\'s Capital Markets'])
Feds_Major_Currency_Index['Moody\'s Analytics'] = Feds_Major_Currency_Index['Moody\'s Analytics'].combine_first(Feds_Major_Currency_Index['Moody\'s Capital Markets Group'])
Feds_Major_Currency_Index['Moody\'s Analytics'] = Feds_Major_Currency_Index['Moody\'s Analytics'].combine_first(Feds_Major_Currency_Index['Moody\'s Econmy.com'])
Feds_Major_Currency_Index['Moody\'s Analytics'] = Feds_Major_Currency_Index['Moody\'s Analytics'].combine_first(Feds_Major_Currency_Index['Moody\'s Economy.com'])
Feds_Major_Currency_Index['Moody\'s Analytics'] = Feds_Major_Currency_Index['Moody\'s Analytics'].combine_first(Feds_Major_Currency_Index['Moody\'s Investors Service'])
Feds_Major_Currency_Index['Moody\'s Analytics'] = Feds_Major_Currency_Index['Moody\'s Analytics'].combine_first(Feds_Major_Currency_Index['Moodys Investors Service'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Moody\'s Capital Markets', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Moody\'s Capital Markets Group', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Moody\'s Econmy.com', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Moody\'s Economy.com', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Moody\'s Investors Service', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Moodys Investors Service', axis=1)

Feds_Major_Currency_Index['Nat\'l Assn. of Realtors'] = Feds_Major_Currency_Index['Nat\'l Assn. of Realtors'].combine_first(Feds_Major_Currency_Index['Nat\'l Assn, of Realtors'])
Feds_Major_Currency_Index['Nat\'l Assn. of Realtors'] = Feds_Major_Currency_Index['Nat\'l Assn. of Realtors'].combine_first(Feds_Major_Currency_Index['Nat\'I Assn, of Realtors'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Nat\'l Assn, of Realtors', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Nat\'I Assn, of Realtors', axis=1)

Feds_Major_Currency_Index['National City Bank'] = Feds_Major_Currency_Index['National City Bank'].combine_first(Feds_Major_Currency_Index['National City Corporation'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('National City Corporation', axis=1)

Feds_Major_Currency_Index['Nomura Securities Inc.'] = Feds_Major_Currency_Index['Nomura Securities Inc.'].combine_first(Feds_Major_Currency_Index['Nomura Securities, Inc.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Nomura Securities, Inc.', axis=1)

Feds_Major_Currency_Index['October Consensus'] = Feds_Major_Currency_Index['October Consensus'].combine_first(Feds_Major_Currency_Index['Octoberber Consensus'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Octoberber Consensus', axis=1)

Feds_Major_Currency_Index['PNC Bank Corp.'] = Feds_Major_Currency_Index['PNC Bank Corp.'].combine_first(Feds_Major_Currency_Index['PNC Financial Services'])
Feds_Major_Currency_Index['PNC Bank Corp.'] = Feds_Major_Currency_Index['PNC Bank Corp.'].combine_first(Feds_Major_Currency_Index['PNC Financial Services Corp.'])
Feds_Major_Currency_Index['PNC Bank Corp.'] = Feds_Major_Currency_Index['PNC Bank Corp.'].combine_first(Feds_Major_Currency_Index['PNC Financial Services Group'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('PNC Financial Services', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('PNC Financial Services Corp.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('PNC Financial Services Group', axis=1)

Feds_Major_Currency_Index['Prudential Securities'] = Feds_Major_Currency_Index['Prudential Securities'].combine_first(Feds_Major_Currency_Index['Prudential Equity Group LLC'])
Feds_Major_Currency_Index['Prudential Securities'] = Feds_Major_Currency_Index['Prudential Securities'].combine_first(Feds_Major_Currency_Index['Prudential Insurance Co.'])
Feds_Major_Currency_Index['Prudential Securities'] = Feds_Major_Currency_Index['Prudential Securities'].combine_first(Feds_Major_Currency_Index['Prudential Financial'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Prudential Financial', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Prudential Insurance Co.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Prudential Equity Group LLC', axis=1)

Feds_Major_Currency_Index['RBS Greenwich Capital Econ.'] = Feds_Major_Currency_Index['RBS Greenwich Capital Econ.'].combine_first(Feds_Major_Currency_Index['RBS Securities'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('RBS Securities', axis=1)

Feds_Major_Currency_Index['RBC'] = Feds_Major_Currency_Index['RBC'].combine_first(Feds_Major_Currency_Index['RBC Capital Markets'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('RBC Capital Markets', axis=1)

Feds_Major_Currency_Index['RDQ Economics'] = Feds_Major_Currency_Index['RDQ Economics'].combine_first(Feds_Major_Currency_Index['RDQ'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('RDQ', axis=1)

Feds_Major_Currency_Index['RidgeWorth Investments'] = Feds_Major_Currency_Index['RidgeWorth Investments'].combine_first(Feds_Major_Currency_Index['RidgeWorth Capital Management'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('RidgeWorth Capital Management', axis=1)

Feds_Major_Currency_Index['S&P Global'] = Feds_Major_Currency_Index['S&P Global'].combine_first(Feds_Major_Currency_Index['S&P Global Market Intelligence'])
Feds_Major_Currency_Index['S&P Global'] = Feds_Major_Currency_Index['S&P Global'].combine_first(Feds_Major_Currency_Index['S&P Global Ratings'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('S&P Global Market Intelligence', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('S&P Global Ratings', axis=1)

Feds_Major_Currency_Index['Scotiabank Group'] = Feds_Major_Currency_Index['Scotiabank Group'].combine_first(Feds_Major_Currency_Index['Scotiabank'])
Feds_Major_Currency_Index['Scotiabank Group'] = Feds_Major_Currency_Index['Scotiabank Group'].combine_first(Feds_Major_Currency_Index['Scotia Capital'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Scotia Capital', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Scotiabank', axis=1)

Feds_Major_Currency_Index['September Consensus'] = Feds_Major_Currency_Index['September Consensus'].combine_first(Feds_Major_Currency_Index['Sept. Consensus'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Sept. Consensus', axis=1)

Feds_Major_Currency_Index['Standard & Poor\'s'] = Feds_Major_Currency_Index['Standard & Poor\'s'].combine_first(Feds_Major_Currency_Index['Standard & Poor\'s Corp.'])
Feds_Major_Currency_Index['Standard & Poor\'s'] = Feds_Major_Currency_Index['Standard & Poor\'s'].combine_first(Feds_Major_Currency_Index['Standard & Poors'])
Feds_Major_Currency_Index['Standard & Poor\'s'] = Feds_Major_Currency_Index['Standard & Poor\'s'].combine_first(Feds_Major_Currency_Index['Standard & Poor’s Corp.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Standard & Poor’s Corp.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Standard & Poor\'s Corp.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Standard & Poors', axis=1)

Feds_Major_Currency_Index['Swiss Re'] = Feds_Major_Currency_Index['Swiss Re'].combine_first(Feds_Major_Currency_Index['Sw iss Re'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Sw iss Re', axis=1)

Feds_Major_Currency_Index['Thredgold Economics'] = Feds_Major_Currency_Index['Thredgold Economics'].combine_first(Feds_Major_Currency_Index['Thredgold Economic Assoc.'])
Feds_Major_Currency_Index['Thredgold Economics'] = Feds_Major_Currency_Index['Thredgold Economics'].combine_first(Feds_Major_Currency_Index['Thredgota Economic Assoc.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Thredgold Economic Assoc.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Thredgota Economic Assoc.', axis=1)

Feds_Major_Currency_Index['Tokai Bank, Ltd.'] = Feds_Major_Currency_Index['Tokai Bank, Ltd.'].combine_first(Feds_Major_Currency_Index['Tokai Bank, Lid.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Tokai Bank, Lid.', axis=1)

Feds_Major_Currency_Index['Wayne Hummer & Co.'] = Feds_Major_Currency_Index['Wayne Hummer & Co.'].combine_first(Feds_Major_Currency_Index['Wayne Hummer Investments'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Wayne Hummer Investments', axis=1)

Feds_Major_Currency_Index['Wachovia'] = Feds_Major_Currency_Index['Wachovia'].combine_first(Feds_Major_Currency_Index['Wachovia Securities'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Wachovia Securities', axis=1)

Feds_Major_Currency_Index['Wells Fargo'] = Feds_Major_Currency_Index['Wells Fargo'].combine_first(Feds_Major_Currency_Index['Wells Capital Management'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Wells Capital Management', axis=1)

Feds_Major_Currency_Index['Woodworth Holdings'] = Feds_Major_Currency_Index['Woodworth Holdings'].combine_first(Feds_Major_Currency_Index['Woodw orth Holdings'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Woodw orth Holdings', axis=1)

Feds_Major_Currency_Index['independent Economic Advisory'] = Feds_Major_Currency_Index['independent Economic Advisory'].combine_first(Feds_Major_Currency_Index['independent Econ. Advisory'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('independent Econ. Advisory', axis=1)

Feds_Major_Currency_Index['MacroFin Analytics'] = Feds_Major_Currency_Index['MacroFin Analytics'].combine_first(Feds_Major_Currency_Index['MacroFin Analytics & RBS'])
Feds_Major_Currency_Index['MacroFin Analytics'] = Feds_Major_Currency_Index['MacroFin Analytics'].combine_first(Feds_Major_Currency_Index['MacroFin Analytics & Rutgers Bus School'])
Feds_Major_Currency_Index['MacroFin Analytics'] = Feds_Major_Currency_Index['MacroFin Analytics'].combine_first(Feds_Major_Currency_Index['MacroFin Analytics/Rutgers Bus School'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('MacroFin Analytics & RBS', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Feds_Major_Currency_Index['Mesirow Financial'] = Feds_Major_Currency_Index['Mesirow  Financial'].combine_first(Feds_Major_Currency_Index['Mesirow  Financial'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Mesirow  Financial', axis=1)

Feds_Major_Currency_Index['Merrill Lynch'] = Feds_Major_Currency_Index['Merrill Lynch'].combine_first(Feds_Major_Currency_Index['Merrill Lynch Economics'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Merrill Lynch Economics', axis=1)

Feds_Major_Currency_Index['LaSalle Nat\'I Bank'] = Feds_Major_Currency_Index['LaSalle Nat\'I Bank'].combine_first(Feds_Major_Currency_Index['LaSalle Nat\'l Bank'])
Feds_Major_Currency_Index['LaSalle Nat\'I Bank'] = Feds_Major_Currency_Index['LaSalle Nat\'I Bank'].combine_first(Feds_Major_Currency_Index['LaSalle Natl Bank'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('LaSalle Nat\'l Bank', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('LaSalle Natl Bank', axis=1)

Feds_Major_Currency_Index['Kellner Economic Advisers'] = Feds_Major_Currency_Index['Kellner Economic Advisers'].combine_first(Feds_Major_Currency_Index['Keller Economic Advisers'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Keller Economic Advisers', axis=1)

Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['J.P. Morgan Chase'])
Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['J.P. Morgan Chase'])
Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['JPMorgan Asset Mgt.'])
Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['JPMorgan Fleming Asset Mgt.'])
Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['JPMorgan Privare Client Services'])
Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['JPMorgan Privare Wealth Mgt.'])
Feds_Major_Currency_Index['J.P. Morgan'] = Feds_Major_Currency_Index['J.P. Morgan'].combine_first(Feds_Major_Currency_Index['JPMorgan Private Banking'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('JPMorgan Private Banking', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('JPMorgan Privare Client Services', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('JPMorgan Asset Mgt.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('J.P. Morgan Chase', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('J.P. MorganChase', axis=1)

Feds_Major_Currency_Index['Independent Economic Advisory'] = Feds_Major_Currency_Index['Independent Economic Advisory'].combine_first(Feds_Major_Currency_Index['Independent Econ. Advisory'])
Feds_Major_Currency_Index['Independent Economic Advisory'] = Feds_Major_Currency_Index['Independent Economic Advisory'].combine_first(Feds_Major_Currency_Index['Investment Economics Advisory'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Independent Econ. Advisory', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Investment Economics Advisory', axis=1)
                                         
Feds_Major_Currency_Index['ING'] = Feds_Major_Currency_Index['ING'].combine_first(Feds_Major_Currency_Index['ING Investment Mgt.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('ING Investment Mgt.', axis=1)

Feds_Major_Currency_Index['Huntington Nat\'I Bank'] = Feds_Major_Currency_Index['Huntington Nat\'I Bank'].combine_first(Feds_Major_Currency_Index['Huntington Nat\'l Bank'])
Feds_Major_Currency_Index['Huntington Nat\'I Bank'] = Feds_Major_Currency_Index['Huntington Nat\'I Bank'].combine_first(Feds_Major_Currency_Index['Huntington Natl Bank'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Huntington Nat\'l Bank', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Huntington Natl Bank', axis=1)

Feds_Major_Currency_Index['Goldman Sachs'] = Feds_Major_Currency_Index['Goldman Sachs'].combine_first(Feds_Major_Currency_Index['Goldman Sachs & Co,'])
Feds_Major_Currency_Index['Goldman Sachs'] = Feds_Major_Currency_Index['Goldman Sachs'].combine_first(Feds_Major_Currency_Index['Goldman Sachs & Co.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Goldman Sachs & Co,', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Goldman Sachs & Co.', axis=1)

Feds_Major_Currency_Index['Genetski Financial Advisors'] = Feds_Major_Currency_Index['Genetski Financial Advisors'].combine_first(Feds_Major_Currency_Index['Genetski.com'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Genetski.com', axis=1)

Feds_Major_Currency_Index['Fannie Mae'] = Feds_Major_Currency_Index['Fannie Mae'].combine_first(Feds_Major_Currency_Index['Fannie Mae '])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Fannie Mae ', axis=1)

Feds_Major_Currency_Index['Deutsche Bank Securities'] = Feds_Major_Currency_Index['Deutsche Bank Securities'].combine_first(Feds_Major_Currency_Index['Deutsche Bank Securities, Inc.'])
Feds_Major_Currency_Index['Deutsche Bank Securities'] = Feds_Major_Currency_Index['Deutsche Bank Securities'].combine_first(Feds_Major_Currency_Index['Deutsche Bank Securities, inc.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Deutsche Bank Securities, Inc.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Deutsche Bank Securities, inc.', axis=1)

Feds_Major_Currency_Index['DePrince & Associates'] = Feds_Major_Currency_Index['DePrince & Associates'].combine_first(Feds_Major_Currency_Index['DePrince & Assoc.'])
Feds_Major_Currency_Index['DePrince & Associates'] = Feds_Major_Currency_Index['DePrince & Associates'].combine_first(Feds_Major_Currency_Index['DePrince Associates'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('DePrince & Assoc.', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('DePrince Associates', axis=1)

Feds_Major_Currency_Index['Aeltus Investment'] = Feds_Major_Currency_Index['Aeltus Investment'].combine_first(Feds_Major_Currency_Index['Aeitus Investment'])
Feds_Major_Currency_Index['Aeltus Investment'] = Feds_Major_Currency_Index['Aeltus Investment'].combine_first(Feds_Major_Currency_Index['Aeltus investment'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Aeitus Investment', axis=1)
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Aeltus investment', axis=1)

Feds_Major_Currency_Index['ASB Capital Management'] = Feds_Major_Currency_Index['ASB Capital Management'].combine_first(Feds_Major_Currency_Index['ASB Captial Management'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('ASB Captial Management', axis=1)

Feds_Major_Currency_Index['BMO Nesbitt Burns'] = Feds_Major_Currency_Index['BMO Nesbitt Burns'].combine_first(Feds_Major_Currency_Index['BMC Nesbitt Burns'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('BMC Nesbitt Burns', axis=1)

Feds_Major_Currency_Index['Banc One Invest. Advisors'] = Feds_Major_Currency_Index['Banc One Invest. Advisors'].combine_first(Feds_Major_Currency_Index['Banc One invest. Advisors'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Banc One invest. Advisors', axis=1)

Feds_Major_Currency_Index['Banc of America Securities'] = Feds_Major_Currency_Index['Banc of America Securities'].combine_first(Feds_Major_Currency_Index['Banc of Amercia Securities'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Banc of Amercia Securities', axis=1)

Feds_Major_Currency_Index['Banc of America Securities'] = Feds_Major_Currency_Index['Banc of America Securities'].combine_first(Feds_Major_Currency_Index['Banc of America Securities, LLC'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Banc of America Securities, LLC', axis=1)

Feds_Major_Currency_Index['Bank of America Merrill Lynch'] = Feds_Major_Currency_Index['Bank of America Merrill Lynch'].combine_first(Feds_Major_Currency_Index['Bank of America-Merrill Lynch'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Bank of America-Merrill Lynch', axis=1)
Feds_Major_Currency_Index['Bank of America Merrill Lynch'] = Feds_Major_Currency_Index['Banc of America-Merrill Lynch'].combine_first(Feds_Major_Currency_Index['Banc of America-Merrill Lynch'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Banc of America-Merrill Lynch', axis=1)

Feds_Major_Currency_Index['Bank of Toyko-Mitsubishi'] = Feds_Major_Currency_Index['Bank of Toyko-Mitsubishi'].combine_first(Feds_Major_Currency_Index['Bank of Toyko-Mitsubishi UFJ'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Feds_Major_Currency_Index['Barclays'] = Feds_Major_Currency_Index['Barclays'].combine_first(Feds_Major_Currency_Index['Barclays Capital'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Barclays Capital', axis=1)

Feds_Major_Currency_Index['Bear Stearns'] = Feds_Major_Currency_Index['Bear Stearns'].combine_first(Feds_Major_Currency_Index['Bear Stearns & Co.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Bear Stearns & Co.', axis=1)
Feds_Major_Currency_Index['Bear Stearns'] = Feds_Major_Currency_Index['Bear Stearns'].combine_first(Feds_Major_Currency_Index['Bear Steams & Co.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Bear Steams & Co.', axis=1)

Feds_Major_Currency_Index['Camilli Economics'] = Feds_Major_Currency_Index['Camilli Economics'].combine_first(Feds_Major_Currency_Index['Camilli Economics LLC'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Camilli Economics LLC', axis=1)
Feds_Major_Currency_Index['Camilli Economics'] = Feds_Major_Currency_Index['Camilli Economics'].combine_first(Feds_Major_Currency_Index['Camilli, Kathleen'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Camilli, Kathleen', axis=1)

Feds_Major_Currency_Index['Citibank Global Asset Mgmt'] = Feds_Major_Currency_Index['Citibank Global Asset Mgmt'].combine_first(Feds_Major_Currency_Index['Citibank Global Asset Mgmt.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Citibank Global Asset Mgmt.', axis=1)
Feds_Major_Currency_Index['Citibank Global Asset Mgmt'] = Feds_Major_Currency_Index['Citibank Global Asset Mgmt'].combine_first(Feds_Major_Currency_Index['Citigroup Asset Management'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Citigroup Asset Management', axis=1)

Feds_Major_Currency_Index['ClearView Economics'] = Feds_Major_Currency_Index['ClearView Economics'].combine_first(Feds_Major_Currency_Index['ClearView Associates'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('ClearView Associates', axis=1)
Feds_Major_Currency_Index['ClearView Economics'] = Feds_Major_Currency_Index['ClearView Economics'].combine_first(Feds_Major_Currency_Index['ClearView  Economics'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('ClearView  Economics', axis=1)

Feds_Major_Currency_Index['Comerica Bank'] = Feds_Major_Currency_Index['Comerica Bank'].combine_first(Feds_Major_Currency_Index['Commerica'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Commerica', axis=1)

Feds_Major_Currency_Index['Cycledata Corp.'] = Feds_Major_Currency_Index['Cycledata Corp.'].combine_first(Feds_Major_Currency_Index['Cycledata corp.'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Cycledata corp.', axis=1)

Feds_Major_Currency_Index['Daiwa Capital Markets America'] = Feds_Major_Currency_Index['Daiwa Capital Markets America'].combine_first(Feds_Major_Currency_Index['Daiw a Capital Markets America'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Daiw a Capital Markets America', axis=1)
Feds_Major_Currency_Index['Daiwa Capital Markets America'] = Feds_Major_Currency_Index['Daiwa Capital Markets America'].combine_first(Feds_Major_Currency_Index['Daiwa Securities America'])
Feds_Major_Currency_Index = Feds_Major_Currency_Index.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Real_GDP['Moody\'s Analytics'] = Real_GDP['Moody\'s Analytics'].combine_first(Real_GDP['Moody\'s Capital Markets'])
Real_GDP['Moody\'s Analytics'] = Real_GDP['Moody\'s Analytics'].combine_first(Real_GDP['Moody\'s Capital Markets Group'])
Real_GDP['Moody\'s Analytics'] = Real_GDP['Moody\'s Analytics'].combine_first(Real_GDP['Moody\'s Econmy.com'])
Real_GDP['Moody\'s Analytics'] = Real_GDP['Moody\'s Analytics'].combine_first(Real_GDP['Moody\'s Economy.com'])
Real_GDP['Moody\'s Analytics'] = Real_GDP['Moody\'s Analytics'].combine_first(Real_GDP['Moody\'s Investors Service'])
Real_GDP['Moody\'s Analytics'] = Real_GDP['Moody\'s Analytics'].combine_first(Real_GDP['Moodys Investors Service'])
Real_GDP = Real_GDP.drop('Moody\'s Capital Markets', axis=1)
Real_GDP = Real_GDP.drop('Moody\'s Capital Markets Group', axis=1)
Real_GDP = Real_GDP.drop('Moody\'s Econmy.com', axis=1)
Real_GDP = Real_GDP.drop('Moody\'s Economy.com', axis=1)
Real_GDP = Real_GDP.drop('Moody\'s Investors Service', axis=1)
Real_GDP = Real_GDP.drop('Moodys Investors Service', axis=1)

Real_GDP['Nat\'l Assn. of Realtors'] = Real_GDP['Nat\'l Assn. of Realtors'].combine_first(Real_GDP['Nat\'l Assn, of Realtors'])
Real_GDP['Nat\'l Assn. of Realtors'] = Real_GDP['Nat\'l Assn. of Realtors'].combine_first(Real_GDP['Nat\'I Assn, of Realtors'])
Real_GDP = Real_GDP.drop('Nat\'l Assn, of Realtors', axis=1)
Real_GDP = Real_GDP.drop('Nat\'I Assn, of Realtors', axis=1)

Real_GDP['National City Bank'] = Real_GDP['National City Bank'].combine_first(Real_GDP['National City Corporation'])
Real_GDP = Real_GDP.drop('National City Corporation', axis=1)

Real_GDP['Nomura Securities Inc.'] = Real_GDP['Nomura Securities Inc.'].combine_first(Real_GDP['Nomura Securities, Inc.'])
Real_GDP = Real_GDP.drop('Nomura Securities, Inc.', axis=1)

Real_GDP['October Consensus'] = Real_GDP['October Consensus'].combine_first(Real_GDP['Octoberber Consensus'])
Real_GDP = Real_GDP.drop('Octoberber Consensus', axis=1)

Real_GDP['PNC Bank Corp.'] = Real_GDP['PNC Bank Corp.'].combine_first(Real_GDP['PNC Financial Services'])
Real_GDP['PNC Bank Corp.'] = Real_GDP['PNC Bank Corp.'].combine_first(Real_GDP['PNC Financial Services Corp.'])
Real_GDP['PNC Bank Corp.'] = Real_GDP['PNC Bank Corp.'].combine_first(Real_GDP['PNC Financial Services Group'])
Real_GDP = Real_GDP.drop('PNC Financial Services', axis=1)
Real_GDP = Real_GDP.drop('PNC Financial Services Corp.', axis=1)
Real_GDP = Real_GDP.drop('PNC Financial Services Group', axis=1)

Real_GDP['Prudential Securities'] = Real_GDP['Prudential Securities'].combine_first(Real_GDP['Prudential Equity Group LLC'])
Real_GDP['Prudential Securities'] = Real_GDP['Prudential Securities'].combine_first(Real_GDP['Prudential Insurance Co.'])
Real_GDP['Prudential Securities'] = Real_GDP['Prudential Securities'].combine_first(Real_GDP['Prudential Financial'])
Real_GDP = Real_GDP.drop('Prudential Financial', axis=1)
Real_GDP = Real_GDP.drop('Prudential Insurance Co.', axis=1)
Real_GDP = Real_GDP.drop('Prudential Equity Group LLC', axis=1)

Real_GDP['RBS Greenwich Capital Econ.'] = Real_GDP['RBS Greenwich Capital Econ.'].combine_first(Real_GDP['RBS Securities'])
Real_GDP = Real_GDP.drop('RBS Securities', axis=1)

Real_GDP['RBC'] = Real_GDP['RBC'].combine_first(Real_GDP['RBC Capital Markets'])
Real_GDP = Real_GDP.drop('RBC Capital Markets', axis=1)

Real_GDP['RDQ Economics'] = Real_GDP['RDQ Economics'].combine_first(Real_GDP['RDQ'])
Real_GDP = Real_GDP.drop('RDQ', axis=1)

Real_GDP['RidgeWorth Investments'] = Real_GDP['RidgeWorth Investments'].combine_first(Real_GDP['RidgeWorth Capital Management'])
Real_GDP = Real_GDP.drop('RidgeWorth Capital Management', axis=1)

Real_GDP['S&P Global'] = Real_GDP['S&P Global'].combine_first(Real_GDP['S&P Global Market Intelligence'])
Real_GDP['S&P Global'] = Real_GDP['S&P Global'].combine_first(Real_GDP['S&P Global Ratings'])
Real_GDP = Real_GDP.drop('S&P Global Market Intelligence', axis=1)
Real_GDP = Real_GDP.drop('S&P Global Ratings', axis=1)

Real_GDP['Scotiabank Group'] = Real_GDP['Scotiabank Group'].combine_first(Real_GDP['Scotiabank'])
Real_GDP['Scotiabank Group'] = Real_GDP['Scotiabank Group'].combine_first(Real_GDP['Scotia Capital'])
Real_GDP = Real_GDP.drop('Scotia Capital', axis=1)
Real_GDP = Real_GDP.drop('Scotiabank', axis=1)

Real_GDP['September Consensus'] = Real_GDP['September Consensus'].combine_first(Real_GDP['Sept. Consensus'])
Real_GDP = Real_GDP.drop('Sept. Consensus', axis=1)

Real_GDP['Standard & Poor\'s'] = Real_GDP['Standard & Poor\'s'].combine_first(Real_GDP['Standard & Poor\'s Corp.'])
Real_GDP['Standard & Poor\'s'] = Real_GDP['Standard & Poor\'s'].combine_first(Real_GDP['Standard & Poors'])
Real_GDP['Standard & Poor\'s'] = Real_GDP['Standard & Poor\'s'].combine_first(Real_GDP['Standard & Poor’s Corp.'])
Real_GDP = Real_GDP.drop('Standard & Poor’s Corp.', axis=1)
Real_GDP = Real_GDP.drop('Standard & Poor\'s Corp.', axis=1)
Real_GDP = Real_GDP.drop('Standard & Poors', axis=1)

Real_GDP['Swiss Re'] = Real_GDP['Swiss Re'].combine_first(Real_GDP['Sw iss Re'])
Real_GDP = Real_GDP.drop('Sw iss Re', axis=1)

Real_GDP['Thredgold Economics'] = Real_GDP['Thredgold Economics'].combine_first(Real_GDP['Thredgold Economic Assoc.'])
Real_GDP['Thredgold Economics'] = Real_GDP['Thredgold Economics'].combine_first(Real_GDP['Thredgota Economic Assoc.'])
Real_GDP = Real_GDP.drop('Thredgold Economic Assoc.', axis=1)
Real_GDP = Real_GDP.drop('Thredgota Economic Assoc.', axis=1)

Real_GDP['Tokai Bank, Ltd.'] = Real_GDP['Tokai Bank, Ltd.'].combine_first(Real_GDP['Tokai Bank, Lid.'])
Real_GDP = Real_GDP.drop('Tokai Bank, Lid.', axis=1)

Real_GDP['Wayne Hummer & Co.'] = Real_GDP['Wayne Hummer & Co.'].combine_first(Real_GDP['Wayne Hummer Investments'])
Real_GDP = Real_GDP.drop('Wayne Hummer Investments', axis=1)

Real_GDP['Wachovia'] = Real_GDP['Wachovia'].combine_first(Real_GDP['Wachovia Securities'])
Real_GDP = Real_GDP.drop('Wachovia Securities', axis=1)

Real_GDP['Wells Fargo'] = Real_GDP['Wells Fargo'].combine_first(Real_GDP['Wells Capital Management'])
Real_GDP = Real_GDP.drop('Wells Capital Management', axis=1)

Real_GDP['Woodworth Holdings'] = Real_GDP['Woodworth Holdings'].combine_first(Real_GDP['Woodw orth Holdings'])
Real_GDP = Real_GDP.drop('Woodw orth Holdings', axis=1)

Real_GDP['independent Economic Advisory'] = Real_GDP['independent Economic Advisory'].combine_first(Real_GDP['independent Econ. Advisory'])
Real_GDP = Real_GDP.drop('independent Econ. Advisory', axis=1)

Real_GDP['MacroFin Analytics'] = Real_GDP['MacroFin Analytics'].combine_first(Real_GDP['MacroFin Analytics & RBS'])
Real_GDP['MacroFin Analytics'] = Real_GDP['MacroFin Analytics'].combine_first(Real_GDP['MacroFin Analytics & Rutgers Bus School'])
Real_GDP['MacroFin Analytics'] = Real_GDP['MacroFin Analytics'].combine_first(Real_GDP['MacroFin Analytics/Rutgers Bus School'])
Real_GDP = Real_GDP.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Real_GDP = Real_GDP.drop('MacroFin Analytics & RBS', axis=1)
Real_GDP = Real_GDP.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Real_GDP['Mesirow Financial'] = Real_GDP['Mesirow  Financial'].combine_first(Real_GDP['Mesirow  Financial'])
Real_GDP = Real_GDP.drop('Mesirow  Financial', axis=1)

Real_GDP['Merrill Lynch'] = Real_GDP['Merrill Lynch'].combine_first(Real_GDP['Merrill Lynch Economics'])
Real_GDP = Real_GDP.drop('Merrill Lynch Economics', axis=1)

Real_GDP['LaSalle Nat\'I Bank'] = Real_GDP['LaSalle Nat\'I Bank'].combine_first(Real_GDP['LaSalle Nat\'l Bank'])
Real_GDP['LaSalle Nat\'I Bank'] = Real_GDP['LaSalle Nat\'I Bank'].combine_first(Real_GDP['LaSalle Natl Bank'])
Real_GDP = Real_GDP.drop('LaSalle Nat\'l Bank', axis=1)
Real_GDP = Real_GDP.drop('LaSalle Natl Bank', axis=1)

Real_GDP['Kellner Economic Advisers'] = Real_GDP['Kellner Economic Advisers'].combine_first(Real_GDP['Keller Economic Advisers'])
Real_GDP = Real_GDP.drop('Keller Economic Advisers', axis=1)

Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['J.P. Morgan Chase'])
Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['J.P. Morgan Chase'])
Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['JPMorgan Asset Mgt.'])
Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['JPMorgan Fleming Asset Mgt.'])
Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['JPMorgan Privare Client Services'])
Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['JPMorgan Privare Wealth Mgt.'])
Real_GDP['J.P. Morgan'] = Real_GDP['J.P. Morgan'].combine_first(Real_GDP['JPMorgan Private Banking'])
Real_GDP = Real_GDP.drop('JPMorgan Private Banking', axis=1)
Real_GDP = Real_GDP.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Real_GDP = Real_GDP.drop('JPMorgan Privare Client Services', axis=1)
Real_GDP = Real_GDP.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Real_GDP = Real_GDP.drop('JPMorgan Asset Mgt.', axis=1)
Real_GDP = Real_GDP.drop('J.P. Morgan Chase', axis=1)
Real_GDP = Real_GDP.drop('J.P. MorganChase', axis=1)

Real_GDP['Independent Economic Advisory'] = Real_GDP['Independent Economic Advisory'].combine_first(Real_GDP['Independent Econ. Advisory'])
Real_GDP['Independent Economic Advisory'] = Real_GDP['Independent Economic Advisory'].combine_first(Real_GDP['Investment Economics Advisory'])
Real_GDP = Real_GDP.drop('Independent Econ. Advisory', axis=1)
Real_GDP = Real_GDP.drop('Investment Economics Advisory', axis=1)
                                         
Real_GDP['ING'] = Real_GDP['ING'].combine_first(Real_GDP['ING Investment Mgt.'])
Real_GDP = Real_GDP.drop('ING Investment Mgt.', axis=1)

Real_GDP['Huntington Nat\'I Bank'] = Real_GDP['Huntington Nat\'I Bank'].combine_first(Real_GDP['Huntington Nat\'l Bank'])
Real_GDP['Huntington Nat\'I Bank'] = Real_GDP['Huntington Nat\'I Bank'].combine_first(Real_GDP['Huntington Natl Bank'])
Real_GDP = Real_GDP.drop('Huntington Nat\'l Bank', axis=1)
Real_GDP = Real_GDP.drop('Huntington Natl Bank', axis=1)

Real_GDP['Goldman Sachs'] = Real_GDP['Goldman Sachs'].combine_first(Real_GDP['Goldman Sachs & Co,'])
Real_GDP['Goldman Sachs'] = Real_GDP['Goldman Sachs'].combine_first(Real_GDP['Goldman Sachs & Co.'])
Real_GDP = Real_GDP.drop('Goldman Sachs & Co,', axis=1)
Real_GDP = Real_GDP.drop('Goldman Sachs & Co.', axis=1)

Real_GDP['Genetski Financial Advisors'] = Real_GDP['Genetski Financial Advisors'].combine_first(Real_GDP['Genetski.com'])
Real_GDP = Real_GDP.drop('Genetski.com', axis=1)

Real_GDP['Fannie Mae'] = Real_GDP['Fannie Mae'].combine_first(Real_GDP['Fannie Mae '])
Real_GDP = Real_GDP.drop('Fannie Mae ', axis=1)

Real_GDP['Deutsche Bank Securities'] = Real_GDP['Deutsche Bank Securities'].combine_first(Real_GDP['Deutsche Bank Securities, Inc.'])
Real_GDP['Deutsche Bank Securities'] = Real_GDP['Deutsche Bank Securities'].combine_first(Real_GDP['Deutsche Bank Securities, inc.'])
Real_GDP = Real_GDP.drop('Deutsche Bank Securities, Inc.', axis=1)
Real_GDP = Real_GDP.drop('Deutsche Bank Securities, inc.', axis=1)

Real_GDP['DePrince & Associates'] = Real_GDP['DePrince & Associates'].combine_first(Real_GDP['DePrince & Assoc.'])
Real_GDP['DePrince & Associates'] = Real_GDP['DePrince & Associates'].combine_first(Real_GDP['DePrince Associates'])
Real_GDP = Real_GDP.drop('DePrince & Assoc.', axis=1)
Real_GDP = Real_GDP.drop('DePrince Associates', axis=1)

Real_GDP['Aeltus Investment'] = Real_GDP['Aeltus Investment'].combine_first(Real_GDP['Aeitus Investment'])
Real_GDP['Aeltus Investment'] = Real_GDP['Aeltus Investment'].combine_first(Real_GDP['Aeltus investment'])
Real_GDP = Real_GDP.drop('Aeitus Investment', axis=1)
Real_GDP = Real_GDP.drop('Aeltus investment', axis=1)

Real_GDP['ASB Capital Management'] = Real_GDP['ASB Capital Management'].combine_first(Real_GDP['ASB Captial Management'])
Real_GDP = Real_GDP.drop('ASB Captial Management', axis=1)

Real_GDP['BMO Nesbitt Burns'] = Real_GDP['BMO Nesbitt Burns'].combine_first(Real_GDP['BMC Nesbitt Burns'])
Real_GDP = Real_GDP.drop('BMC Nesbitt Burns', axis=1)

Real_GDP['Banc One Invest. Advisors'] = Real_GDP['Banc One Invest. Advisors'].combine_first(Real_GDP['Banc One invest. Advisors'])
Real_GDP = Real_GDP.drop('Banc One invest. Advisors', axis=1)

Real_GDP['Banc of America Securities'] = Real_GDP['Banc of America Securities'].combine_first(Real_GDP['Banc of Amercia Securities'])
Real_GDP = Real_GDP.drop('Banc of Amercia Securities', axis=1)

Real_GDP['Banc of America Securities'] = Real_GDP['Banc of America Securities'].combine_first(Real_GDP['Banc of America Securities, LLC'])
Real_GDP = Real_GDP.drop('Banc of America Securities, LLC', axis=1)

Real_GDP['Bank of America Merrill Lynch'] = Real_GDP['Bank of America Merrill Lynch'].combine_first(Real_GDP['Bank of America-Merrill Lynch'])
Real_GDP = Real_GDP.drop('Bank of America-Merrill Lynch', axis=1)
Real_GDP['Bank of America Merrill Lynch'] = Real_GDP['Banc of America-Merrill Lynch'].combine_first(Real_GDP['Banc of America-Merrill Lynch'])
Real_GDP = Real_GDP.drop('Banc of America-Merrill Lynch', axis=1)

Real_GDP['Bank of Toyko-Mitsubishi'] = Real_GDP['Bank of Toyko-Mitsubishi'].combine_first(Real_GDP['Bank of Toyko-Mitsubishi UFJ'])
Real_GDP = Real_GDP.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Real_GDP['Barclays'] = Real_GDP['Barclays'].combine_first(Real_GDP['Barclays Capital'])
Real_GDP = Real_GDP.drop('Barclays Capital', axis=1)

Real_GDP['Bear Stearns'] = Real_GDP['Bear Stearns'].combine_first(Real_GDP['Bear Stearns & Co.'])
Real_GDP = Real_GDP.drop('Bear Stearns & Co.', axis=1)
Real_GDP['Bear Stearns'] = Real_GDP['Bear Stearns'].combine_first(Real_GDP['Bear Steams & Co.'])
Real_GDP = Real_GDP.drop('Bear Steams & Co.', axis=1)

Real_GDP['Camilli Economics'] = Real_GDP['Camilli Economics'].combine_first(Real_GDP['Camilli Economics LLC'])
Real_GDP = Real_GDP.drop('Camilli Economics LLC', axis=1)
Real_GDP['Camilli Economics'] = Real_GDP['Camilli Economics'].combine_first(Real_GDP['Camilli, Kathleen'])
Real_GDP = Real_GDP.drop('Camilli, Kathleen', axis=1)

Real_GDP['Citibank Global Asset Mgmt'] = Real_GDP['Citibank Global Asset Mgmt'].combine_first(Real_GDP['Citibank Global Asset Mgmt.'])
Real_GDP = Real_GDP.drop('Citibank Global Asset Mgmt.', axis=1)
Real_GDP['Citibank Global Asset Mgmt'] = Real_GDP['Citibank Global Asset Mgmt'].combine_first(Real_GDP['Citigroup Asset Management'])
Real_GDP = Real_GDP.drop('Citigroup Asset Management', axis=1)

Real_GDP['ClearView Economics'] = Real_GDP['ClearView Economics'].combine_first(Real_GDP['ClearView Associates'])
Real_GDP = Real_GDP.drop('ClearView Associates', axis=1)
Real_GDP['ClearView Economics'] = Real_GDP['ClearView Economics'].combine_first(Real_GDP['ClearView  Economics'])
Real_GDP = Real_GDP.drop('ClearView  Economics', axis=1)

Real_GDP['Comerica Bank'] = Real_GDP['Comerica Bank'].combine_first(Real_GDP['Commerica'])
Real_GDP = Real_GDP.drop('Commerica', axis=1)

Real_GDP['Cycledata Corp.'] = Real_GDP['Cycledata Corp.'].combine_first(Real_GDP['Cycledata corp.'])
Real_GDP = Real_GDP.drop('Cycledata corp.', axis=1)

Real_GDP['Daiwa Capital Markets America'] = Real_GDP['Daiwa Capital Markets America'].combine_first(Real_GDP['Daiw a Capital Markets America'])
Real_GDP = Real_GDP.drop('Daiw a Capital Markets America', axis=1)
Real_GDP['Daiwa Capital Markets America'] = Real_GDP['Daiwa Capital Markets America'].combine_first(Real_GDP['Daiwa Securities America'])
Real_GDP = Real_GDP.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
GDP_Price_Index['Moody\'s Analytics'] = GDP_Price_Index['Moody\'s Analytics'].combine_first(GDP_Price_Index['Moody\'s Capital Markets'])
GDP_Price_Index['Moody\'s Analytics'] = GDP_Price_Index['Moody\'s Analytics'].combine_first(GDP_Price_Index['Moody\'s Capital Markets Group'])
GDP_Price_Index['Moody\'s Analytics'] = GDP_Price_Index['Moody\'s Analytics'].combine_first(GDP_Price_Index['Moody\'s Econmy.com'])
GDP_Price_Index['Moody\'s Analytics'] = GDP_Price_Index['Moody\'s Analytics'].combine_first(GDP_Price_Index['Moody\'s Economy.com'])
GDP_Price_Index['Moody\'s Analytics'] = GDP_Price_Index['Moody\'s Analytics'].combine_first(GDP_Price_Index['Moody\'s Investors Service'])
GDP_Price_Index['Moody\'s Analytics'] = GDP_Price_Index['Moody\'s Analytics'].combine_first(GDP_Price_Index['Moodys Investors Service'])
GDP_Price_Index = GDP_Price_Index.drop('Moody\'s Capital Markets', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Moody\'s Capital Markets Group', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Moody\'s Econmy.com', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Moody\'s Economy.com', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Moody\'s Investors Service', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Moodys Investors Service', axis=1)

GDP_Price_Index['Nat\'l Assn. of Realtors'] = GDP_Price_Index['Nat\'l Assn. of Realtors'].combine_first(GDP_Price_Index['Nat\'l Assn, of Realtors'])
GDP_Price_Index['Nat\'l Assn. of Realtors'] = GDP_Price_Index['Nat\'l Assn. of Realtors'].combine_first(GDP_Price_Index['Nat\'I Assn, of Realtors'])
GDP_Price_Index = GDP_Price_Index.drop('Nat\'l Assn, of Realtors', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Nat\'I Assn, of Realtors', axis=1)

GDP_Price_Index['National City Bank'] = GDP_Price_Index['National City Bank'].combine_first(GDP_Price_Index['National City Corporation'])
GDP_Price_Index = GDP_Price_Index.drop('National City Corporation', axis=1)

GDP_Price_Index['Nomura Securities Inc.'] = GDP_Price_Index['Nomura Securities Inc.'].combine_first(GDP_Price_Index['Nomura Securities, Inc.'])
GDP_Price_Index = GDP_Price_Index.drop('Nomura Securities, Inc.', axis=1)

GDP_Price_Index['October Consensus'] = GDP_Price_Index['October Consensus'].combine_first(GDP_Price_Index['Octoberber Consensus'])
GDP_Price_Index = GDP_Price_Index.drop('Octoberber Consensus', axis=1)

GDP_Price_Index['PNC Bank Corp.'] = GDP_Price_Index['PNC Bank Corp.'].combine_first(GDP_Price_Index['PNC Financial Services'])
GDP_Price_Index['PNC Bank Corp.'] = GDP_Price_Index['PNC Bank Corp.'].combine_first(GDP_Price_Index['PNC Financial Services Corp.'])
GDP_Price_Index['PNC Bank Corp.'] = GDP_Price_Index['PNC Bank Corp.'].combine_first(GDP_Price_Index['PNC Financial Services Group'])
GDP_Price_Index = GDP_Price_Index.drop('PNC Financial Services', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('PNC Financial Services Corp.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('PNC Financial Services Group', axis=1)

GDP_Price_Index['Prudential Securities'] = GDP_Price_Index['Prudential Securities'].combine_first(GDP_Price_Index['Prudential Equity Group LLC'])
GDP_Price_Index['Prudential Securities'] = GDP_Price_Index['Prudential Securities'].combine_first(GDP_Price_Index['Prudential Insurance Co.'])
GDP_Price_Index['Prudential Securities'] = GDP_Price_Index['Prudential Securities'].combine_first(GDP_Price_Index['Prudential Financial'])
GDP_Price_Index = GDP_Price_Index.drop('Prudential Financial', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Prudential Insurance Co.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Prudential Equity Group LLC', axis=1)

GDP_Price_Index['RBS Greenwich Capital Econ.'] = GDP_Price_Index['RBS Greenwich Capital Econ.'].combine_first(GDP_Price_Index['RBS Securities'])
GDP_Price_Index = GDP_Price_Index.drop('RBS Securities', axis=1)

GDP_Price_Index['RBC'] = GDP_Price_Index['RBC'].combine_first(GDP_Price_Index['RBC Capital Markets'])
GDP_Price_Index = GDP_Price_Index.drop('RBC Capital Markets', axis=1)

GDP_Price_Index['RDQ Economics'] = GDP_Price_Index['RDQ Economics'].combine_first(GDP_Price_Index['RDQ'])
GDP_Price_Index = GDP_Price_Index.drop('RDQ', axis=1)

GDP_Price_Index['RidgeWorth Investments'] = GDP_Price_Index['RidgeWorth Investments'].combine_first(GDP_Price_Index['RidgeWorth Capital Management'])
GDP_Price_Index = GDP_Price_Index.drop('RidgeWorth Capital Management', axis=1)

GDP_Price_Index['S&P Global'] = GDP_Price_Index['S&P Global'].combine_first(GDP_Price_Index['S&P Global Market Intelligence'])
GDP_Price_Index['S&P Global'] = GDP_Price_Index['S&P Global'].combine_first(GDP_Price_Index['S&P Global Ratings'])
GDP_Price_Index = GDP_Price_Index.drop('S&P Global Market Intelligence', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('S&P Global Ratings', axis=1)

GDP_Price_Index['Scotiabank Group'] = GDP_Price_Index['Scotiabank Group'].combine_first(GDP_Price_Index['Scotiabank'])
GDP_Price_Index['Scotiabank Group'] = GDP_Price_Index['Scotiabank Group'].combine_first(GDP_Price_Index['Scotia Capital'])
GDP_Price_Index = GDP_Price_Index.drop('Scotia Capital', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Scotiabank', axis=1)

GDP_Price_Index['September Consensus'] = GDP_Price_Index['September Consensus'].combine_first(GDP_Price_Index['Sept. Consensus'])
GDP_Price_Index = GDP_Price_Index.drop('Sept. Consensus', axis=1)

GDP_Price_Index['Standard & Poor\'s'] = GDP_Price_Index['Standard & Poor\'s'].combine_first(GDP_Price_Index['Standard & Poor\'s Corp.'])
GDP_Price_Index['Standard & Poor\'s'] = GDP_Price_Index['Standard & Poor\'s'].combine_first(GDP_Price_Index['Standard & Poors'])
GDP_Price_Index['Standard & Poor\'s'] = GDP_Price_Index['Standard & Poor\'s'].combine_first(GDP_Price_Index['Standard & Poor’s Corp.'])
GDP_Price_Index = GDP_Price_Index.drop('Standard & Poor’s Corp.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Standard & Poor\'s Corp.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Standard & Poors', axis=1)

GDP_Price_Index['Swiss Re'] = GDP_Price_Index['Swiss Re'].combine_first(GDP_Price_Index['Sw iss Re'])
GDP_Price_Index = GDP_Price_Index.drop('Sw iss Re', axis=1)

GDP_Price_Index['Thredgold Economics'] = GDP_Price_Index['Thredgold Economics'].combine_first(GDP_Price_Index['Thredgold Economic Assoc.'])
GDP_Price_Index['Thredgold Economics'] = GDP_Price_Index['Thredgold Economics'].combine_first(GDP_Price_Index['Thredgota Economic Assoc.'])
GDP_Price_Index = GDP_Price_Index.drop('Thredgold Economic Assoc.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Thredgota Economic Assoc.', axis=1)

GDP_Price_Index['Tokai Bank, Ltd.'] = GDP_Price_Index['Tokai Bank, Ltd.'].combine_first(GDP_Price_Index['Tokai Bank, Lid.'])
GDP_Price_Index = GDP_Price_Index.drop('Tokai Bank, Lid.', axis=1)

GDP_Price_Index['Wayne Hummer & Co.'] = GDP_Price_Index['Wayne Hummer & Co.'].combine_first(GDP_Price_Index['Wayne Hummer Investments'])
GDP_Price_Index = GDP_Price_Index.drop('Wayne Hummer Investments', axis=1)

GDP_Price_Index['Wachovia'] = GDP_Price_Index['Wachovia'].combine_first(GDP_Price_Index['Wachovia Securities'])
GDP_Price_Index = GDP_Price_Index.drop('Wachovia Securities', axis=1)

GDP_Price_Index['Wells Fargo'] = GDP_Price_Index['Wells Fargo'].combine_first(GDP_Price_Index['Wells Capital Management'])
GDP_Price_Index = GDP_Price_Index.drop('Wells Capital Management', axis=1)

GDP_Price_Index['Woodworth Holdings'] = GDP_Price_Index['Woodworth Holdings'].combine_first(GDP_Price_Index['Woodw orth Holdings'])
GDP_Price_Index = GDP_Price_Index.drop('Woodw orth Holdings', axis=1)

GDP_Price_Index['independent Economic Advisory'] = GDP_Price_Index['independent Economic Advisory'].combine_first(GDP_Price_Index['independent Econ. Advisory'])
GDP_Price_Index = GDP_Price_Index.drop('independent Econ. Advisory', axis=1)

GDP_Price_Index['MacroFin Analytics'] = GDP_Price_Index['MacroFin Analytics'].combine_first(GDP_Price_Index['MacroFin Analytics & RBS'])
GDP_Price_Index['MacroFin Analytics'] = GDP_Price_Index['MacroFin Analytics'].combine_first(GDP_Price_Index['MacroFin Analytics & Rutgers Bus School'])
GDP_Price_Index['MacroFin Analytics'] = GDP_Price_Index['MacroFin Analytics'].combine_first(GDP_Price_Index['MacroFin Analytics/Rutgers Bus School'])
GDP_Price_Index = GDP_Price_Index.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('MacroFin Analytics & RBS', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

GDP_Price_Index['Mesirow Financial'] = GDP_Price_Index['Mesirow  Financial'].combine_first(GDP_Price_Index['Mesirow  Financial'])
GDP_Price_Index = GDP_Price_Index.drop('Mesirow  Financial', axis=1)

GDP_Price_Index['Merrill Lynch'] = GDP_Price_Index['Merrill Lynch'].combine_first(GDP_Price_Index['Merrill Lynch Economics'])
GDP_Price_Index = GDP_Price_Index.drop('Merrill Lynch Economics', axis=1)

GDP_Price_Index['LaSalle Nat\'I Bank'] = GDP_Price_Index['LaSalle Nat\'I Bank'].combine_first(GDP_Price_Index['LaSalle Nat\'l Bank'])
GDP_Price_Index['LaSalle Nat\'I Bank'] = GDP_Price_Index['LaSalle Nat\'I Bank'].combine_first(GDP_Price_Index['LaSalle Natl Bank'])
GDP_Price_Index = GDP_Price_Index.drop('LaSalle Nat\'l Bank', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('LaSalle Natl Bank', axis=1)

GDP_Price_Index['Kellner Economic Advisers'] = GDP_Price_Index['Kellner Economic Advisers'].combine_first(GDP_Price_Index['Keller Economic Advisers'])
GDP_Price_Index = GDP_Price_Index.drop('Keller Economic Advisers', axis=1)

GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['J.P. Morgan Chase'])
GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['J.P. Morgan Chase'])
GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['JPMorgan Asset Mgt.'])
GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['JPMorgan Fleming Asset Mgt.'])
GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['JPMorgan Privare Client Services'])
GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['JPMorgan Privare Wealth Mgt.'])
GDP_Price_Index['J.P. Morgan'] = GDP_Price_Index['J.P. Morgan'].combine_first(GDP_Price_Index['JPMorgan Private Banking'])
GDP_Price_Index = GDP_Price_Index.drop('JPMorgan Private Banking', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('JPMorgan Privare Wealth Mgt.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('JPMorgan Privare Client Services', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('JPMorgan Fleming Asset Mgt.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('JPMorgan Asset Mgt.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('J.P. Morgan Chase', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('J.P. MorganChase', axis=1)

GDP_Price_Index['Independent Economic Advisory'] = GDP_Price_Index['Independent Economic Advisory'].combine_first(GDP_Price_Index['Independent Econ. Advisory'])
GDP_Price_Index['Independent Economic Advisory'] = GDP_Price_Index['Independent Economic Advisory'].combine_first(GDP_Price_Index['Investment Economics Advisory'])
GDP_Price_Index = GDP_Price_Index.drop('Independent Econ. Advisory', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Investment Economics Advisory', axis=1)
                                         
GDP_Price_Index['ING'] = GDP_Price_Index['ING'].combine_first(GDP_Price_Index['ING Investment Mgt.'])
GDP_Price_Index = GDP_Price_Index.drop('ING Investment Mgt.', axis=1)

GDP_Price_Index['Huntington Nat\'I Bank'] = GDP_Price_Index['Huntington Nat\'I Bank'].combine_first(GDP_Price_Index['Huntington Nat\'l Bank'])
GDP_Price_Index['Huntington Nat\'I Bank'] = GDP_Price_Index['Huntington Nat\'I Bank'].combine_first(GDP_Price_Index['Huntington Natl Bank'])
GDP_Price_Index = GDP_Price_Index.drop('Huntington Nat\'l Bank', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Huntington Natl Bank', axis=1)

GDP_Price_Index['Goldman Sachs'] = GDP_Price_Index['Goldman Sachs'].combine_first(GDP_Price_Index['Goldman Sachs & Co,'])
GDP_Price_Index['Goldman Sachs'] = GDP_Price_Index['Goldman Sachs'].combine_first(GDP_Price_Index['Goldman Sachs & Co.'])
GDP_Price_Index = GDP_Price_Index.drop('Goldman Sachs & Co,', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Goldman Sachs & Co.', axis=1)

GDP_Price_Index['Genetski Financial Advisors'] = GDP_Price_Index['Genetski Financial Advisors'].combine_first(GDP_Price_Index['Genetski.com'])
GDP_Price_Index = GDP_Price_Index.drop('Genetski.com', axis=1)

GDP_Price_Index['Fannie Mae'] = GDP_Price_Index['Fannie Mae'].combine_first(GDP_Price_Index['Fannie Mae '])
GDP_Price_Index = GDP_Price_Index.drop('Fannie Mae ', axis=1)

GDP_Price_Index['Deutsche Bank Securities'] = GDP_Price_Index['Deutsche Bank Securities'].combine_first(GDP_Price_Index['Deutsche Bank Securities, Inc.'])
GDP_Price_Index['Deutsche Bank Securities'] = GDP_Price_Index['Deutsche Bank Securities'].combine_first(GDP_Price_Index['Deutsche Bank Securities, inc.'])
GDP_Price_Index = GDP_Price_Index.drop('Deutsche Bank Securities, Inc.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Deutsche Bank Securities, inc.', axis=1)

GDP_Price_Index['DePrince & Associates'] = GDP_Price_Index['DePrince & Associates'].combine_first(GDP_Price_Index['DePrince & Assoc.'])
GDP_Price_Index['DePrince & Associates'] = GDP_Price_Index['DePrince & Associates'].combine_first(GDP_Price_Index['DePrince Associates'])
GDP_Price_Index = GDP_Price_Index.drop('DePrince & Assoc.', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('DePrince Associates', axis=1)

GDP_Price_Index['Aeltus Investment'] = GDP_Price_Index['Aeltus Investment'].combine_first(GDP_Price_Index['Aeitus Investment'])
GDP_Price_Index['Aeltus Investment'] = GDP_Price_Index['Aeltus Investment'].combine_first(GDP_Price_Index['Aeltus investment'])
GDP_Price_Index = GDP_Price_Index.drop('Aeitus Investment', axis=1)
GDP_Price_Index = GDP_Price_Index.drop('Aeltus investment', axis=1)

GDP_Price_Index['ASB Capital Management'] = GDP_Price_Index['ASB Capital Management'].combine_first(GDP_Price_Index['ASB Captial Management'])
GDP_Price_Index = GDP_Price_Index.drop('ASB Captial Management', axis=1)

GDP_Price_Index['BMO Nesbitt Burns'] = GDP_Price_Index['BMO Nesbitt Burns'].combine_first(GDP_Price_Index['BMC Nesbitt Burns'])
GDP_Price_Index = GDP_Price_Index.drop('BMC Nesbitt Burns', axis=1)

GDP_Price_Index['Banc One Invest. Advisors'] = GDP_Price_Index['Banc One Invest. Advisors'].combine_first(GDP_Price_Index['Banc One invest. Advisors'])
GDP_Price_Index = GDP_Price_Index.drop('Banc One invest. Advisors', axis=1)

GDP_Price_Index['Banc of America Securities'] = GDP_Price_Index['Banc of America Securities'].combine_first(GDP_Price_Index['Banc of Amercia Securities'])
GDP_Price_Index = GDP_Price_Index.drop('Banc of Amercia Securities', axis=1)

GDP_Price_Index['Banc of America Securities'] = GDP_Price_Index['Banc of America Securities'].combine_first(GDP_Price_Index['Banc of America Securities, LLC'])
GDP_Price_Index = GDP_Price_Index.drop('Banc of America Securities, LLC', axis=1)

GDP_Price_Index['Bank of America Merrill Lynch'] = GDP_Price_Index['Bank of America Merrill Lynch'].combine_first(GDP_Price_Index['Bank of America-Merrill Lynch'])
GDP_Price_Index = GDP_Price_Index.drop('Bank of America-Merrill Lynch', axis=1)
GDP_Price_Index['Bank of America Merrill Lynch'] = GDP_Price_Index['Banc of America-Merrill Lynch'].combine_first(GDP_Price_Index['Banc of America-Merrill Lynch'])
GDP_Price_Index = GDP_Price_Index.drop('Banc of America-Merrill Lynch', axis=1)

GDP_Price_Index['Bank of Toyko-Mitsubishi'] = GDP_Price_Index['Bank of Toyko-Mitsubishi'].combine_first(GDP_Price_Index['Bank of Toyko-Mitsubishi UFJ'])
GDP_Price_Index = GDP_Price_Index.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

GDP_Price_Index['Barclays'] = GDP_Price_Index['Barclays'].combine_first(GDP_Price_Index['Barclays Capital'])
GDP_Price_Index = GDP_Price_Index.drop('Barclays Capital', axis=1)

GDP_Price_Index['Bear Stearns'] = GDP_Price_Index['Bear Stearns'].combine_first(GDP_Price_Index['Bear Stearns & Co.'])
GDP_Price_Index = GDP_Price_Index.drop('Bear Stearns & Co.', axis=1)
GDP_Price_Index['Bear Stearns'] = GDP_Price_Index['Bear Stearns'].combine_first(GDP_Price_Index['Bear Steams & Co.'])
GDP_Price_Index = GDP_Price_Index.drop('Bear Steams & Co.', axis=1)

GDP_Price_Index['Camilli Economics'] = GDP_Price_Index['Camilli Economics'].combine_first(GDP_Price_Index['Camilli Economics LLC'])
GDP_Price_Index = GDP_Price_Index.drop('Camilli Economics LLC', axis=1)
GDP_Price_Index['Camilli Economics'] = GDP_Price_Index['Camilli Economics'].combine_first(GDP_Price_Index['Camilli, Kathleen'])
GDP_Price_Index = GDP_Price_Index.drop('Camilli, Kathleen', axis=1)

GDP_Price_Index['Citibank Global Asset Mgmt'] = GDP_Price_Index['Citibank Global Asset Mgmt'].combine_first(GDP_Price_Index['Citibank Global Asset Mgmt.'])
GDP_Price_Index = GDP_Price_Index.drop('Citibank Global Asset Mgmt.', axis=1)
GDP_Price_Index['Citibank Global Asset Mgmt'] = GDP_Price_Index['Citibank Global Asset Mgmt'].combine_first(GDP_Price_Index['Citigroup Asset Management'])
GDP_Price_Index = GDP_Price_Index.drop('Citigroup Asset Management', axis=1)

GDP_Price_Index['ClearView Economics'] = GDP_Price_Index['ClearView Economics'].combine_first(GDP_Price_Index['ClearView Associates'])
GDP_Price_Index = GDP_Price_Index.drop('ClearView Associates', axis=1)
GDP_Price_Index['ClearView Economics'] = GDP_Price_Index['ClearView Economics'].combine_first(GDP_Price_Index['ClearView  Economics'])
GDP_Price_Index = GDP_Price_Index.drop('ClearView  Economics', axis=1)

GDP_Price_Index['Comerica Bank'] = GDP_Price_Index['Comerica Bank'].combine_first(GDP_Price_Index['Commerica'])
GDP_Price_Index = GDP_Price_Index.drop('Commerica', axis=1)

GDP_Price_Index['Cycledata Corp.'] = GDP_Price_Index['Cycledata Corp.'].combine_first(GDP_Price_Index['Cycledata corp.'])
GDP_Price_Index = GDP_Price_Index.drop('Cycledata corp.', axis=1)

GDP_Price_Index['Daiwa Capital Markets America'] = GDP_Price_Index['Daiwa Capital Markets America'].combine_first(GDP_Price_Index['Daiw a Capital Markets America'])
GDP_Price_Index = GDP_Price_Index.drop('Daiw a Capital Markets America', axis=1)
GDP_Price_Index['Daiwa Capital Markets America'] = GDP_Price_Index['Daiwa Capital Markets America'].combine_first(GDP_Price_Index['Daiwa Securities America'])
GDP_Price_Index = GDP_Price_Index.drop('Daiwa Securities America', axis=1)

# %%
# Объединение столбцов
Cons_Price_Index['Moody\'s Analytics'] = Cons_Price_Index['Moody\'s Analytics'].combine_first(Cons_Price_Index['Moody\'s Capital Markets'])
Cons_Price_Index['Moody\'s Analytics'] = Cons_Price_Index['Moody\'s Analytics'].combine_first(Cons_Price_Index['Moody\'s Capital Markets Group'])
Cons_Price_Index['Moody\'s Analytics'] = Cons_Price_Index['Moody\'s Analytics'].combine_first(Cons_Price_Index['Moody\'s Econmy.com'])
Cons_Price_Index['Moody\'s Analytics'] = Cons_Price_Index['Moody\'s Analytics'].combine_first(Cons_Price_Index['Moody\'s Economy.com'])
Cons_Price_Index['Moody\'s Analytics'] = Cons_Price_Index['Moody\'s Analytics'].combine_first(Cons_Price_Index['Moody\'s Investors Service'])
Cons_Price_Index['Moody\'s Analytics'] = Cons_Price_Index['Moody\'s Analytics'].combine_first(Cons_Price_Index['Moodys Investors Service'])
Cons_Price_Index = Cons_Price_Index.drop('Moody\'s Capital Markets', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Moody\'s Capital Markets Group', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Moody\'s Econmy.com', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Moody\'s Economy.com', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Moody\'s Investors Service', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Moodys Investors Service', axis=1)

Cons_Price_Index['Nat\'l Assn. of Realtors'] = Cons_Price_Index['Nat\'l Assn. of Realtors'].combine_first(Cons_Price_Index['Nat\'l Assn, of Realtors'])
Cons_Price_Index['Nat\'l Assn. of Realtors'] = Cons_Price_Index['Nat\'l Assn. of Realtors'].combine_first(Cons_Price_Index['Nat\'I Assn, of Realtors'])
Cons_Price_Index = Cons_Price_Index.drop('Nat\'l Assn, of Realtors', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Nat\'I Assn, of Realtors', axis=1)

Cons_Price_Index['National City Bank'] = Cons_Price_Index['National City Bank'].combine_first(Cons_Price_Index['National City Corporation'])
Cons_Price_Index = Cons_Price_Index.drop('National City Corporation', axis=1)

Cons_Price_Index['Nomura Securities Inc.'] = Cons_Price_Index['Nomura Securities Inc.'].combine_first(Cons_Price_Index['Nomura Securities, Inc.'])
Cons_Price_Index = Cons_Price_Index.drop('Nomura Securities, Inc.', axis=1)

Cons_Price_Index['October Consensus'] = Cons_Price_Index['October Consensus'].combine_first(Cons_Price_Index['Octoberber Consensus'])
Cons_Price_Index = Cons_Price_Index.drop('Octoberber Consensus', axis=1)

Cons_Price_Index['PNC Bank Corp.'] = Cons_Price_Index['PNC Bank Corp.'].combine_first(Cons_Price_Index['PNC Financial Services'])
Cons_Price_Index['PNC Bank Corp.'] = Cons_Price_Index['PNC Bank Corp.'].combine_first(Cons_Price_Index['PNC Financial Services Corp.'])
Cons_Price_Index['PNC Bank Corp.'] = Cons_Price_Index['PNC Bank Corp.'].combine_first(Cons_Price_Index['PNC Financial Services Group'])
Cons_Price_Index = Cons_Price_Index.drop('PNC Financial Services', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('PNC Financial Services Corp.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('PNC Financial Services Group', axis=1)

Cons_Price_Index['Prudential Securities'] = Cons_Price_Index['Prudential Securities'].combine_first(Cons_Price_Index['Prudential Equity Group LLC'])
Cons_Price_Index['Prudential Securities'] = Cons_Price_Index['Prudential Securities'].combine_first(Cons_Price_Index['Prudential Insurance Co.'])
Cons_Price_Index['Prudential Securities'] = Cons_Price_Index['Prudential Securities'].combine_first(Cons_Price_Index['Prudential Financial'])
Cons_Price_Index = Cons_Price_Index.drop('Prudential Financial', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Prudential Insurance Co.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Prudential Equity Group LLC', axis=1)

Cons_Price_Index['RBS Greenwich Capital Econ.'] = Cons_Price_Index['RBS Greenwich Capital Econ.'].combine_first(Cons_Price_Index['RBS Securities'])
Cons_Price_Index = Cons_Price_Index.drop('RBS Securities', axis=1)

Cons_Price_Index['RBC'] = Cons_Price_Index['RBC'].combine_first(Cons_Price_Index['RBC Capital Markets'])
Cons_Price_Index = Cons_Price_Index.drop('RBC Capital Markets', axis=1)

Cons_Price_Index['RDQ Economics'] = Cons_Price_Index['RDQ Economics'].combine_first(Cons_Price_Index['RDQ'])
Cons_Price_Index = Cons_Price_Index.drop('RDQ', axis=1)

Cons_Price_Index['RidgeWorth Investments'] = Cons_Price_Index['RidgeWorth Investments'].combine_first(Cons_Price_Index['RidgeWorth Capital Management'])
Cons_Price_Index = Cons_Price_Index.drop('RidgeWorth Capital Management', axis=1)

Cons_Price_Index['S&P Global'] = Cons_Price_Index['S&P Global'].combine_first(Cons_Price_Index['S&P Global Market Intelligence'])
Cons_Price_Index['S&P Global'] = Cons_Price_Index['S&P Global'].combine_first(Cons_Price_Index['S&P Global Ratings'])
Cons_Price_Index = Cons_Price_Index.drop('S&P Global Market Intelligence', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('S&P Global Ratings', axis=1)

Cons_Price_Index['Scotiabank Group'] = Cons_Price_Index['Scotiabank Group'].combine_first(Cons_Price_Index['Scotiabank'])
Cons_Price_Index['Scotiabank Group'] = Cons_Price_Index['Scotiabank Group'].combine_first(Cons_Price_Index['Scotia Capital'])
Cons_Price_Index = Cons_Price_Index.drop('Scotia Capital', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Scotiabank', axis=1)

Cons_Price_Index['September Consensus'] = Cons_Price_Index['September Consensus'].combine_first(Cons_Price_Index['Sept. Consensus'])
Cons_Price_Index = Cons_Price_Index.drop('Sept. Consensus', axis=1)

Cons_Price_Index['Standard & Poor\'s'] = Cons_Price_Index['Standard & Poor\'s'].combine_first(Cons_Price_Index['Standard & Poor\'s Corp.'])
Cons_Price_Index['Standard & Poor\'s'] = Cons_Price_Index['Standard & Poor\'s'].combine_first(Cons_Price_Index['Standard & Poors'])
Cons_Price_Index['Standard & Poor\'s'] = Cons_Price_Index['Standard & Poor\'s'].combine_first(Cons_Price_Index['Standard & Poor’s Corp.'])
Cons_Price_Index = Cons_Price_Index.drop('Standard & Poor’s Corp.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Standard & Poor\'s Corp.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Standard & Poors', axis=1)

Cons_Price_Index['Swiss Re'] = Cons_Price_Index['Swiss Re'].combine_first(Cons_Price_Index['Sw iss Re'])
Cons_Price_Index = Cons_Price_Index.drop('Sw iss Re', axis=1)

Cons_Price_Index['Thredgold Economics'] = Cons_Price_Index['Thredgold Economics'].combine_first(Cons_Price_Index['Thredgold Economic Assoc.'])
Cons_Price_Index['Thredgold Economics'] = Cons_Price_Index['Thredgold Economics'].combine_first(Cons_Price_Index['Thredgota Economic Assoc.'])
Cons_Price_Index = Cons_Price_Index.drop('Thredgold Economic Assoc.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Thredgota Economic Assoc.', axis=1)

Cons_Price_Index['Tokai Bank, Ltd.'] = Cons_Price_Index['Tokai Bank, Ltd.'].combine_first(Cons_Price_Index['Tokai Bank, Lid.'])
Cons_Price_Index = Cons_Price_Index.drop('Tokai Bank, Lid.', axis=1)

Cons_Price_Index['Wayne Hummer & Co.'] = Cons_Price_Index['Wayne Hummer & Co.'].combine_first(Cons_Price_Index['Wayne Hummer Investments'])
Cons_Price_Index = Cons_Price_Index.drop('Wayne Hummer Investments', axis=1)

Cons_Price_Index['Wachovia'] = Cons_Price_Index['Wachovia'].combine_first(Cons_Price_Index['Wachovia Securities'])
Cons_Price_Index = Cons_Price_Index.drop('Wachovia Securities', axis=1)

Cons_Price_Index['Wells Fargo'] = Cons_Price_Index['Wells Fargo'].combine_first(Cons_Price_Index['Wells Capital Management'])
Cons_Price_Index = Cons_Price_Index.drop('Wells Capital Management', axis=1)

Cons_Price_Index['Woodworth Holdings'] = Cons_Price_Index['Woodworth Holdings'].combine_first(Cons_Price_Index['Woodw orth Holdings'])
Cons_Price_Index = Cons_Price_Index.drop('Woodw orth Holdings', axis=1)

Cons_Price_Index['independent Economic Advisory'] = Cons_Price_Index['independent Economic Advisory'].combine_first(Cons_Price_Index['independent Econ. Advisory'])
Cons_Price_Index = Cons_Price_Index.drop('independent Econ. Advisory', axis=1)

Cons_Price_Index['MacroFin Analytics'] = Cons_Price_Index['MacroFin Analytics'].combine_first(Cons_Price_Index['MacroFin Analytics & RBS'])
Cons_Price_Index['MacroFin Analytics'] = Cons_Price_Index['MacroFin Analytics'].combine_first(Cons_Price_Index['MacroFin Analytics & Rutgers Bus School'])
Cons_Price_Index['MacroFin Analytics'] = Cons_Price_Index['MacroFin Analytics'].combine_first(Cons_Price_Index['MacroFin Analytics/Rutgers Bus School'])
Cons_Price_Index = Cons_Price_Index.drop('MacroFin Analytics/Rutgers Bus School', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('MacroFin Analytics & RBS', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('MacroFin Analytics & Rutgers Bus School', axis=1)

Cons_Price_Index['Mesirow Financial'] = Cons_Price_Index['Mesirow  Financial'].combine_first(Cons_Price_Index['Mesirow  Financial'])
Cons_Price_Index = Cons_Price_Index.drop('Mesirow  Financial', axis=1)

Cons_Price_Index['Merrill Lynch'] = Cons_Price_Index['Merrill Lynch'].combine_first(Cons_Price_Index['Merrill Lynch Economics'])
Cons_Price_Index = Cons_Price_Index.drop('Merrill Lynch Economics', axis=1)

Cons_Price_Index['LaSalle Nat\'I Bank'] = Cons_Price_Index['LaSalle Nat\'I Bank'].combine_first(Cons_Price_Index['LaSalle Nat\'l Bank'])
Cons_Price_Index['LaSalle Nat\'I Bank'] = Cons_Price_Index['LaSalle Nat\'I Bank'].combine_first(Cons_Price_Index['LaSalle Natl Bank'])
Cons_Price_Index = Cons_Price_Index.drop('LaSalle Nat\'l Bank', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('LaSalle Natl Bank', axis=1)

Cons_Price_Index['Kellner Economic Advisers'] = Cons_Price_Index['Kellner Economic Advisers'].combine_first(Cons_Price_Index['Keller Economic Advisers'])
Cons_Price_Index = Cons_Price_Index.drop('Keller Economic Advisers', axis=1)

Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['J.P. Morgan Chase'])
Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['J.P. Morgan Chase'])
Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['JPMorgan Asset Mgt.'])
Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['JPMorgan Fleming Asset Mgt.'])
Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['JPMorgan Privare Client Services'])
Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['JPMorgan Privare Wealth Mgt.'])
Cons_Price_Index['J.P. Morgan'] = Cons_Price_Index['J.P. Morgan'].combine_first(Cons_Price_Index['JPMorgan Private Banking'])
Cons_Price_Index = Cons_Price_Index.drop('JPMorgan Private Banking', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('JPMorgan Privare Wealth Mgt.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('JPMorgan Privare Client Services', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('JPMorgan Fleming Asset Mgt.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('JPMorgan Asset Mgt.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('J.P. Morgan Chase', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('J.P. MorganChase', axis=1)

Cons_Price_Index['Independent Economic Advisory'] = Cons_Price_Index['Independent Economic Advisory'].combine_first(Cons_Price_Index['Independent Econ. Advisory'])
Cons_Price_Index['Independent Economic Advisory'] = Cons_Price_Index['Independent Economic Advisory'].combine_first(Cons_Price_Index['Investment Economics Advisory'])
Cons_Price_Index = Cons_Price_Index.drop('Independent Econ. Advisory', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Investment Economics Advisory', axis=1)
                                         
Cons_Price_Index['ING'] = Cons_Price_Index['ING'].combine_first(Cons_Price_Index['ING Investment Mgt.'])
Cons_Price_Index = Cons_Price_Index.drop('ING Investment Mgt.', axis=1)

Cons_Price_Index['Huntington Nat\'I Bank'] = Cons_Price_Index['Huntington Nat\'I Bank'].combine_first(Cons_Price_Index['Huntington Nat\'l Bank'])
Cons_Price_Index['Huntington Nat\'I Bank'] = Cons_Price_Index['Huntington Nat\'I Bank'].combine_first(Cons_Price_Index['Huntington Natl Bank'])
Cons_Price_Index = Cons_Price_Index.drop('Huntington Nat\'l Bank', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Huntington Natl Bank', axis=1)

Cons_Price_Index['Goldman Sachs'] = Cons_Price_Index['Goldman Sachs'].combine_first(Cons_Price_Index['Goldman Sachs & Co,'])
Cons_Price_Index['Goldman Sachs'] = Cons_Price_Index['Goldman Sachs'].combine_first(Cons_Price_Index['Goldman Sachs & Co.'])
Cons_Price_Index = Cons_Price_Index.drop('Goldman Sachs & Co,', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Goldman Sachs & Co.', axis=1)

Cons_Price_Index['Genetski Financial Advisors'] = Cons_Price_Index['Genetski Financial Advisors'].combine_first(Cons_Price_Index['Genetski.com'])
Cons_Price_Index = Cons_Price_Index.drop('Genetski.com', axis=1)

Cons_Price_Index['Fannie Mae'] = Cons_Price_Index['Fannie Mae'].combine_first(Cons_Price_Index['Fannie Mae '])
Cons_Price_Index = Cons_Price_Index.drop('Fannie Mae ', axis=1)

Cons_Price_Index['Deutsche Bank Securities'] = Cons_Price_Index['Deutsche Bank Securities'].combine_first(Cons_Price_Index['Deutsche Bank Securities, Inc.'])
Cons_Price_Index['Deutsche Bank Securities'] = Cons_Price_Index['Deutsche Bank Securities'].combine_first(Cons_Price_Index['Deutsche Bank Securities, inc.'])
Cons_Price_Index = Cons_Price_Index.drop('Deutsche Bank Securities, Inc.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Deutsche Bank Securities, inc.', axis=1)

Cons_Price_Index['DePrince & Associates'] = Cons_Price_Index['DePrince & Associates'].combine_first(Cons_Price_Index['DePrince & Assoc.'])
Cons_Price_Index['DePrince & Associates'] = Cons_Price_Index['DePrince & Associates'].combine_first(Cons_Price_Index['DePrince Associates'])
Cons_Price_Index = Cons_Price_Index.drop('DePrince & Assoc.', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('DePrince Associates', axis=1)

Cons_Price_Index['Aeltus Investment'] = Cons_Price_Index['Aeltus Investment'].combine_first(Cons_Price_Index['Aeitus Investment'])
Cons_Price_Index['Aeltus Investment'] = Cons_Price_Index['Aeltus Investment'].combine_first(Cons_Price_Index['Aeltus investment'])
Cons_Price_Index = Cons_Price_Index.drop('Aeitus Investment', axis=1)
Cons_Price_Index = Cons_Price_Index.drop('Aeltus investment', axis=1)

Cons_Price_Index['ASB Capital Management'] = Cons_Price_Index['ASB Capital Management'].combine_first(Cons_Price_Index['ASB Captial Management'])
Cons_Price_Index = Cons_Price_Index.drop('ASB Captial Management', axis=1)

Cons_Price_Index['BMO Nesbitt Burns'] = Cons_Price_Index['BMO Nesbitt Burns'].combine_first(Cons_Price_Index['BMC Nesbitt Burns'])
Cons_Price_Index = Cons_Price_Index.drop('BMC Nesbitt Burns', axis=1)

Cons_Price_Index['Banc One Invest. Advisors'] = Cons_Price_Index['Banc One Invest. Advisors'].combine_first(Cons_Price_Index['Banc One invest. Advisors'])
Cons_Price_Index = Cons_Price_Index.drop('Banc One invest. Advisors', axis=1)

Cons_Price_Index['Banc of America Securities'] = Cons_Price_Index['Banc of America Securities'].combine_first(Cons_Price_Index['Banc of Amercia Securities'])
Cons_Price_Index = Cons_Price_Index.drop('Banc of Amercia Securities', axis=1)

Cons_Price_Index['Banc of America Securities'] = Cons_Price_Index['Banc of America Securities'].combine_first(Cons_Price_Index['Banc of America Securities, LLC'])
Cons_Price_Index = Cons_Price_Index.drop('Banc of America Securities, LLC', axis=1)

Cons_Price_Index['Bank of America Merrill Lynch'] = Cons_Price_Index['Bank of America Merrill Lynch'].combine_first(Cons_Price_Index['Bank of America-Merrill Lynch'])
Cons_Price_Index = Cons_Price_Index.drop('Bank of America-Merrill Lynch', axis=1)
Cons_Price_Index['Bank of America Merrill Lynch'] = Cons_Price_Index['Banc of America-Merrill Lynch'].combine_first(Cons_Price_Index['Banc of America-Merrill Lynch'])
Cons_Price_Index = Cons_Price_Index.drop('Banc of America-Merrill Lynch', axis=1)

Cons_Price_Index['Bank of Toyko-Mitsubishi'] = Cons_Price_Index['Bank of Toyko-Mitsubishi'].combine_first(Cons_Price_Index['Bank of Toyko-Mitsubishi UFJ'])
Cons_Price_Index = Cons_Price_Index.drop('Bank of Toyko-Mitsubishi UFJ', axis=1)

Cons_Price_Index['Barclays'] = Cons_Price_Index['Barclays'].combine_first(Cons_Price_Index['Barclays Capital'])
Cons_Price_Index = Cons_Price_Index.drop('Barclays Capital', axis=1)

Cons_Price_Index['Bear Stearns'] = Cons_Price_Index['Bear Stearns'].combine_first(Cons_Price_Index['Bear Stearns & Co.'])
Cons_Price_Index = Cons_Price_Index.drop('Bear Stearns & Co.', axis=1)
Cons_Price_Index['Bear Stearns'] = Cons_Price_Index['Bear Stearns'].combine_first(Cons_Price_Index['Bear Steams & Co.'])
Cons_Price_Index = Cons_Price_Index.drop('Bear Steams & Co.', axis=1)

Cons_Price_Index['Camilli Economics'] = Cons_Price_Index['Camilli Economics'].combine_first(Cons_Price_Index['Camilli Economics LLC'])
Cons_Price_Index = Cons_Price_Index.drop('Camilli Economics LLC', axis=1)
Cons_Price_Index['Camilli Economics'] = Cons_Price_Index['Camilli Economics'].combine_first(Cons_Price_Index['Camilli, Kathleen'])
Cons_Price_Index = Cons_Price_Index.drop('Camilli, Kathleen', axis=1)

Cons_Price_Index['Citibank Global Asset Mgmt'] = Cons_Price_Index['Citibank Global Asset Mgmt'].combine_first(Cons_Price_Index['Citibank Global Asset Mgmt.'])
Cons_Price_Index = Cons_Price_Index.drop('Citibank Global Asset Mgmt.', axis=1)
Cons_Price_Index['Citibank Global Asset Mgmt'] = Cons_Price_Index['Citibank Global Asset Mgmt'].combine_first(Cons_Price_Index['Citigroup Asset Management'])
Cons_Price_Index = Cons_Price_Index.drop('Citigroup Asset Management', axis=1)

Cons_Price_Index['ClearView Economics'] = Cons_Price_Index['ClearView Economics'].combine_first(Cons_Price_Index['ClearView Associates'])
Cons_Price_Index = Cons_Price_Index.drop('ClearView Associates', axis=1)
Cons_Price_Index['ClearView Economics'] = Cons_Price_Index['ClearView Economics'].combine_first(Cons_Price_Index['ClearView  Economics'])
Cons_Price_Index = Cons_Price_Index.drop('ClearView  Economics', axis=1)

Cons_Price_Index['Comerica Bank'] = Cons_Price_Index['Comerica Bank'].combine_first(Cons_Price_Index['Commerica'])
Cons_Price_Index = Cons_Price_Index.drop('Commerica', axis=1)

Cons_Price_Index['Cycledata Corp.'] = Cons_Price_Index['Cycledata Corp.'].combine_first(Cons_Price_Index['Cycledata corp.'])
Cons_Price_Index = Cons_Price_Index.drop('Cycledata corp.', axis=1)

Cons_Price_Index['Daiwa Capital Markets America'] = Cons_Price_Index['Daiwa Capital Markets America'].combine_first(Cons_Price_Index['Daiw a Capital Markets America'])
Cons_Price_Index = Cons_Price_Index.drop('Daiw a Capital Markets America', axis=1)
Cons_Price_Index['Daiwa Capital Markets America'] = Cons_Price_Index['Daiwa Capital Markets America'].combine_first(Cons_Price_Index['Daiwa Securities America'])
Cons_Price_Index = Cons_Price_Index.drop('Daiwa Securities America', axis=1)

# %%
# Создаем словарь с DataFrame-ами
dfs = {'FederalFundsRate': FederalFundsRate,
       'PrimeBankRate': PrimeBankRate,
       'LIBOR_Rate_3_Mo': LIBOR_Rate_3_Mo,
       'Com_Paper_1_Mo': Com_Paper_1_Mo,
       'Treas_Bills_3_Mo': Treas_Bills_3_Mo,
       'Treas_Bills_6_Mo': Treas_Bills_6_Mo,
       'Treas_Bills_1_Yr': Treas_Bills_1_Yr,
       'Treas_Bills_2_Yr': Treas_Bills_2_Yr,
       'Treas_Bills_5_Yr': Treas_Bills_5_Yr,
       'Treas_Bills_10_Yr': Treas_Bills_10_Yr,
       'Treas_Bills_30_Yr': Treas_Bills_30_Yr,
       'Aaa_Corp_Bond': Aaa_Corp_Bond,
       'Baa_Corp_Bond': Baa_Corp_Bond,
       'State_Local_Bonds': State_Local_Bonds,
       'Home_Mtg_Rate': Home_Mtg_Rate,
       'Feds_Major_Currency_Index': Feds_Major_Currency_Index,
       'Real_GDP': Real_GDP,
       'GDP_Price_Index': GDP_Price_Index,
       'Cons_Price_Index': Cons_Price_Index}

# Заменяем все значения NaN на -99 в каждом DataFrame
for df in dfs.values():
    df.fillna(-99, inplace=True)
    for col in df.columns:
        if df[col].dtype == 'int64' or df[col].dtype == 'float64':
            df[col] = df[col].astype(float)

# Создаем объект ExcelWriter и записываем каждый DataFrame в отдельный лист
with pd.ExcelWriter('/Users/ludmila/Desktop/bonds_no_seasonal_effect.xlsx') as writer:  
    for sheet_name, df in dfs.items():
        df.to_excel(writer, sheet_name=sheet_name)
